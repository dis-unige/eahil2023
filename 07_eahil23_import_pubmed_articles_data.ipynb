# %% [markdown]
# # The Unconquerables of Open Access
#
# ## Merge of journals with PubMed references
#
# Project for the EAHIL conference 2023 : https://eahil2023.org/
# Authors : **Floriane Muller & Pablo Iriarte**, University of Geneva
# Last update : 03.05.2023
#
# This purpose of this notebook is to import all the publications metadata from PubMed usefull for the study.
#
#
# ### Sources
#
# * Journal information obtained with notebooks 1-6
# * PubMed references obtained from the NLM FTP following the information available here: https://www.nlm.nih.gov/databases/download/pubmed_medline.html ).
#
# The whole database is downloadable in form of compressed XML files (medline23n[0001-1166].xml.gz). At the moment of our study (03.05.2023) we obtained 1166 gz files (38Gb in total)
#
# The elements of XML files are described here : https://www.nlm.nih.gov/bsd/licensee/elements_descriptions.html

# %% [markdown]
# ## MEDLINE metadata extraction
#
# * Metadata elements description: https://www.nlm.nih.gov/bsd/licensee/elements_alphabetical.html

# %% [markdown]
# ### Choice of fields to extract
#
#  * PMID: PubmedArticleSet/PubmedArticle/MedlineCitation/PMID
#  * DOI: PubmedArticleSet/PubmedArticle/PubmedData/ArticleIdList/ArticleId@IdType="doi"
#  * Publication date: PubmedArticleSet/PubmedArticle/MedlineCitation/Article/Journal/JournalIssue/PubDate/Year
#  * Journal ID: PubmedArticleSet/PubmedArticle/MedlineCitation/MedlineJournalInfo/NlmUniqueID

# %% [markdown]
# ### Extract content using XPATH and export in TSV format

# %%
import codecs
import glob
from lxml import etree
import pandas as pd
# display the full content of rows (non truncated)
pd.set_option('display.max_colwidth', -1)
# display all the columns
pd.set_option('display.max_columns', None)

# %%
# Loop for all the XML files in gz format
myfolderin = 'E:/data_sources/nlm/extractions_xml/pubmed_xml_baseline_20230503/baseline/'

# Loop for all the XML files in gz format
myfolderout = 'data/sources/pubmed/'

# select files to include
# here we limite the extraction to last 72 files (around 2'000'000 citations)
all_files = glob.glob(myfolderin + "pubmed23*.gz")

# loop into the XML files
for file_ in all_files:
    # skip x files in case of error 
    if (int(file_[-11:-7]) > 0):
        print(file_[-20:])

        # create file
        # keep the last 15 last chars of name
        fname = myfolderout + file_[-20:-7] + '.tsv'
        file = codecs.open(fname, 'w', 'utf-8')

        # write first line
        file.write('PMID\tYear\tMedlineDate\tDOI\tNlmUniqueID\n')

        # Parse XML
        root = etree.parse(file_)

        # select the node roots
        citations = root.xpath('/PubmedArticleSet/PubmedArticle')

        for i in range(len(citations)):
            # pmid
            pmid = citations[i].xpath('MedlineCitation/PMID')[0].text

            # joutnal
            journal = ''
            if (citations[i].xpath('MedlineCitation/MedlineJournalInfo/NlmUniqueID')):
                journal = citations[i].xpath('MedlineCitation/MedlineJournalInfo/NlmUniqueID')[0].text

            # year
            year = ''
            if (citations[i].xpath('MedlineCitation/Article/Journal/JournalIssue/PubDate/Year')):
                year = citations[i].xpath('MedlineCitation/Article/Journal/JournalIssue/PubDate/Year')[0].text

            date = ''
            if (citations[i].xpath('MedlineCitation/Article/Journal/JournalIssue/PubDate/MedlineDate')):
                date = citations[i].xpath('MedlineCitation/Article/Journal/JournalIssue/PubDate/MedlineDate')[0].text

            # doi
            doi = ''
            if (citations[i].xpath('PubmedData/ArticleIdList/ArticleId[@IdType="doi"]')):
                doi = citations[i].xpath('PubmedData/ArticleIdList/ArticleId[@IdType="doi"]')[0].text
                if doi is None:
                    doi = ''

            # saving data
            file.write(pmid + '\t')
            file.write(year + '\t')
            file.write(date + '\t')
            file.write(doi + '\t')
            file.write(journal + '\t')
            file.write('\n')
        file.close()
# Out:
# pubmed23n0001.xml.gz
# pubmed23n0002.xml.gz
# pubmed23n0003.xml.gz
# pubmed23n0004.xml.gz
# pubmed23n0005.xml.gz
# pubmed23n0006.xml.gz
# pubmed23n0007.xml.gz
# pubmed23n0008.xml.gz
# pubmed23n0009.xml.gz
# pubmed23n0010.xml.gz
# pubmed23n0011.xml.gz
# pubmed23n0012.xml.gz
# pubmed23n0013.xml.gz
# pubmed23n0014.xml.gz
# pubmed23n0015.xml.gz
# pubmed23n0016.xml.gz
# pubmed23n0017.xml.gz
# pubmed23n0018.xml.gz
# pubmed23n0019.xml.gz
# pubmed23n0020.xml.gz
# pubmed23n0021.xml.gz
# pubmed23n0022.xml.gz
# pubmed23n0023.xml.gz
# pubmed23n0024.xml.gz
# pubmed23n0025.xml.gz
# pubmed23n0026.xml.gz
# pubmed23n0027.xml.gz
# pubmed23n0028.xml.gz
# pubmed23n0029.xml.gz
# pubmed23n0030.xml.gz
# pubmed23n0031.xml.gz
# pubmed23n0032.xml.gz
# pubmed23n0033.xml.gz
# pubmed23n0034.xml.gz
# pubmed23n0035.xml.gz
# pubmed23n0036.xml.gz
# pubmed23n0037.xml.gz
# pubmed23n0038.xml.gz
# pubmed23n0039.xml.gz
# pubmed23n0040.xml.gz
# pubmed23n0041.xml.gz
# pubmed23n0042.xml.gz
# pubmed23n0043.xml.gz
# pubmed23n0044.xml.gz
# pubmed23n0045.xml.gz
# pubmed23n0046.xml.gz
# pubmed23n0047.xml.gz
# pubmed23n0048.xml.gz
# pubmed23n0049.xml.gz
# pubmed23n0050.xml.gz
# pubmed23n0051.xml.gz
# pubmed23n0052.xml.gz
# pubmed23n0053.xml.gz
# pubmed23n0054.xml.gz
# pubmed23n0055.xml.gz
# pubmed23n0056.xml.gz
# pubmed23n0057.xml.gz
# pubmed23n0058.xml.gz
# pubmed23n0059.xml.gz
# pubmed23n0060.xml.gz
# pubmed23n0061.xml.gz
# pubmed23n0062.xml.gz
# pubmed23n0063.xml.gz
# pubmed23n0064.xml.gz
# pubmed23n0065.xml.gz
# pubmed23n0066.xml.gz
# pubmed23n0067.xml.gz
# pubmed23n0068.xml.gz
# pubmed23n0069.xml.gz
# pubmed23n0070.xml.gz
# pubmed23n0071.xml.gz
# pubmed23n0072.xml.gz
# pubmed23n0073.xml.gz
# pubmed23n0074.xml.gz
# pubmed23n0075.xml.gz
# pubmed23n0076.xml.gz
# pubmed23n0077.xml.gz
# pubmed23n0078.xml.gz
# pubmed23n0079.xml.gz
# pubmed23n0080.xml.gz
# pubmed23n0081.xml.gz
# pubmed23n0082.xml.gz
# pubmed23n0083.xml.gz
# pubmed23n0084.xml.gz
# pubmed23n0085.xml.gz
# pubmed23n0086.xml.gz
# pubmed23n0087.xml.gz
# pubmed23n0088.xml.gz
# pubmed23n0089.xml.gz
# pubmed23n0090.xml.gz
# pubmed23n0091.xml.gz
# pubmed23n0092.xml.gz
# pubmed23n0093.xml.gz
# pubmed23n0094.xml.gz
# pubmed23n0095.xml.gz
# pubmed23n0096.xml.gz
# pubmed23n0097.xml.gz
# pubmed23n0098.xml.gz
# pubmed23n0099.xml.gz
# pubmed23n0100.xml.gz
# pubmed23n0101.xml.gz
# pubmed23n0102.xml.gz
# pubmed23n0103.xml.gz
# pubmed23n0104.xml.gz
# pubmed23n0105.xml.gz
# pubmed23n0106.xml.gz
# pubmed23n0107.xml.gz
# pubmed23n0108.xml.gz
# pubmed23n0109.xml.gz
# pubmed23n0110.xml.gz
# pubmed23n0111.xml.gz
# pubmed23n0112.xml.gz
# pubmed23n0113.xml.gz
# pubmed23n0114.xml.gz
# pubmed23n0115.xml.gz
# pubmed23n0116.xml.gz
# pubmed23n0117.xml.gz
# pubmed23n0118.xml.gz
# pubmed23n0119.xml.gz
# pubmed23n0120.xml.gz
# pubmed23n0121.xml.gz
# pubmed23n0122.xml.gz
# pubmed23n0123.xml.gz
# pubmed23n0124.xml.gz
# pubmed23n0125.xml.gz
# pubmed23n0126.xml.gz
# pubmed23n0127.xml.gz
# pubmed23n0128.xml.gz
# pubmed23n0129.xml.gz
# pubmed23n0130.xml.gz
# pubmed23n0131.xml.gz
# pubmed23n0132.xml.gz
# pubmed23n0133.xml.gz
# pubmed23n0134.xml.gz
# pubmed23n0135.xml.gz
# pubmed23n0136.xml.gz
# pubmed23n0137.xml.gz
# pubmed23n0138.xml.gz
# pubmed23n0139.xml.gz
# pubmed23n0140.xml.gz
# pubmed23n0141.xml.gz
# pubmed23n0142.xml.gz
# pubmed23n0143.xml.gz
# pubmed23n0144.xml.gz
# pubmed23n0145.xml.gz
# pubmed23n0146.xml.gz
# pubmed23n0147.xml.gz
# pubmed23n0148.xml.gz
# pubmed23n0149.xml.gz
# pubmed23n0150.xml.gz
# pubmed23n0151.xml.gz
# pubmed23n0152.xml.gz
# pubmed23n0153.xml.gz
# pubmed23n0154.xml.gz
# pubmed23n0155.xml.gz
# pubmed23n0156.xml.gz
# pubmed23n0157.xml.gz
# pubmed23n0158.xml.gz
# pubmed23n0159.xml.gz
# pubmed23n0160.xml.gz
# pubmed23n0161.xml.gz
# pubmed23n0162.xml.gz
# pubmed23n0163.xml.gz
# pubmed23n0164.xml.gz
# pubmed23n0165.xml.gz
# pubmed23n0166.xml.gz
# pubmed23n0167.xml.gz
# pubmed23n0168.xml.gz
# pubmed23n0169.xml.gz
# pubmed23n0170.xml.gz
# pubmed23n0171.xml.gz
# pubmed23n0172.xml.gz
# pubmed23n0173.xml.gz
# pubmed23n0174.xml.gz
# pubmed23n0175.xml.gz
# pubmed23n0176.xml.gz
# pubmed23n0177.xml.gz
# pubmed23n0178.xml.gz
# pubmed23n0179.xml.gz
# pubmed23n0180.xml.gz
# pubmed23n0181.xml.gz
# pubmed23n0182.xml.gz
# pubmed23n0183.xml.gz
# pubmed23n0184.xml.gz
# pubmed23n0185.xml.gz
# pubmed23n0186.xml.gz
# pubmed23n0187.xml.gz
# pubmed23n0188.xml.gz
# pubmed23n0189.xml.gz
# pubmed23n0190.xml.gz
# pubmed23n0191.xml.gz
# pubmed23n0192.xml.gz
# pubmed23n0193.xml.gz
# pubmed23n0194.xml.gz
# pubmed23n0195.xml.gz
# pubmed23n0196.xml.gz
# pubmed23n0197.xml.gz
# pubmed23n0198.xml.gz
# pubmed23n0199.xml.gz
# pubmed23n0200.xml.gz
# pubmed23n0201.xml.gz
# pubmed23n0202.xml.gz
# pubmed23n0203.xml.gz
# pubmed23n0204.xml.gz
# pubmed23n0205.xml.gz
# pubmed23n0206.xml.gz
# pubmed23n0207.xml.gz
# pubmed23n0208.xml.gz
# pubmed23n0209.xml.gz
# pubmed23n0210.xml.gz
# pubmed23n0211.xml.gz
# pubmed23n0212.xml.gz
# pubmed23n0213.xml.gz
# pubmed23n0214.xml.gz
# pubmed23n0215.xml.gz
# pubmed23n0216.xml.gz
# pubmed23n0217.xml.gz
# pubmed23n0218.xml.gz
# pubmed23n0219.xml.gz
# pubmed23n0220.xml.gz
# pubmed23n0221.xml.gz
# pubmed23n0222.xml.gz
# pubmed23n0223.xml.gz
# pubmed23n0224.xml.gz
# pubmed23n0225.xml.gz
# pubmed23n0226.xml.gz
# pubmed23n0227.xml.gz
# pubmed23n0228.xml.gz
# pubmed23n0229.xml.gz
# pubmed23n0230.xml.gz
# pubmed23n0231.xml.gz
# pubmed23n0232.xml.gz
# pubmed23n0233.xml.gz
# pubmed23n0234.xml.gz
# pubmed23n0235.xml.gz
# pubmed23n0236.xml.gz
# pubmed23n0237.xml.gz
# pubmed23n0238.xml.gz
# pubmed23n0239.xml.gz
# pubmed23n0240.xml.gz
# pubmed23n0241.xml.gz
# pubmed23n0242.xml.gz
# pubmed23n0243.xml.gz
# pubmed23n0244.xml.gz
# pubmed23n0245.xml.gz
# pubmed23n0246.xml.gz
# pubmed23n0247.xml.gz
# pubmed23n0248.xml.gz
# pubmed23n0249.xml.gz
# pubmed23n0250.xml.gz
# pubmed23n0251.xml.gz
# pubmed23n0252.xml.gz
# pubmed23n0253.xml.gz
# pubmed23n0254.xml.gz
# pubmed23n0255.xml.gz
# pubmed23n0256.xml.gz
# pubmed23n0257.xml.gz
# pubmed23n0258.xml.gz
# pubmed23n0259.xml.gz
# pubmed23n0260.xml.gz
# pubmed23n0261.xml.gz
# pubmed23n0262.xml.gz
# pubmed23n0263.xml.gz
# pubmed23n0264.xml.gz
# pubmed23n0265.xml.gz
# pubmed23n0266.xml.gz
# pubmed23n0267.xml.gz
# pubmed23n0268.xml.gz
# pubmed23n0269.xml.gz
# pubmed23n0270.xml.gz
# pubmed23n0271.xml.gz
# pubmed23n0272.xml.gz
# pubmed23n0273.xml.gz
# pubmed23n0274.xml.gz
# pubmed23n0275.xml.gz
# pubmed23n0276.xml.gz
# pubmed23n0277.xml.gz
# pubmed23n0278.xml.gz
# pubmed23n0279.xml.gz
# pubmed23n0280.xml.gz
# pubmed23n0281.xml.gz
# pubmed23n0282.xml.gz
# pubmed23n0283.xml.gz
# pubmed23n0284.xml.gz
# pubmed23n0285.xml.gz
# pubmed23n0286.xml.gz
# pubmed23n0287.xml.gz
# pubmed23n0288.xml.gz
# pubmed23n0289.xml.gz
# pubmed23n0290.xml.gz
# pubmed23n0291.xml.gz
# pubmed23n0292.xml.gz
# pubmed23n0293.xml.gz
# pubmed23n0294.xml.gz
# pubmed23n0295.xml.gz
# pubmed23n0296.xml.gz
# pubmed23n0297.xml.gz
# pubmed23n0298.xml.gz
# pubmed23n0299.xml.gz
# pubmed23n0300.xml.gz
# pubmed23n0301.xml.gz
# pubmed23n0302.xml.gz
# pubmed23n0303.xml.gz
# pubmed23n0304.xml.gz
# pubmed23n0305.xml.gz
# pubmed23n0306.xml.gz
# pubmed23n0307.xml.gz
# pubmed23n0308.xml.gz
# pubmed23n0309.xml.gz
# pubmed23n0310.xml.gz
# pubmed23n0311.xml.gz
# pubmed23n0312.xml.gz
# pubmed23n0313.xml.gz
# pubmed23n0314.xml.gz
# pubmed23n0315.xml.gz
# pubmed23n0316.xml.gz
# pubmed23n0317.xml.gz
# pubmed23n0318.xml.gz
# pubmed23n0319.xml.gz
# pubmed23n0320.xml.gz
# pubmed23n0321.xml.gz
# pubmed23n0322.xml.gz
# pubmed23n0323.xml.gz
# pubmed23n0324.xml.gz
# pubmed23n0325.xml.gz
# pubmed23n0326.xml.gz
# pubmed23n0327.xml.gz
# pubmed23n0328.xml.gz
# pubmed23n0329.xml.gz
# pubmed23n0330.xml.gz
# pubmed23n0331.xml.gz
# pubmed23n0332.xml.gz
# pubmed23n0333.xml.gz
# pubmed23n0334.xml.gz
# pubmed23n0335.xml.gz
# pubmed23n0336.xml.gz
# pubmed23n0337.xml.gz
# pubmed23n0338.xml.gz
# pubmed23n0339.xml.gz
# pubmed23n0340.xml.gz
# pubmed23n0341.xml.gz
# pubmed23n0342.xml.gz
# pubmed23n0343.xml.gz
# pubmed23n0344.xml.gz
# pubmed23n0345.xml.gz
# pubmed23n0346.xml.gz
# pubmed23n0347.xml.gz
# pubmed23n0348.xml.gz
# pubmed23n0349.xml.gz
# pubmed23n0350.xml.gz
# pubmed23n0351.xml.gz
# pubmed23n0352.xml.gz
# pubmed23n0353.xml.gz
# pubmed23n0354.xml.gz
# pubmed23n0355.xml.gz
# pubmed23n0356.xml.gz
# pubmed23n0357.xml.gz
# pubmed23n0358.xml.gz
# pubmed23n0359.xml.gz
# pubmed23n0360.xml.gz
# pubmed23n0361.xml.gz
# pubmed23n0362.xml.gz
# pubmed23n0363.xml.gz
# pubmed23n0364.xml.gz
# pubmed23n0365.xml.gz
# pubmed23n0366.xml.gz
# pubmed23n0367.xml.gz
# pubmed23n0368.xml.gz
# pubmed23n0369.xml.gz
# pubmed23n0370.xml.gz
# pubmed23n0371.xml.gz
# pubmed23n0372.xml.gz
# pubmed23n0373.xml.gz
# pubmed23n0374.xml.gz
# pubmed23n0375.xml.gz
# pubmed23n0376.xml.gz
# pubmed23n0377.xml.gz
# pubmed23n0378.xml.gz
# pubmed23n0379.xml.gz
# pubmed23n0380.xml.gz
# pubmed23n0381.xml.gz
# pubmed23n0382.xml.gz
# pubmed23n0383.xml.gz
# pubmed23n0384.xml.gz
# pubmed23n0385.xml.gz
# pubmed23n0386.xml.gz
# pubmed23n0387.xml.gz
# pubmed23n0388.xml.gz
# pubmed23n0389.xml.gz
# pubmed23n0390.xml.gz
# pubmed23n0391.xml.gz
# pubmed23n0392.xml.gz
# pubmed23n0393.xml.gz
# pubmed23n0394.xml.gz
# pubmed23n0395.xml.gz
# pubmed23n0396.xml.gz
# pubmed23n0397.xml.gz
# pubmed23n0398.xml.gz
# pubmed23n0399.xml.gz
# pubmed23n0400.xml.gz
# pubmed23n0401.xml.gz
# pubmed23n0402.xml.gz
# pubmed23n0403.xml.gz
# pubmed23n0404.xml.gz
# pubmed23n0405.xml.gz
# pubmed23n0406.xml.gz
# pubmed23n0407.xml.gz
# pubmed23n0408.xml.gz
# pubmed23n0409.xml.gz
# pubmed23n0410.xml.gz
# pubmed23n0411.xml.gz
# pubmed23n0412.xml.gz
# pubmed23n0413.xml.gz
# pubmed23n0414.xml.gz
# pubmed23n0415.xml.gz
# pubmed23n0416.xml.gz
# pubmed23n0417.xml.gz
# pubmed23n0418.xml.gz
# pubmed23n0419.xml.gz
# pubmed23n0420.xml.gz
# pubmed23n0421.xml.gz
# pubmed23n0422.xml.gz
# pubmed23n0423.xml.gz
# pubmed23n0424.xml.gz
# pubmed23n0425.xml.gz
# pubmed23n0426.xml.gz
# pubmed23n0427.xml.gz
# pubmed23n0428.xml.gz
# pubmed23n0429.xml.gz
# pubmed23n0430.xml.gz
# pubmed23n0431.xml.gz
# pubmed23n0432.xml.gz
# pubmed23n0433.xml.gz
# pubmed23n0434.xml.gz
# pubmed23n0435.xml.gz
# pubmed23n0436.xml.gz
# pubmed23n0437.xml.gz
# pubmed23n0438.xml.gz
# pubmed23n0439.xml.gz
# pubmed23n0440.xml.gz
# pubmed23n0441.xml.gz
# pubmed23n0442.xml.gz
# pubmed23n0443.xml.gz
# pubmed23n0444.xml.gz
# pubmed23n0445.xml.gz
# pubmed23n0446.xml.gz
# pubmed23n0447.xml.gz
# pubmed23n0448.xml.gz
# pubmed23n0449.xml.gz
# pubmed23n0450.xml.gz
# pubmed23n0451.xml.gz
# pubmed23n0452.xml.gz
# pubmed23n0453.xml.gz
# pubmed23n0454.xml.gz
# pubmed23n0455.xml.gz
# pubmed23n0456.xml.gz
# pubmed23n0457.xml.gz
# pubmed23n0458.xml.gz
# pubmed23n0459.xml.gz
# pubmed23n0460.xml.gz
# pubmed23n0461.xml.gz
# pubmed23n0462.xml.gz
# pubmed23n0463.xml.gz
# pubmed23n0464.xml.gz
# pubmed23n0465.xml.gz
# pubmed23n0466.xml.gz
# pubmed23n0467.xml.gz
# pubmed23n0468.xml.gz
# pubmed23n0469.xml.gz
# pubmed23n0470.xml.gz
# pubmed23n0471.xml.gz
# pubmed23n0472.xml.gz
# pubmed23n0473.xml.gz
# pubmed23n0474.xml.gz
# pubmed23n0475.xml.gz
# pubmed23n0476.xml.gz
# pubmed23n0477.xml.gz
# pubmed23n0478.xml.gz
# pubmed23n0479.xml.gz
# pubmed23n0480.xml.gz
# pubmed23n0481.xml.gz
# pubmed23n0482.xml.gz
# pubmed23n0483.xml.gz
# pubmed23n0484.xml.gz
# pubmed23n0485.xml.gz
# pubmed23n0486.xml.gz
# pubmed23n0487.xml.gz
# pubmed23n0488.xml.gz
# pubmed23n0489.xml.gz
# pubmed23n0490.xml.gz
# pubmed23n0491.xml.gz
# pubmed23n0492.xml.gz
# pubmed23n0493.xml.gz
# pubmed23n0494.xml.gz
# pubmed23n0495.xml.gz
# pubmed23n0496.xml.gz
# pubmed23n0497.xml.gz
# pubmed23n0498.xml.gz
# pubmed23n0499.xml.gz
# pubmed23n0500.xml.gz
# pubmed23n0501.xml.gz
# pubmed23n0502.xml.gz
# pubmed23n0503.xml.gz
# pubmed23n0504.xml.gz
# pubmed23n0505.xml.gz
# pubmed23n0506.xml.gz
# pubmed23n0507.xml.gz
# pubmed23n0508.xml.gz
# pubmed23n0509.xml.gz
# pubmed23n0510.xml.gz
# pubmed23n0511.xml.gz
# pubmed23n0512.xml.gz
# pubmed23n0513.xml.gz
# pubmed23n0514.xml.gz
# pubmed23n0515.xml.gz
# pubmed23n0516.xml.gz
# pubmed23n0517.xml.gz
# pubmed23n0518.xml.gz
# pubmed23n0519.xml.gz
# pubmed23n0520.xml.gz
# pubmed23n0521.xml.gz
# pubmed23n0522.xml.gz
# pubmed23n0523.xml.gz
# pubmed23n0524.xml.gz
# pubmed23n0525.xml.gz
# pubmed23n0526.xml.gz
# pubmed23n0527.xml.gz
# pubmed23n0528.xml.gz
# pubmed23n0529.xml.gz
# pubmed23n0530.xml.gz
# pubmed23n0531.xml.gz
# pubmed23n0532.xml.gz
# pubmed23n0533.xml.gz
# pubmed23n0534.xml.gz
# pubmed23n0535.xml.gz
# pubmed23n0536.xml.gz
# pubmed23n0537.xml.gz
# pubmed23n0538.xml.gz
# pubmed23n0539.xml.gz
# pubmed23n0540.xml.gz
# pubmed23n0541.xml.gz
# pubmed23n0542.xml.gz
# pubmed23n0543.xml.gz
# pubmed23n0544.xml.gz
# pubmed23n0545.xml.gz
# pubmed23n0546.xml.gz
# pubmed23n0547.xml.gz
# pubmed23n0548.xml.gz
# pubmed23n0549.xml.gz
# pubmed23n0550.xml.gz
# pubmed23n0551.xml.gz
# pubmed23n0552.xml.gz
# pubmed23n0553.xml.gz
# pubmed23n0554.xml.gz
# pubmed23n0555.xml.gz
# pubmed23n0556.xml.gz
# pubmed23n0557.xml.gz
# pubmed23n0558.xml.gz
# pubmed23n0559.xml.gz
# pubmed23n0560.xml.gz
# pubmed23n0561.xml.gz
# pubmed23n0562.xml.gz
# pubmed23n0563.xml.gz
# pubmed23n0564.xml.gz
# pubmed23n0565.xml.gz
# pubmed23n0566.xml.gz
# pubmed23n0567.xml.gz
# pubmed23n0568.xml.gz
# pubmed23n0569.xml.gz
# pubmed23n0570.xml.gz
# pubmed23n0571.xml.gz
# pubmed23n0572.xml.gz
# pubmed23n0573.xml.gz
# pubmed23n0574.xml.gz
# pubmed23n0575.xml.gz
# pubmed23n0576.xml.gz
# pubmed23n0577.xml.gz
# pubmed23n0578.xml.gz
# pubmed23n0579.xml.gz
# pubmed23n0580.xml.gz
# pubmed23n0581.xml.gz
# pubmed23n0582.xml.gz
# pubmed23n0583.xml.gz
# pubmed23n0584.xml.gz
# pubmed23n0585.xml.gz
# pubmed23n0586.xml.gz
# pubmed23n0587.xml.gz
# pubmed23n0588.xml.gz
# pubmed23n0589.xml.gz
# pubmed23n0590.xml.gz
# pubmed23n0591.xml.gz
# pubmed23n0592.xml.gz
# pubmed23n0593.xml.gz
# pubmed23n0594.xml.gz
# pubmed23n0595.xml.gz
# pubmed23n0596.xml.gz
# pubmed23n0597.xml.gz
# pubmed23n0598.xml.gz
# pubmed23n0599.xml.gz
# pubmed23n0600.xml.gz
# pubmed23n0601.xml.gz
# pubmed23n0602.xml.gz
# pubmed23n0603.xml.gz
# pubmed23n0604.xml.gz
# pubmed23n0605.xml.gz
# pubmed23n0606.xml.gz
# pubmed23n0607.xml.gz
# pubmed23n0608.xml.gz
# pubmed23n0609.xml.gz
# pubmed23n0610.xml.gz
# pubmed23n0611.xml.gz
# pubmed23n0612.xml.gz
# pubmed23n0613.xml.gz
# pubmed23n0614.xml.gz
# pubmed23n0615.xml.gz
# pubmed23n0616.xml.gz
# pubmed23n0617.xml.gz
# pubmed23n0618.xml.gz
# pubmed23n0619.xml.gz
# pubmed23n0620.xml.gz
# pubmed23n0621.xml.gz
# pubmed23n0622.xml.gz
# pubmed23n0623.xml.gz
# pubmed23n0624.xml.gz
# pubmed23n0625.xml.gz
# pubmed23n0626.xml.gz
# pubmed23n0627.xml.gz
# pubmed23n0628.xml.gz
# pubmed23n0629.xml.gz
# pubmed23n0630.xml.gz
# pubmed23n0631.xml.gz
# pubmed23n0632.xml.gz
# pubmed23n0633.xml.gz
# pubmed23n0634.xml.gz
# pubmed23n0635.xml.gz
# pubmed23n0636.xml.gz
# pubmed23n0637.xml.gz
# pubmed23n0638.xml.gz
# pubmed23n0639.xml.gz
# pubmed23n0640.xml.gz
# pubmed23n0641.xml.gz
# pubmed23n0642.xml.gz
# pubmed23n0643.xml.gz
# pubmed23n0644.xml.gz
# pubmed23n0645.xml.gz
# pubmed23n0646.xml.gz
# pubmed23n0647.xml.gz
# pubmed23n0648.xml.gz
# pubmed23n0649.xml.gz
# pubmed23n0650.xml.gz
# pubmed23n0651.xml.gz
# pubmed23n0652.xml.gz
# pubmed23n0653.xml.gz
# pubmed23n0654.xml.gz
# pubmed23n0655.xml.gz
# pubmed23n0656.xml.gz
# pubmed23n0657.xml.gz
# pubmed23n0658.xml.gz
# pubmed23n0659.xml.gz
# pubmed23n0660.xml.gz
# pubmed23n0661.xml.gz
# pubmed23n0662.xml.gz
# pubmed23n0663.xml.gz
# pubmed23n0664.xml.gz
# pubmed23n0665.xml.gz
# pubmed23n0666.xml.gz
# pubmed23n0667.xml.gz
# pubmed23n0668.xml.gz
# pubmed23n0669.xml.gz
# pubmed23n0670.xml.gz
# pubmed23n0671.xml.gz
# pubmed23n0672.xml.gz
# pubmed23n0673.xml.gz
# pubmed23n0674.xml.gz
# pubmed23n0675.xml.gz
# pubmed23n0676.xml.gz
# pubmed23n0677.xml.gz
# pubmed23n0678.xml.gz
# pubmed23n0679.xml.gz
# pubmed23n0680.xml.gz
# pubmed23n0681.xml.gz
# pubmed23n0682.xml.gz
# pubmed23n0683.xml.gz
# pubmed23n0684.xml.gz
# pubmed23n0685.xml.gz
# pubmed23n0686.xml.gz
# pubmed23n0687.xml.gz
# pubmed23n0688.xml.gz
# pubmed23n0689.xml.gz
# pubmed23n0690.xml.gz
# pubmed23n0691.xml.gz
# pubmed23n0692.xml.gz
# pubmed23n0693.xml.gz
# pubmed23n0694.xml.gz
# pubmed23n0695.xml.gz
# pubmed23n0696.xml.gz
# pubmed23n0697.xml.gz
# pubmed23n0698.xml.gz
# pubmed23n0699.xml.gz
# pubmed23n0700.xml.gz
# pubmed23n0701.xml.gz
# pubmed23n0702.xml.gz
# pubmed23n0703.xml.gz
# pubmed23n0704.xml.gz
# pubmed23n0705.xml.gz
# pubmed23n0706.xml.gz
# pubmed23n0707.xml.gz
# pubmed23n0708.xml.gz
# pubmed23n0709.xml.gz
# pubmed23n0710.xml.gz
# pubmed23n0711.xml.gz
# pubmed23n0712.xml.gz
# pubmed23n0713.xml.gz
# pubmed23n0714.xml.gz
# pubmed23n0715.xml.gz
# pubmed23n0716.xml.gz
# pubmed23n0717.xml.gz
# pubmed23n0718.xml.gz
# pubmed23n0719.xml.gz
# pubmed23n0720.xml.gz
# pubmed23n0721.xml.gz
# pubmed23n0722.xml.gz
# pubmed23n0723.xml.gz
# pubmed23n0724.xml.gz
# pubmed23n0725.xml.gz
# pubmed23n0726.xml.gz
# pubmed23n0727.xml.gz
# pubmed23n0728.xml.gz
# pubmed23n0729.xml.gz
# pubmed23n0730.xml.gz
# pubmed23n0731.xml.gz
# pubmed23n0732.xml.gz
# pubmed23n0733.xml.gz
# pubmed23n0734.xml.gz
# pubmed23n0735.xml.gz
# pubmed23n0736.xml.gz
# pubmed23n0737.xml.gz
# pubmed23n0738.xml.gz
# pubmed23n0739.xml.gz
# pubmed23n0740.xml.gz
# pubmed23n0741.xml.gz
# pubmed23n0742.xml.gz
# pubmed23n0743.xml.gz
# pubmed23n0744.xml.gz
# pubmed23n0745.xml.gz
# pubmed23n0746.xml.gz
# pubmed23n0747.xml.gz
# pubmed23n0748.xml.gz
# pubmed23n0749.xml.gz
# pubmed23n0750.xml.gz
# pubmed23n0751.xml.gz
# pubmed23n0752.xml.gz
# pubmed23n0753.xml.gz
# pubmed23n0754.xml.gz
# pubmed23n0755.xml.gz
# pubmed23n0756.xml.gz
# pubmed23n0757.xml.gz
# pubmed23n0758.xml.gz
# pubmed23n0759.xml.gz
# pubmed23n0760.xml.gz
# pubmed23n0761.xml.gz
# pubmed23n0762.xml.gz
# pubmed23n0763.xml.gz
# pubmed23n0764.xml.gz
# pubmed23n0765.xml.gz
# pubmed23n0766.xml.gz
# pubmed23n0767.xml.gz
# pubmed23n0768.xml.gz
# pubmed23n0769.xml.gz
# pubmed23n0770.xml.gz
# pubmed23n0771.xml.gz
# pubmed23n0772.xml.gz
# pubmed23n0773.xml.gz
# pubmed23n0774.xml.gz
# pubmed23n0775.xml.gz
# pubmed23n0776.xml.gz
# pubmed23n0777.xml.gz
# pubmed23n0778.xml.gz
# pubmed23n0779.xml.gz
# pubmed23n0780.xml.gz
# pubmed23n0781.xml.gz
# pubmed23n0782.xml.gz
# pubmed23n0783.xml.gz
# pubmed23n0784.xml.gz
# pubmed23n0785.xml.gz
# pubmed23n0786.xml.gz
# pubmed23n0787.xml.gz
# pubmed23n0788.xml.gz
# pubmed23n0789.xml.gz
# pubmed23n0790.xml.gz
# pubmed23n0791.xml.gz
# pubmed23n0792.xml.gz
# pubmed23n0793.xml.gz
# pubmed23n0794.xml.gz
# pubmed23n0795.xml.gz
# pubmed23n0796.xml.gz
# pubmed23n0797.xml.gz
# pubmed23n0798.xml.gz
# pubmed23n0799.xml.gz
# pubmed23n0800.xml.gz
# pubmed23n0801.xml.gz
# pubmed23n0802.xml.gz
# pubmed23n0803.xml.gz
# pubmed23n0804.xml.gz
# pubmed23n0805.xml.gz
# pubmed23n0806.xml.gz
# pubmed23n0807.xml.gz
# pubmed23n0808.xml.gz
# pubmed23n0809.xml.gz
# pubmed23n0810.xml.gz
# pubmed23n0811.xml.gz
# pubmed23n0812.xml.gz
# pubmed23n0813.xml.gz
# pubmed23n0814.xml.gz
# pubmed23n0815.xml.gz
# pubmed23n0816.xml.gz
# pubmed23n0817.xml.gz
# pubmed23n0818.xml.gz
# pubmed23n0819.xml.gz
# pubmed23n0820.xml.gz
# pubmed23n0821.xml.gz
# pubmed23n0822.xml.gz
# pubmed23n0823.xml.gz
# pubmed23n0824.xml.gz
# pubmed23n0825.xml.gz
# pubmed23n0826.xml.gz
# pubmed23n0827.xml.gz
# pubmed23n0828.xml.gz
# pubmed23n0829.xml.gz
# pubmed23n0830.xml.gz
# pubmed23n0831.xml.gz
# pubmed23n0832.xml.gz
# pubmed23n0833.xml.gz
# pubmed23n0834.xml.gz
# pubmed23n0835.xml.gz
# pubmed23n0836.xml.gz
# pubmed23n0837.xml.gz
# pubmed23n0838.xml.gz
# pubmed23n0839.xml.gz
# pubmed23n0840.xml.gz
# pubmed23n0841.xml.gz
# pubmed23n0842.xml.gz
# pubmed23n0843.xml.gz
# pubmed23n0844.xml.gz
# pubmed23n0845.xml.gz
# pubmed23n0846.xml.gz
# pubmed23n0847.xml.gz
# pubmed23n0848.xml.gz
# pubmed23n0849.xml.gz
# pubmed23n0850.xml.gz
# pubmed23n0851.xml.gz
# pubmed23n0852.xml.gz
# pubmed23n0853.xml.gz
# pubmed23n0854.xml.gz
# pubmed23n0855.xml.gz
# pubmed23n0856.xml.gz
# pubmed23n0857.xml.gz
# pubmed23n0858.xml.gz
# pubmed23n0859.xml.gz
# pubmed23n0860.xml.gz
# pubmed23n0861.xml.gz
# pubmed23n0862.xml.gz
# pubmed23n0863.xml.gz
# pubmed23n0864.xml.gz
# pubmed23n0865.xml.gz
# pubmed23n0866.xml.gz
# pubmed23n0867.xml.gz
# pubmed23n0868.xml.gz
# pubmed23n0869.xml.gz
# pubmed23n0870.xml.gz
# pubmed23n0871.xml.gz
# pubmed23n0872.xml.gz
# pubmed23n0873.xml.gz
# pubmed23n0874.xml.gz
# pubmed23n0875.xml.gz
# pubmed23n0876.xml.gz
# pubmed23n0877.xml.gz
# pubmed23n0878.xml.gz
# pubmed23n0879.xml.gz
# pubmed23n0880.xml.gz
# pubmed23n0881.xml.gz
# pubmed23n0882.xml.gz
# pubmed23n0883.xml.gz
# pubmed23n0884.xml.gz
# pubmed23n0885.xml.gz
# pubmed23n0886.xml.gz
# pubmed23n0887.xml.gz
# pubmed23n0888.xml.gz
# pubmed23n0889.xml.gz
# pubmed23n0890.xml.gz
# pubmed23n0891.xml.gz
# pubmed23n0892.xml.gz
# pubmed23n0893.xml.gz
# pubmed23n0894.xml.gz
# pubmed23n0895.xml.gz
# pubmed23n0896.xml.gz
# pubmed23n0897.xml.gz
# pubmed23n0898.xml.gz
# pubmed23n0899.xml.gz
# pubmed23n0900.xml.gz
# pubmed23n0901.xml.gz
# pubmed23n0902.xml.gz
# pubmed23n0903.xml.gz
# pubmed23n0904.xml.gz
# pubmed23n0905.xml.gz
# pubmed23n0906.xml.gz
# pubmed23n0907.xml.gz
# pubmed23n0908.xml.gz
# pubmed23n0909.xml.gz
# pubmed23n0910.xml.gz
# pubmed23n0911.xml.gz
# pubmed23n0912.xml.gz
# pubmed23n0913.xml.gz
# pubmed23n0914.xml.gz
# pubmed23n0915.xml.gz
# pubmed23n0916.xml.gz
# pubmed23n0917.xml.gz
# pubmed23n0918.xml.gz
# pubmed23n0919.xml.gz
# pubmed23n0920.xml.gz
# pubmed23n0921.xml.gz
# pubmed23n0922.xml.gz
# pubmed23n0923.xml.gz
# pubmed23n0924.xml.gz
# pubmed23n0925.xml.gz
# pubmed23n0926.xml.gz
# pubmed23n0927.xml.gz
# pubmed23n0928.xml.gz
# pubmed23n0929.xml.gz
# pubmed23n0930.xml.gz
# pubmed23n0931.xml.gz
# pubmed23n0932.xml.gz
# pubmed23n0933.xml.gz
# pubmed23n0934.xml.gz
# pubmed23n0935.xml.gz
# pubmed23n0936.xml.gz
# pubmed23n0937.xml.gz
# pubmed23n0938.xml.gz
# pubmed23n0939.xml.gz
# pubmed23n0940.xml.gz
# pubmed23n0941.xml.gz
# pubmed23n0942.xml.gz
# pubmed23n0943.xml.gz
# pubmed23n0944.xml.gz
# pubmed23n0945.xml.gz
# pubmed23n0946.xml.gz
# pubmed23n0947.xml.gz
# pubmed23n0948.xml.gz
# pubmed23n0949.xml.gz
# pubmed23n0950.xml.gz
# pubmed23n0951.xml.gz
# pubmed23n0952.xml.gz
# pubmed23n0953.xml.gz
# pubmed23n0954.xml.gz
# pubmed23n0955.xml.gz
# pubmed23n0956.xml.gz
# pubmed23n0957.xml.gz
# pubmed23n0958.xml.gz
# pubmed23n0959.xml.gz
# pubmed23n0960.xml.gz
# pubmed23n0961.xml.gz
# pubmed23n0962.xml.gz
# pubmed23n0963.xml.gz
# pubmed23n0964.xml.gz
# pubmed23n0965.xml.gz
# pubmed23n0966.xml.gz
# pubmed23n0967.xml.gz
# pubmed23n0968.xml.gz
# pubmed23n0969.xml.gz
# pubmed23n0970.xml.gz
# pubmed23n0971.xml.gz
# pubmed23n0972.xml.gz
# pubmed23n0973.xml.gz
# pubmed23n0974.xml.gz
# pubmed23n0975.xml.gz
# pubmed23n0976.xml.gz
# pubmed23n0977.xml.gz
# pubmed23n0978.xml.gz
# pubmed23n0979.xml.gz
# pubmed23n0980.xml.gz
# pubmed23n0981.xml.gz
# pubmed23n0982.xml.gz
# pubmed23n0983.xml.gz
# pubmed23n0984.xml.gz
# pubmed23n0985.xml.gz
# pubmed23n0986.xml.gz
# pubmed23n0987.xml.gz
# pubmed23n0988.xml.gz
# pubmed23n0989.xml.gz
# pubmed23n0990.xml.gz
# pubmed23n0991.xml.gz
# pubmed23n0992.xml.gz
# pubmed23n0993.xml.gz
# pubmed23n0994.xml.gz
# pubmed23n0995.xml.gz
# pubmed23n0996.xml.gz
# pubmed23n0997.xml.gz
# pubmed23n0998.xml.gz
# pubmed23n0999.xml.gz
# pubmed23n1000.xml.gz
# pubmed23n1001.xml.gz
# pubmed23n1002.xml.gz
# pubmed23n1003.xml.gz
# pubmed23n1004.xml.gz
# pubmed23n1005.xml.gz
# pubmed23n1006.xml.gz
# pubmed23n1007.xml.gz
# pubmed23n1008.xml.gz
# pubmed23n1009.xml.gz
# pubmed23n1010.xml.gz
# pubmed23n1011.xml.gz
# pubmed23n1012.xml.gz
# pubmed23n1013.xml.gz
# pubmed23n1014.xml.gz
# pubmed23n1015.xml.gz
# pubmed23n1016.xml.gz
# pubmed23n1017.xml.gz
# pubmed23n1018.xml.gz
# pubmed23n1019.xml.gz
# pubmed23n1020.xml.gz
# pubmed23n1021.xml.gz
# pubmed23n1022.xml.gz
# pubmed23n1023.xml.gz
# pubmed23n1024.xml.gz
# pubmed23n1025.xml.gz
# pubmed23n1026.xml.gz
# pubmed23n1027.xml.gz
# pubmed23n1028.xml.gz
# pubmed23n1029.xml.gz
# pubmed23n1030.xml.gz
# pubmed23n1031.xml.gz
# pubmed23n1032.xml.gz
# pubmed23n1033.xml.gz
# pubmed23n1034.xml.gz
# pubmed23n1035.xml.gz
# pubmed23n1036.xml.gz
# pubmed23n1037.xml.gz
# pubmed23n1038.xml.gz
# pubmed23n1039.xml.gz
# pubmed23n1040.xml.gz
# pubmed23n1041.xml.gz
# pubmed23n1042.xml.gz
# pubmed23n1043.xml.gz
# pubmed23n1044.xml.gz
# pubmed23n1045.xml.gz
# pubmed23n1046.xml.gz
# pubmed23n1047.xml.gz
# pubmed23n1048.xml.gz
# pubmed23n1049.xml.gz
# pubmed23n1050.xml.gz
# pubmed23n1051.xml.gz
# pubmed23n1052.xml.gz
# pubmed23n1053.xml.gz
# pubmed23n1054.xml.gz
# pubmed23n1055.xml.gz
# pubmed23n1056.xml.gz
# pubmed23n1057.xml.gz
# pubmed23n1058.xml.gz
# pubmed23n1059.xml.gz
# pubmed23n1060.xml.gz
# pubmed23n1061.xml.gz
# pubmed23n1062.xml.gz
# pubmed23n1063.xml.gz
# pubmed23n1064.xml.gz
# pubmed23n1065.xml.gz
# pubmed23n1066.xml.gz
# pubmed23n1067.xml.gz
# pubmed23n1068.xml.gz
# pubmed23n1069.xml.gz
# pubmed23n1070.xml.gz
# pubmed23n1071.xml.gz
# pubmed23n1072.xml.gz
# pubmed23n1073.xml.gz
# pubmed23n1074.xml.gz
# pubmed23n1075.xml.gz
# pubmed23n1076.xml.gz
# pubmed23n1077.xml.gz
# pubmed23n1078.xml.gz
# pubmed23n1079.xml.gz
# pubmed23n1080.xml.gz
# pubmed23n1081.xml.gz
# pubmed23n1082.xml.gz
# pubmed23n1083.xml.gz
# pubmed23n1084.xml.gz
# pubmed23n1085.xml.gz
# pubmed23n1086.xml.gz
# pubmed23n1087.xml.gz
# pubmed23n1088.xml.gz
# pubmed23n1089.xml.gz
# pubmed23n1090.xml.gz
# pubmed23n1091.xml.gz
# pubmed23n1092.xml.gz
# pubmed23n1093.xml.gz
# pubmed23n1094.xml.gz
# pubmed23n1095.xml.gz
# pubmed23n1096.xml.gz
# pubmed23n1097.xml.gz
# pubmed23n1098.xml.gz
# pubmed23n1099.xml.gz
# pubmed23n1100.xml.gz
# pubmed23n1101.xml.gz
# pubmed23n1102.xml.gz
# pubmed23n1103.xml.gz
# pubmed23n1104.xml.gz
# pubmed23n1105.xml.gz
# pubmed23n1106.xml.gz
# pubmed23n1107.xml.gz
# pubmed23n1108.xml.gz
# pubmed23n1109.xml.gz
# pubmed23n1110.xml.gz
# pubmed23n1111.xml.gz
# pubmed23n1112.xml.gz
# pubmed23n1113.xml.gz
# pubmed23n1114.xml.gz
# pubmed23n1115.xml.gz
# pubmed23n1116.xml.gz
# pubmed23n1117.xml.gz
# pubmed23n1118.xml.gz
# pubmed23n1119.xml.gz
# pubmed23n1120.xml.gz
# pubmed23n1121.xml.gz
# pubmed23n1122.xml.gz
# pubmed23n1123.xml.gz
# pubmed23n1124.xml.gz
# pubmed23n1125.xml.gz
# pubmed23n1126.xml.gz
# pubmed23n1127.xml.gz
# pubmed23n1128.xml.gz
# pubmed23n1129.xml.gz
# pubmed23n1130.xml.gz
# pubmed23n1131.xml.gz
# pubmed23n1132.xml.gz
# pubmed23n1133.xml.gz
# pubmed23n1134.xml.gz
# pubmed23n1135.xml.gz
# pubmed23n1136.xml.gz
# pubmed23n1137.xml.gz
# pubmed23n1138.xml.gz
# pubmed23n1139.xml.gz
# pubmed23n1140.xml.gz
# pubmed23n1141.xml.gz
# pubmed23n1142.xml.gz
# pubmed23n1143.xml.gz
# pubmed23n1144.xml.gz
# pubmed23n1145.xml.gz
# pubmed23n1146.xml.gz
# pubmed23n1147.xml.gz
# pubmed23n1148.xml.gz
# pubmed23n1149.xml.gz
# pubmed23n1150.xml.gz
# pubmed23n1151.xml.gz
# pubmed23n1152.xml.gz
# pubmed23n1153.xml.gz
# pubmed23n1154.xml.gz
# pubmed23n1155.xml.gz
# pubmed23n1156.xml.gz
# pubmed23n1157.xml.gz
# pubmed23n1158.xml.gz
# pubmed23n1159.xml.gz
# pubmed23n1160.xml.gz
# pubmed23n1161.xml.gz
# pubmed23n1162.xml.gz
# pubmed23n1163.xml.gz
# pubmed23n1164.xml.gz
# pubmed23n1165.xml.gz
# pubmed23n1166.xml.gz
