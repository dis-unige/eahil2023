# %% [markdown]
# # The Unconquerables of Open Access
#
# ## Merge of journals with PubMed references
#
# Project for the EAHIL conference 2023 : https://eahil2023.org/
# Authors : **Floriane Muller & Pablo Iriarte**, University of Geneva
# Last update : 24.05.2023
#
# This purpose of this notebook is to merge the information about journals with all the publications metadata extracted from PubMed
#
#
# ### Sources
#
# * Journal information obtained with notebooks 1-6 : file results/2023/MedlineJournals.tsv
# * PubMed references metadata obtained with notebook 7: 1166 tsv files in data/sources/pubmed/pubmed23n[0001-1166].tsv

# %% [markdown]
# ### Choice of fields extracted
#
#  * PMID: PubmedArticleSet/PubmedArticle/MedlineCitation/PMID
#  * DOI: PubmedArticleSet/PubmedArticle/PubmedData/ArticleIdList/ArticleId@IdType="doi"
#  * Publication date: PubmedArticleSet/PubmedArticle/MedlineCitation/Article/Journal/JournalIssue/PubDate/Year
#  * Journal ID: PubmedArticleSet/PubmedArticle/MedlineCitation/MedlineJournalInfo/NlmUniqueID

# %% [markdown]
# ### Extract content using XPATH and export in TSV format

# %%
import pandas as pd
import os
# display the full content of rows (non truncated)
pd.set_option('display.max_colwidth', -1)
# display all the columns
pd.set_option('display.max_columns', None)
# folder of PubMed tsv files
myfolderpubmed = 'data/sources/pubmed/'
# dataframe
df_pubmed = pd.DataFrame()

# %%
# loop into the TSV files
for file in os.listdir(myfolderpubmed):
    # skip x files in case of error
    # errors:
    # file pubmed23n0303.tsv, Expected 6 fields in line 19219, saw 7: "9127676	1996		10.1076/apab.104.7.814.13110		9510153	"
    # file pubmed23n0325.tsv, Expected 6 fields in line 17666, saw 7: "9803271	1998		10.1046/j.1469-1809.1998.6230271.x		0416661	"
    # file pubmed23n0389.tsv, Expected 6 fields in line 14430, saw 7: "11772327	2002		10.1517/13543784.11.1.125		9434197	"
    # file pubmed23n0396.tsv, Expected 6 fields in line 15897, saw 7: "11996645	2002		10.1517/13543784.11.5.631	9434197	"
    # file pubmed23n0417.tsv, Expected 6 fields in line 24429, saw 7: "12745873	2003		10.1080/0049825031000066259		1306665	"
    # file pubmed23n0422.tsv, Expected 6 fields in line 16816, saw 7: "12901678	2003		10.1080/713610419	8914274	"
    # file pubmed23n0422.tsv, Expected 6 fields in line 16817, saw 7: "12901679	2003		10.1080/713610420	8914274	"
    # file pubmed23n0507.tsv, Expected 6 fields in line 21839, saw 7: "15545080	2004		10.1080/10611860400005697	9312476	"
    # file pubmed23n0592.tsv, Expected 6 fields in line 19800, saw 7: "18274931	2008		10.1080/10611860802095494		9312476	"
    # file pubmed23n0598.tsv, Expected 6 fields in line 3122, saw 7: "18446603	2008		10.1080/10611860802088523		9312476	"
    # file pubmed23n0599.tsv, Expected 6 fields in line 28353, saw 7: "18504824	2008		10.1038/nrg2381		100962779	"
    # file pubmed23n0602.tsv, Expected 6 fields in line 27008, saw 7: "18604657	2008		10.1080/10611860802088523		9312476	"
    # file pubmed23n0602.tsv, Expected 6 fields in line 27010, saw 7: "18604657	2008		10.1080/10611860802088523		9312476	"
    # file pubmed23n0603.tsv, Expected 6 fields in line 2968, saw 7: "18611112	2008		10.1517/17425255.4.6.697		101228422	"
    # file pubmed23n0615.tsv, Expected 6 fields in line 13590, saw 7: "19005871	2009		10.1080/14756360902784425		101150203	"
    if (int(file[9:13]) > 0):
        print(file[9:13])
        df_temp = pd.read_csv(myfolderpubmed + file, sep='\t', header=0, usecols=['PMID', 'Year', 'MedlineDate', 'DOI', 'NlmUniqueID'], dtype={'MedlineDate' : str, 'DOI' : str, 'NlmUniqueID' : str})
        df_pubmed = df_pubmed.append(df_temp, ignore_index=True)
# Out:
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# 0137
# 0138
# 0139
# 0140
# 0141
# 0142
# 0143
# 0144
# 0145
# 0146
# 0147
# 0148
# 0149
# 0150
# 0151
# 0152
# 0153
# 0154
# 0155
# 0156
# 0157
# 0158
# 0159
# 0160
# 0161
# 0162
# 0163
# 0164
# 0165
# 0166
# 0167
# 0168
# 0169
# 0170
# 0171
# 0172
# 0173
# 0174
# 0175
# 0176
# 0177
# 0178
# 0179
# 0180
# 0181
# 0182
# 0183
# 0184
# 0185
# 0186
# 0187
# 0188
# 0189
# 0190
# 0191
# 0192
# 0193
# 0194
# 0195
# 0196
# 0197
# 0198
# 0199
# 0200
# 0201
# 0202
# 0203
# 0204
# 0205
# 0206
# 0207
# 0208
# 0209
# 0210
# 0211
# 0212
# 0213
# 0214
# 0215
# 0216
# 0217
# 0218
# 0219
# 0220
# 0221
# 0222
# 0223
# 0224
# 0225
# 0226
# 0227
# 0228
# 0229
# 0230
# 0231
# 0232
# 0233
# 0234
# 0235
# 0236
# 0237
# 0238
# 0239
# 0240
# 0241
# 0242
# 0243
# 0244
# 0245
# 0246
# 0247
# 0248
# 0249
# 0250
# 0251
# 0252
# 0253
# 0254
# 0255
# 0256
# 0257
# 0258
# 0259
# 0260
# 0261
# 0262
# 0263
# 0264
# 0265
# 0266
# 0267
# 0268
# 0269
# 0270
# 0271
# 0272
# 0273
# 0274
# 0275
# 0276
# 0277
# 0278
# 0279
# 0280
# 0281
# 0282
# 0283
# 0284
# 0285
# 0286
# 0287
# 0288
# 0289
# 0290
# 0291
# 0292
# 0293
# 0294
# 0295
# 0296
# 0297
# 0298
# 0299
# 0300
# 0301
# 0302
# 0303
# 0304
# 0305
# 0306
# 0307
# 0308
# 0309
# 0310
# 0311
# 0312
# 0313
# 0314
# 0315
# 0316
# 0317
# 0318
# 0319
# 0320
# 0321
# 0322
# 0323
# 0324
# 0325
# 0326
# 0327
# 0328
# 0329
# 0330
# 0331
# 0332
# 0333
# 0334
# 0335
# 0336
# 0337
# 0338
# 0339
# 0340
# 0341
# 0342
# 0343
# 0344
# 0345
# 0346
# 0347
# 0348
# 0349
# 0350
# 0351
# 0352
# 0353
# 0354
# 0355
# 0356
# 0357
# 0358
# 0359
# 0360
# 0361
# 0362
# 0363
# 0364
# 0365
# 0366
# 0367
# 0368
# 0369
# 0370
# 0371
# 0372
# 0373
# 0374
# 0375
# 0376
# 0377
# 0378
# 0379
# 0380
# 0381
# 0382
# 0383
# 0384
# 0385
# 0386
# 0387
# 0388
# 0389
# 0390
# 0391
# 0392
# 0393
# 0394
# 0395
# 0396
# 0397
# 0398
# 0399
# 0400
# 0401
# 0402
# 0403
# 0404
# 0405
# 0406
# 0407
# 0408
# 0409
# 0410
# 0411
# 0412
# 0413
# 0414
# 0415
# 0416
# 0417
# 0418
# 0419
# 0420
# 0421
# 0422
# 0423
# 0424
# 0425
# 0426
# 0427
# 0428
# 0429
# 0430
# 0431
# 0432
# 0433
# 0434
# 0435
# 0436
# 0437
# 0438
# 0439
# 0440
# 0441
# 0442
# 0443
# 0444
# 0445
# 0446
# 0447
# 0448
# 0449
# 0450
# 0451
# 0452
# 0453
# 0454
# 0455
# 0456
# 0457
# 0458
# 0459
# 0460
# 0461
# 0462
# 0463
# 0464
# 0465
# 0466
# 0467
# 0468
# 0469
# 0470
# 0471
# 0472
# 0473
# 0474
# 0475
# 0476
# 0477
# 0478
# 0479
# 0480
# 0481
# 0482
# 0483
# 0484
# 0485
# 0486
# 0487
# 0488
# 0489
# 0490
# 0491
# 0492
# 0493
# 0494
# 0495
# 0496
# 0497
# 0498
# 0499
# 0500
# 0501
# 0502
# 0503
# 0504
# 0505
# 0506
# 0507
# 0508
# 0509
# 0510
# 0511
# 0512
# 0513
# 0514
# 0515
# 0516
# 0517
# 0518
# 0519
# 0520
# 0521
# 0522
# 0523
# 0524
# 0525
# 0526
# 0527
# 0528
# 0529
# 0530
# 0531
# 0532
# 0533
# 0534
# 0535
# 0536
# 0537
# 0538
# 0539
# 0540
# 0541
# 0542
# 0543
# 0544
# 0545
# 0546
# 0547
# 0548
# 0549
# 0550
# 0551
# 0552
# 0553
# 0554
# 0555
# 0556
# 0557
# 0558
# 0559
# 0560
# 0561
# 0562
# 0563
# 0564
# 0565
# 0566
# 0567
# 0568
# 0569
# 0570
# 0571
# 0572
# 0573
# 0574
# 0575
# 0576
# 0577
# 0578
# 0579
# 0580
# 0581
# 0582
# 0583
# 0584
# 0585
# 0586
# 0587
# 0588
# 0589
# 0590
# 0591
# 0592
# 0593
# 0594
# 0595
# 0596
# 0597
# 0598
# 0599
# 0600
# 0601
# 0602
# 0603
# 0604
# 0605
# 0606
# 0607
# 0608
# 0609
# 0610
# 0611
# 0612
# 0613
# 0614
# 0615
# 0616
# 0617
# 0618
# 0619
# 0620
# 0621
# 0622
# 0623
# 0624
# 0625
# 0626
# 0627
# 0628
# 0629
# 0630
# 0631
# 0632
# 0633
# 0634
# 0635
# 0636
# 0637
# 0638
# 0639
# 0640
# 0641
# 0642
# 0643
# 0644
# 0645
# 0646
# 0647
# 0648
# 0649
# 0650
# 0651
# 0652
# 0653
# 0654
# 0655
# 0656
# 0657
# 0658
# 0659
# 0660
# 0661
# 0662
# 0663
# 0664
# 0665
# 0666
# 0667
# 0668
# 0669
# 0670
# 0671
# 0672
# 0673
# 0674
# 0675
# 0676
# 0677
# 0678
# 0679
# 0680
# 0681
# 0682
# 0683
# 0684
# 0685
# 0686
# 0687
# 0688
# 0689
# 0690
# 0691
# 0692
# 0693
# 0694
# 0695
# 0696
# 0697
# 0698
# 0699
# 0700
# 0701
# 0702
# 0703
# 0704
# 0705
# 0706
# 0707
# 0708
# 0709
# 0710
# 0711
# 0712
# 0713
# 0714
# 0715
# 0716
# 0717
# 0718
# 0719
# 0720
# 0721
# 0722
# 0723
# 0724
# 0725
# 0726
# 0727
# 0728
# 0729
# 0730
# 0731
# 0732
# 0733
# 0734
# 0735
# 0736
# 0737
# 0738
# 0739
# 0740
# 0741
# 0742
# 0743
# 0744
# 0745
# 0746
# 0747
# 0748
# 0749
# 0750
# 0751
# 0752
# 0753
# 0754
# 0755
# 0756
# 0757
# 0758
# 0759
# 0760
# 0761
# 0762
# 0763
# 0764
# 0765
# 0766
# 0767
# 0768
# 0769
# 0770
# 0771
# 0772
# 0773
# 0774
# 0775
# 0776
# 0777
# 0778
# 0779
# 0780
# 0781
# 0782
# 0783
# 0784
# 0785
# 0786
# 0787
# 0788
# 0789
# 0790
# 0791
# 0792
# 0793
# 0794
# 0795
# 0796
# 0797
# 0798
# 0799
# 0800
# 0801
# 0802
# 0803
# 0804
# 0805
# 0806
# 0807
# 0808
# 0809
# 0810
# 0811
# 0812
# 0813
# 0814
# 0815
# 0816
# 0817
# 0818
# 0819
# 0820
# 0821
# 0822
# 0823
# 0824
# 0825
# 0826
# 0827
# 0828
# 0829
# 0830
# 0831
# 0832
# 0833
# 0834
# 0835
# 0836
# 0837
# 0838
# 0839
# 0840
# 0841
# 0842
# 0843
# 0844
# 0845
# 0846
# 0847
# 0848
# 0849
# 0850
# 0851
# 0852
# 0853
# 0854
# 0855
# 0856
# 0857
# 0858
# 0859
# 0860
# 0861
# 0862
# 0863
# 0864
# 0865
# 0866
# 0867
# 0868
# 0869
# 0870
# 0871
# 0872
# 0873
# 0874
# 0875
# 0876
# 0877
# 0878
# 0879
# 0880
# 0881
# 0882
# 0883
# 0884
# 0885
# 0886
# 0887
# 0888
# 0889
# 0890
# 0891
# 0892
# 0893
# 0894
# 0895
# 0896
# 0897
# 0898
# 0899
# 0900
# 0901
# 0902
# 0903
# 0904
# 0905
# 0906
# 0907
# 0908
# 0909
# 0910
# 0911
# 0912
# 0913
# 0914
# 0915
# 0916
# 0917
# 0918
# 0919
# 0920
# 0921
# 0922
# 0923
# 0924
# 0925
# 0926
# 0927
# 0928
# 0929
# 0930
# 0931
# 0932
# 0933
# 0934
# 0935
# 0936
# 0937
# 0938
# 0939
# 0940
# 0941
# 0942
# 0943
# 0944
# 0945
# 0946
# 0947
# 0948
# 0949
# 0950
# 0951
# 0952
# 0953
# 0954
# 0955
# 0956
# 0957
# 0958
# 0959
# 0960
# 0961
# 0962
# 0963
# 0964
# 0965
# 0966
# 0967
# 0968
# 0969
# 0970
# 0971
# 0972
# 0973
# 0974
# 0975
# 0976
# 0977
# 0978
# 0979
# 0980
# 0981
# 0982
# 0983
# 0984
# 0985
# 0986
# 0987
# 0988
# 0989
# 0990
# 0991
# 0992
# 0993
# 0994
# 0995
# 0996
# 0997
# 0998
# 0999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1146
# 1147
# 1148
# 1149
# 1150
# 1151
# 1152
# 1153
# 1154
# 1155
# 1156
# 1157
# 1158
# 1159
# 1160
# 1161
# 1162
# 1163
# 1164
# 1165
# 1166

# %%
df_pubmed
# Out:
#               PMID    Year MedlineDate                           DOI  \
# 0         1         1975.0  NaN         10.1016/0006-2944(75)90147-7
# 1         2         1975.0  NaN         10.1016/0006-291x(75)90482-9
# 2         4         1975.0  NaN         10.1016/0006-291x(75)90506-9
# 3         3         1975.0  NaN         10.1016/0006-291x(75)90498-2
# 4         5         1975.0  NaN         10.1016/0006-291x(75)90508-2
# ...      ..            ...  ...                                  ...
# 34960695  36475580  2022.0  NaN         10.1021/acsami.2c16255
# 34960696  36475581  2022.0  NaN         10.1021/acsami.2c17703
# 34960697  36475582  2022.0  NaN         10.1021/acsami.2c16205
# 34960698  36475583  2022.0  NaN         10.1021/acsami.2c17147
# 34960699  36475584  2022.0  NaN         10.1021/acsabm.2c00725
#
#          NlmUniqueID
# 0         0151424
# 1         0372516
# 2         0372516
# 3         0372516
# 4         0372516
# ...           ...
# 34960695  101504991
# 34960696  101504991
# 34960697  101504991
# 34960698  101504991
# 34960699  101729147
#
# [34960700 rows x 5 columns]

# %%
# csv export
df_pubmed.to_csv('data/temp/2023/pubmed_all.tsv', sep='\t', index=False)

# %%
# refs with empty year
df_pubmed.loc[df_pubmed['Year'].isna()]
# Out:
#               PMID  Year   MedlineDate                               DOI  \
# 93        93       NaN    1975 Jul-Aug  NaN
# 95        94       NaN    1975 Jul-Aug  NaN
# 97        95       NaN    1975 Jul-Aug  NaN
# 112       111      NaN    1975 Jan-Feb  NaN
# 171       168      NaN    1975 Nov-Dec  10.1097/00003086-197511000-00030
# ...       ...       ..             ...                               ...
# 34960613  36475491 NaN    2022 Nov-Dec  10.31857/S0026898422060027
# 34960616  36475494 NaN    2022 Nov-Dec  10.31857/S0026898422060064
# 34960617  36475495 NaN    2022 Nov-Dec  10.31857/S0026898422060076
# 34960619  36475493 NaN    2022 Nov-Dec  10.31857/S0026898422060179
# 34960621  36475492 NaN    2022 Nov-Dec  10.31857/S0026898422060246
#
#          NlmUniqueID
# 93        0372666
# 95        0372666
# 97        0372666
# 112       7611945
# 171       0075674
# ...           ...
# 34960613  0105454
# 34960616  0105454
# 34960617  0105454
# 34960619  0105454
# 34960621  0105454
#
# [2335794 rows x 5 columns]

# %%
# fixing empty Years with first chars from MedlineDate
df_pubmed.loc[df_pubmed['Year'].isna(), 'Year'] = df_pubmed['MedlineDate'].astype(str).str[0:4]

# %%
# refs with empty year
df_pubmed.loc[df_pubmed['Year'].isna()]
# Out:
# Empty DataFrame
# Columns: [PMID, Year, MedlineDate, DOI, NlmUniqueID]
# Index: []

# %%
# refs by year
df_pubmed['Year'].value_counts()[0:50]
# Out:
# 2022.0    1554222
# 2021.0    1515685
# 2020.0    1353157
# 2019.0    1180575
# 2018.0    1119795
# 2017.0    1070770
# 2016.0    1054072
# 2015.0    1026530
# 2014.0    991457
# 2013.0    946318
# 2012.0    893101
# 2011.0    826889
# 2010.0    773128
# 2009.0    733193
# 2008.0    700232
# 2007.0    660374
# 2006.0    633771
# 2005.0    602491
# 2004.0    570883
# 2003.0    537534
# 2002.0    514549
# 2001.0    499442
# 2000.0    489258
# 1999.0    453242
# 1998.0    436114
# 1996.0    423232
# 1997.0    418667
# 1995.0    413233
# 1994.0    403463
# 1993.0    391136
# 1992.0    383548
# 1991.0    378349
# 1990.0    375225
# 1989.0    368442
# 1988.0    354960
# 1987.0    336517
# 1986.0    319122
# 1985.0    304404
# 1984.0    288876
# 1983.0    282728
# 1982.0    270533
# 1981.0    259926
# 1979.0    258460
# 1980.0    257624
# 1978.0    248722
# 1977.0    238614
# 1976.0    231587
# 1975.0    226576
# 1974.0    215524
# 1973.0    211763
# Name: Year, dtype: int64

# %%
# refs by year
df_pubmed['Year'].value_counts()[50:100]
# Out:
# 1972.0    209243
# 1971.0    204139
# 1970.0    200601
# 1969.0    196590
# 1968.0    188248
# 1967.0    173389
# 1966.0    161712
# 1965.0    157090
# 1964.0    144106
# 1963.0    126098
# 1962.0    111837
# 1961.0    107461
# 1960.0    100485
# 1959.0    98246
# 1953.0    97781
# 1957.0    97578
# 1958.0    97520
# 1952.0    96930
# 1955.0    95809
# 1954.0    94317
# 1956.0    93482
# 1951.0    92647
# 1950.0    76394
# 1948.0    65560
# 2015      62811
# 2016      60870
# 1947.0    60090
# 1949.0    57895
# 2017      55176
# 2005      54301
# 2018      52835
# 2014      52819
# 2021      51834
# 2009      51678
# 2006      51664
# 2008      51464
# 2020      51038
# 2007      50525
# 2013      50456
# 1946.0    50431
# 2010      50352
# 2004      49686
# 2011      49574
# 2012      48187
# 2019      47923
# 2003      46987
# 2002      44559
# 2001      44374
# 2000      41265
# 2022      40769
# Name: Year, dtype: int64

# %%
# refs by year
df_pubmed['Year'].value_counts()[100:150]
# Out:
# 1999      40541
# 1998      38553
# 1997      38109
# 1995      35880
# 1993      35586
# 1990      35389
# 1996      35338
# 1991      34825
# 1994      34775
# 1992      34449
# 1989      34330
# 1988      32060
# 1987      31467
# 1985      30945
# 1986      30598
# 1984      29365
# 1983      26791
# 1982      25229
# 1978      23845
# 1981      23696
# 1979      23657
# 1977      23574
# 1976      23386
# 1980      22979
# 1975      22612
# 1968      19907
# 1965      19647
# 1974      19584
# 1971      19517
# 1973      19363
# 1970      18823
# 1969      18756
# 1967      18685
# 1972      18680
# 1945.0    18677
# 1966      18472
# 1964      18004
# 1963      15441
# 2023.0    14179
# 1957      13950
# 1962      13856
# 1956      13533
# 1955      12753
# 1961      12719
# 1958      11947
# 1959      11754
# 1960      11737
# 1954      11625
# 1952      11252
# 1951      11174
# Name: Year, dtype: int64

# %%
# refs by year
df_pubmed['Year'].value_counts()[150:200]
# Out:
# 1953      11143
# 1950      9398
# 1927.0    5978
# 1938.0    5874
# 1929.0    5793
# 1935.0    5763
# 1930.0    5733
# 1933.0    5703
# 1939.0    5661
# 1932.0    5654
# 1931.0    5608
# 1934.0    5607
# 1928.0    5564
# 1936.0    5496
# 1937.0    5428
# 1926.0    5427
# 1948      5197
# 1914.0    5191
# 1913.0    5183
# 1920.0    5130
# 1925.0    5080
# 1940.0    5073
# 1911.0    4990
# 1924.0    4989
# 1947      4960
# 1949      4931
# 1941.0    4918
# 1912.0    4896
# 1942.0    4843
# 1910.0    4814
# 1921.0    4776
# 1909.0    4662
# 1915.0    4660
# 1944.0    4579
# 1923.0    4554
# 1919.0    4539
# 1943.0    4526
# 1916.0    4470
# 1908.0    4438
# 1897.0    4386
# 1898.0    4306
# 1922.0    4232
# 1907.0    4224
# 1917.0    4223
# 1918.0    4176
# 1896.0    4167
# 1904.0    3893
# 1905.0    3883
# 1893.0    3855
# 1895.0    3806
# Name: Year, dtype: int64

# %%
# refs by year
df_pubmed['Year'].value_counts()[200:250]
# Out:
# 1899.0    3784
# 1903.0    3719
# 1906.0    3707
# 1902.0    3686
# 1901.0    3661
# 1900.0    3621
# 1889.0    3567
# 1892.0    3551
# 1946      3500
# 1894.0    3477
# 1890.0    3345
# 1887.0    3221
# 1888.0    3131
# 1891.0    2959
# 1886.0    2641
# 1885.0    2576
# 1883.0    2411
# 1884.0    2406
# 1881.0    2238
# 1880.0    1941
# 1878.0    1904
# 1874.0    1889
# 1873.0    1842
# 1882.0    1839
# 1879.0    1837
# 1945      1836
# 1872.0    1829
# 1877.0    1805
# 1875.0    1741
# 1876.0    1677
# 1871.0    1577
# 1869.0    1336
# 1867.0    1304
# 1868.0    1246
# 1870.0    1229
# 1858.0    1185
# 1856.0    1168
# 1857.0    1132
# 1866.0    1107
# 1859.0    1060
# 1860.0    1020
# 1855.0    997
# 1842.0    972
# 1853.0    918
# Fall      867
# 1848.0    827
# 1843.0    813
# 1841.0    805
# 1851.0    782
# 1861.0    780
# Name: Year, dtype: int64

# %%
# refs by year
df_pubmed['Year'].value_counts()[250:300]
# Out:
# 1852.0    779
# 1847.0    777
# Wint      776
# 1849.0    760
# 1850.0    758
# 1846.0    750
# Spri      728
# 1854.0    692
# 1845.0    684
# 1864.0    680
# 1862.0    658
# Summ      625
# 1844.0    609
# 1865.0    576
# 1829.0    568
# 1863.0    546
# 1830.0    510
# 2023      482
# 1828.0    409
# 1831.0    403
# 1800.0    387
# 1826.0    385
# 1801.0    368
# 1840.0    361
# 1827.0    327
# 1811.0    322
# 1816.0    315
# 1805.0    314
# 1804.0    304
# 1799.0    300
# 1807.0    295
# 1823.0    291
# 1802.0    291
# 1808.0    289
# 1817.0    288
# 1814.0    285
# 1832.0    285
# 1806.0    282
# 1837.0    281
# 1818.0    279
# 1821.0    270
# 1803.0    269
# 1824.0    269
# 1810.0    267
# 1809.0    265
# 1813.0    265
# 1838.0    265
# 1825.0    262
# 1839.0    253
# 1822.0    247
# Name: Year, dtype: int64

# %%
# refs by year
df_pubmed['Year'].value_counts()[300:350]
# Out:
# 1812.0    239
# 1819.0    225
# 1835.0    222
# 1815.0    222
# 1833.0    221
# 1836.0    220
# 1820.0    213
# 1944      212
# 1834.0    209
# 1831      176
# 1797.0    69
# 1781.0    69
# 1786.0    60
# 1868      58
# Autu      55
# 1865      48
# 1790.0    45
# 1785.0    43
# 1787.0    43
# 1871      43
# 1929      38
# 1839      36
# 1943      35
# 1840      34
# 1788.0    33
# 1792.0    33
# 1789.0    32
# 1922      32
# 1784      31
# 1783      26
# 1923      25
# 1841      24
# 1860      24
# 1782      22
# 1873      21
# 1933      21
# 1796.0    20
# 1876      20
# 1791.0    19
# 1798.0    19
# 1794.0    18
# 1932      17
# 1793.0    17
# 1928      15
# 1795.0    13
# 1925      13
# 1935      6
# 1918      5
# 1924      3
# spri      2
# Name: Year, dtype: int64

# %%
# refs by year
df_pubmed['Year'].value_counts()[350:400]
# Out:
# 1927    2
# summ    1
# fall    1
# Name: Year, dtype: int64

# %%
# fix some errors
# Fall      867
# Wint      776
# Spri      728
# Summ      625
# Autu      55
# spri      2
# fall    1
# summ    1
df_pubmed.loc[(df_pubmed['Year'] == 'Fall') | (df_pubmed['Year'] == 'Wint') | (df_pubmed['Year'] == 'Spri') | (df_pubmed['Year'] == 'Summ') | (df_pubmed['Year'] == 'Autu') | (df_pubmed['Year'] == 'spri') | (df_pubmed['Year'] == 'fall') | (df_pubmed['Year'] == 'summ')]
# Out:
#               PMID  Year  MedlineDate                 DOI NlmUniqueID
# 19705876  20376331  Wint  Winter 2006  NaN                 0323553
# 19792267  20467646  Summ  Summer 2008  NaN                 101473719
# 19792269  20467647  Summ  Summer 2008  NaN                 101473719
# 19792272  20467648  Summ  Summer 2008  NaN                 101473719
# 19792274  20467649  Summ  Summer 2008  NaN                 101473719
# ...            ...   ...          ...  ...                       ...
# 33780115  35278311  Spri  Spring 2022  10.55460/WUMM-Y4N3  101158402
# 33780116  35278312  Spri  Spring 2022  10.55460/ETZI-SI9T  101158402
# 33780118  35278313  Spri  Spring 2022  10.55460/8IUQ-907J  101158402
# 33780134  35278329  Spri  Spring 2022  10.55460/WXGA-QYX2  101158402
# 33780135  35278331  Spri  Spring 2022  10.55460/SOZV-TQN9  101158402
#
# [3055 rows x 5 columns]

# %%
# fix Year taking the end of string
df_pubmed.loc[(df_pubmed['Year'] == 'Fall') | (df_pubmed['Year'] == 'Wint') | (df_pubmed['Year'] == 'Spri') | (df_pubmed['Year'] == 'Summ') | (df_pubmed['Year'] == 'Autu') | (df_pubmed['Year'] == 'spri') | (df_pubmed['Year'] == 'fall') | (df_pubmed['Year'] == 'summ'), 'Year'] = df_pubmed['MedlineDate'].astype(str).str[-4:]

# %%
# test
df_pubmed['Year'].value_counts()[300:350]
# Out:
# 1833.0    221
# 1836.0    220
# 1820.0    213
# 1944      212
# 1834.0    209
# 1831      176
# 1797.0    69
# 1781.0    69
# 1786.0    60
# 1868      58
# 1865      48
# 1790.0    45
# 1787.0    43
# 1785.0    43
# 1871      43
# 1929      38
# 1839      36
# 1943      35
# 1840      34
# 1788.0    33
# 1792.0    33
# 1789.0    32
# 1922      32
# 1784      31
# 1783      26
# 1923      25
# 1860      24
# 1841      24
# 1782      22
# 1933      21
# 1873      21
# 1876      20
# 1796.0    20
# 1798.0    19
# 1791.0    19
# 1794.0    18
# 1793.0    17
# 1932      17
# 1928      15
# 1925      13
# 1795.0    13
# 1935      6
# 1918      5
# 1924      3
# 1927      2
# Name: Year, dtype: int64

# %%
# convert Year to int
df_pubmed.loc[df_pubmed['Year'].notna(), 'Year'] = df_pubmed['Year'].astype(int)
df_pubmed
# Out:
#               PMID  Year MedlineDate                           DOI NlmUniqueID
# 0         1         1975  NaN         10.1016/0006-2944(75)90147-7  0151424
# 1         2         1975  NaN         10.1016/0006-291x(75)90482-9  0372516
# 2         4         1975  NaN         10.1016/0006-291x(75)90506-9  0372516
# 3         3         1975  NaN         10.1016/0006-291x(75)90498-2  0372516
# 4         5         1975  NaN         10.1016/0006-291x(75)90508-2  0372516
# ...      ..          ...  ...                                  ...      ...
# 34960695  36475580  2022  NaN         10.1021/acsami.2c16255        101504991
# 34960696  36475581  2022  NaN         10.1021/acsami.2c17703        101504991
# 34960697  36475582  2022  NaN         10.1021/acsami.2c16205        101504991
# 34960698  36475583  2022  NaN         10.1021/acsami.2c17147        101504991
# 34960699  36475584  2022  NaN         10.1021/acsabm.2c00725        101729147
#
# [34960700 rows x 5 columns]

# %%
# remove MedlineDate
del df_pubmed['MedlineDate']
df_pubmed
# Out:
#               PMID  Year                           DOI NlmUniqueID
# 0         1         1975  10.1016/0006-2944(75)90147-7  0151424
# 1         2         1975  10.1016/0006-291x(75)90482-9  0372516
# 2         4         1975  10.1016/0006-291x(75)90506-9  0372516
# 3         3         1975  10.1016/0006-291x(75)90498-2  0372516
# 4         5         1975  10.1016/0006-291x(75)90508-2  0372516
# ...      ..          ...                           ...      ...
# 34960695  36475580  2022  10.1021/acsami.2c16255        101504991
# 34960696  36475581  2022  10.1021/acsami.2c17703        101504991
# 34960697  36475582  2022  10.1021/acsami.2c16205        101504991
# 34960698  36475583  2022  10.1021/acsami.2c17147        101504991
# 34960699  36475584  2022  10.1021/acsabm.2c00725        101729147
#
# [34960700 rows x 4 columns]

# %%
# test NAs
df_pubmed.loc[df_pubmed['DOI'].isna()]
# Out:
#               PMID  Year  DOI NlmUniqueID
# 9         10        1975  NaN  0101032
# 20        21        1975  NaN  0372660
# 21        22        1975  NaN  0372660
# 22        23        1975  NaN  0372660
# 23        24        1975  NaN  0372660
# ...       ..         ...  ...      ...
# 34960153  36475032  2022  NaN  101528042
# 34960154  36475034  2022  NaN  101528042
# 34960157  36475035  2022  NaN  101528042
# 34960159  36475036  2022  NaN  101528042
# 34960210  36475090  2022  NaN  8403840
#
# [8825380 rows x 4 columns]

# %%
# simplification of DOI to 0/1 to reduce size
df_pubmed.loc[df_pubmed['DOI'].notna(), 'DOI2'] = 1
df_pubmed.loc[df_pubmed['DOI'].isna(), 'DOI2'] = 0
df_pubmed
# Out:
#               PMID  Year                           DOI NlmUniqueID  DOI2
# 0         1         1975  10.1016/0006-2944(75)90147-7  0151424     1.0
# 1         2         1975  10.1016/0006-291x(75)90482-9  0372516     1.0
# 2         4         1975  10.1016/0006-291x(75)90506-9  0372516     1.0
# 3         3         1975  10.1016/0006-291x(75)90498-2  0372516     1.0
# 4         5         1975  10.1016/0006-291x(75)90508-2  0372516     1.0
# ...      ..          ...                           ...      ...     ...
# 34960695  36475580  2022  10.1021/acsami.2c16255        101504991   1.0
# 34960696  36475581  2022  10.1021/acsami.2c17703        101504991   1.0
# 34960697  36475582  2022  10.1021/acsami.2c16205        101504991   1.0
# 34960698  36475583  2022  10.1021/acsami.2c17147        101504991   1.0
# 34960699  36475584  2022  10.1021/acsabm.2c00725        101729147   1.0
#
# [34960700 rows x 5 columns]

# %%
# test NAs
df_pubmed.loc[df_pubmed['DOI2'] == 0]
# Out:
#               PMID  Year  DOI NlmUniqueID  DOI2
# 9         10        1975  NaN  0101032     0.0
# 20        21        1975  NaN  0372660     0.0
# 21        22        1975  NaN  0372660     0.0
# 22        23        1975  NaN  0372660     0.0
# 23        24        1975  NaN  0372660     0.0
# ...       ..         ...  ...      ...     ...
# 34960153  36475032  2022  NaN  101528042   0.0
# 34960154  36475034  2022  NaN  101528042   0.0
# 34960157  36475035  2022  NaN  101528042   0.0
# 34960159  36475036  2022  NaN  101528042   0.0
# 34960210  36475090  2022  NaN  8403840     0.0
#
# [8825380 rows x 5 columns]

# %%
del df_pubmed['DOI']
df_pubmed = df_pubmed.rename(columns={'DOI2' : 'DOI'})
df_pubmed
# Out:
#               PMID  Year NlmUniqueID  DOI
# 0         1         1975  0151424     1.0
# 1         2         1975  0372516     1.0
# 2         4         1975  0372516     1.0
# 3         3         1975  0372516     1.0
# 4         5         1975  0372516     1.0
# ...      ..          ...      ...     ...
# 34960695  36475580  2022  101504991   1.0
# 34960696  36475581  2022  101504991   1.0
# 34960697  36475582  2022  101504991   1.0
# 34960698  36475583  2022  101504991   1.0
# 34960699  36475584  2022  101729147   1.0
#
# [34960700 rows x 4 columns]

# %%
# csv export
df_pubmed.to_csv('data/temp/2023/pubmed_simplified.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# ## MEDLINE Journals enriched

# %%
import pandas as pd
# display the full content of rows (non truncated)
pd.set_option('display.max_colwidth', -1)
# display all the columns
pd.set_option('display.max_columns', None)

# %%
# Open MEDLINE journals data merged with Sherpa/Romeo, DOAJ and reveres flipped data
df_journals = pd.read_csv('results/2023/MedlineJournals.tsv', delimiter='\t', header=0)
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 5274  yes
# 5275  NaN
# 5276  NaN
# 5277  NaN
# 5278  NaN
#
# [5279 rows x 68 columns]

# %%
# Open Pubmed data
df_pubmed = pd.read_csv('data/temp/2023/pubmed_simplified.tsv', delimiter='\t', header=0)
df_pubmed
# Out:
#               PMID  Year NlmUniqueID  DOI
# 0         1         1975  0151424     1.0
# 1         2         1975  0372516     1.0
# 2         4         1975  0372516     1.0
# 3         3         1975  0372516     1.0
# 4         5         1975  0372516     1.0
# ...      ..          ...      ...     ...
# 34960695  36475580  2022  101504991   1.0
# 34960696  36475581  2022  101504991   1.0
# 34960697  36475582  2022  101504991   1.0
# 34960698  36475583  2022  101504991   1.0
# 34960699  36475584  2022  101729147   1.0
#
# [34960700 rows x 4 columns]

# %%
# test DOIs
df_pubmed.loc[df_pubmed['DOI'] == 0]
# Out:
#               PMID  Year NlmUniqueID  DOI
# 9         10        1975  0101032     0.0
# 20        21        1975  0372660     0.0
# 21        22        1975  0372660     0.0
# 22        23        1975  0372660     0.0
# 23        24        1975  0372660     0.0
# ...       ..         ...      ...     ...
# 34960153  36475032  2022  101528042   0.0
# 34960154  36475034  2022  101528042   0.0
# 34960157  36475035  2022  101528042   0.0
# 34960159  36475036  2022  101528042   0.0
# 34960210  36475090  2022  8403840     0.0
#
# [8825380 rows x 4 columns]

# %%
# test DOIs
df_pubmed.loc[df_pubmed['DOI'].isna()]
# Out:
# Empty DataFrame
# Columns: [PMID, Year, NlmUniqueID, DOI]
# Index: []

# %%
# Open MEDLINE journals unconquerables
df_unconquerables = pd.read_csv('results/2023/MedlineJournals_not_sherpa_and_not_doaj_or_not_oa.tsv', delimiter='\t', header=0)
df_unconquerables
# Out:
#     NlmUniqueID  \
# 0    101714112
# 1    101269322
# 2    0431420
# 3    101206716
# 4    101194794
# ..         ...
# 778  9425197
# 779  7511141
# 780  7904962
# 781  7910681
# 782  8702287
#
#                                                                                                            Title  \
# 0    A&A practice
# 1    AACN advanced critical care
# 2    AANA journal
# 3    Acta biochimica et biophysica Sinica
# 4    Acta of bioengineering and biomechanics
# ..                                       ...
# 778  Zhonghua yi xue yi chuan xue za zhi = Zhonghua yixue yichuanxue zazhi = Chinese journal of medical genetics
# 779  Zhonghua yi xue za zhi
# 780  Zhonghua yu fang yi xue za zhi [Chinese journal of preventive medicine]
# 781  Zhonghua zhong liu za zhi [Chinese journal of oncology]
# 782  Zoological science
#
#                                MedlineTA        Country  \
# 0    A A Pract                            United States
# 1    AACN Adv Crit Care                   United States
# 2    AANA J                               United States
# 3    Acta Biochim Biophys Sin (Shanghai)  China
# 4    Acta Bioeng Biomech                  Poland
# ..                   ...                     ...
# 778  Zhonghua Yi Xue Yi Chuan Xue Za Zhi  China
# 779  Zhonghua Yi Xue Za Zhi               China
# 780  Zhonghua Yu Fang Yi Xue Za Zhi       China
# 781  Zhonghua Zhong Liu Za Zhi            China
# 782  Zoolog Sci                           Japan
#
#                             Place  \
# 0    [Philadelphia, PA]
# 1    Aliso Viejo, CA
# 2    Park Ridge, Ill.
# 3    Shanghai
# 4    Wrocław
# ..       ...
# 778  Chengdu, Sichuan, P.R. China
# 779  Beijing
# 780  Beijing
# 781  Peking
# 782  Tokyo, Japan
#
#                                                Publisher PublicationFirstYear  \
# 0    Wolters Kluwer Health, Inc.                          2018
# 1    American Association of Critical-Care Nurses (AACN)  2006
# 2    American Association of Nurse Anesthetists           1974
# 3    China Science Publishing & Media Ltd.                2004
# 4    Oficyna Wydawnicza Politechniki Wrocławskiej         1999
# ..                                            ...          ...
# 778  Sichuan University                                   1992
# 779  Zhonghua yi xue hui                                  1960
# 780  Zhonghua yi xue hui                                  1967
# 781  Chinese Medical Association                          1979
# 782  Zoological Society of Japan                          1984
#
#      PublicationEndYear     Frequency ISSN-Electronic ISSN-Print ISSN-Linking  \
# 0   NaN                  Biweekly      2575-3126       NaN        2575-3126
# 1   NaN                  Quarterly     1559-7776       1559-7768  1559-7768
# 2   NaN                  Bimonthly     2162-5239       0094-6354  0094-6354
# 3   NaN                  Monthly       1745-7270       1672-9145  1672-9145
# 4   NaN                  Irregular     NaN             1509-409X  1509-409X
# ..   ..                        ...     ...                   ...        ...
# 778 NaN                  Bimonthly     NaN             1003-9406  1003-9406
# 779 NaN                  Semimonthly,  NaN             0376-2491  0376-2491
# 780 NaN                  Bimonthly     NaN             0253-9624  0253-9624
# 781 NaN                  Bimonthly     NaN             0253-3766  0253-3766
# 782 NaN                  Monthly,      NaN             0289-0003  0289-0003
#
#     Language TitleContinuationYN  IndexingStartDate CurrentlyIndexedYN  \
# 0    eng      Y                   2018.0             Y
# 1    eng      Y                   2006.0             Y
# 2    eng      N                   1974.0             Y
# 3    eng      Y                   2004.0             Y
# 4    eng      N                   2007.0             Y
# ..   ...     ..                      ...            ..
# 778  chi      N                   1998.0             Y
# 779  chi      N                   1973.0             Y
# 780  chi      N                   1979.0             Y
# 781  chi      N                   1979.0             Y
# 782  eng      N                   2002.0             Y
#
#     IndexOnlineYN IndexingSubset  \
# 0    Y             IM
# 1    Y             N
# 2    Y             N
# 3    Y             IM
# 4    Y             IM
# ..  ..             ..
# 778  N             IM
# 779  N             IM
# 780  N             IM
# 781  N             IM
# 782  Y             IM
#
#                                                                                 IndexingSelectedURL  \
# 0    https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 1    https://aacnjournals.org/aacnacconline
# 2    https://www.aana.com/publications/aana-journal
# 3    https://academic.oup.com/abbs
# 4    http://www.actabio.pwr.wroc.pl/archive.php
# ..                                          ...
# 778  NaN
# 779  NaN
# 780  NaN
# 781  NaN
# 782  http://www.bioone.org/loi/jzoo
#
#     ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0    Y                 2575-3126  NaN               NaN
# 1    Y                 1559-7776  yes               NaN
# 2    Y                 2162-5239  NaN               NaN
# 3    Y                 1745-7270  NaN               NaN
# 4    Y                 1509-409X  NaN               NaN
# ..  ..                       ...  ...                ..
# 778  Y                 1003-9406  NaN               NaN
# 779  Y                 0376-2491  NaN               NaN
# 780  Y                 0253-9624  NaN               NaN
# 781  Y                 0253-3766  NaN               NaN
# 782  Y                 0289-0003  NaN               NaN
#
#      embargo_published_version  embargo_accepted_version  sherpa_oa_green  \
# 0   NaN                        NaN                       NaN
# 1   NaN                        NaN                       NaN
# 2   NaN                        NaN                       NaN
# 3   NaN                        NaN                       NaN
# 4   NaN                        NaN                       NaN
# ..   ..                         ..                        ..
# 778 NaN                        NaN                       NaN
# 779 NaN                        NaN                       NaN
# 780 NaN                        NaN                       NaN
# 781 NaN                        NaN                       NaN
# 782 NaN                        NaN                       NaN
#
#      additional_oa_fee                 title_sherpa issne_sherpa issnp_sherpa  \
# 0   NaN                 NaN                          NaN          NaN
# 1   NaN                 AACN Advanced Critical Care  1559-7776    1559-7768
# 2   NaN                 NaN                          NaN          NaN
# 3   NaN                 NaN                          NaN          NaN
# 4   NaN                 NaN                          NaN          NaN
# ..   ..                 ...                          ...          ...
# 778 NaN                 NaN                          NaN          NaN
# 779 NaN                 NaN                          NaN          NaN
# 780 NaN                 NaN                          NaN          NaN
# 781 NaN                 NaN                          NaN          NaN
# 782 NaN                 NaN                          NaN          NaN
#
#                               url  publisher_id publisher_country  \
# 0    NaN                          NaN            NaN
# 1    http://acc.aacnjournals.org/  663.0         us
# 2    NaN                          NaN            NaN
# 3    NaN                          NaN            NaN
# 4    NaN                          NaN            NaN
# ..   ...                           ..            ...
# 778  NaN                          NaN            NaN
# 779  NaN                          NaN            NaN
# 780  NaN                          NaN            NaN
# 781  NaN                          NaN            NaN
# 782  NaN                          NaN            NaN
#
#         publisher_type          publisher_url  \
# 0    NaN                NaN
# 1    society_publisher  https://www.aacn.org/
# 2    NaN                NaN
# 3    NaN                NaN
# 4    NaN                NaN
# ..   ...                ...
# 778  NaN                NaN
# 779  NaN                NaN
# 780  NaN                NaN
# 781  NaN                NaN
# 782  NaN                NaN
#
#                                    publisher_name  \
# 0    NaN
# 1    American Association of Critical Care Nurses
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 778  NaN
# 779  NaN
# 780  NaN
# 781  NaN
# 782  NaN
#
#                                           sherpa_uri       sherpa_created  \
# 0    NaN                                              NaN
# 1    https://v2.sherpa.ac.uk/id/publisher_policy/663  2010-08-24 15:05:09
# 2    NaN                                              NaN
# 3    NaN                                              NaN
# 4    NaN                                              NaN
# ..   ...                                              ...
# 778  NaN                                              NaN
# 779  NaN                                              NaN
# 780  NaN                                              NaN
# 781  NaN                                              NaN
# 782  NaN                                              NaN
#
#     sherpa_last_modified  sherpa_id  DOAJ_pissn  ISSN_old  DOAJ_title  \
# 0    NaN                 NaN        NaN         NaN       NaN
# 1    2022-07-08 08:42:33  10921.0   NaN         NaN       NaN
# 2    NaN                 NaN        NaN         NaN       NaN
# 3    NaN                 NaN        NaN         NaN       NaN
# 4    NaN                 NaN        NaN         NaN       NaN
# ..   ...                  ..         ..          ..        ..
# 778  NaN                 NaN        NaN         NaN       NaN
# 779  NaN                 NaN        NaN         NaN       NaN
# 780  NaN                 NaN        NaN         NaN       NaN
# 781  NaN                 NaN        NaN         NaN       NaN
# 782  NaN                 NaN        NaN         NaN       NaN
#
#      DOAJ_eissn  DOAJ_Seal  DOAJ_date  DOAJ_year  DOAJ_license  \
# 0   NaN         NaN        NaN        NaN        NaN
# 1   NaN         NaN        NaN        NaN        NaN
# 2   NaN         NaN        NaN        NaN        NaN
# 3   NaN         NaN        NaN        NaN        NaN
# 4   NaN         NaN        NaN        NaN        NaN
# ..   ..          ..         ..         ..         ..
# 778 NaN         NaN        NaN        NaN        NaN
# 779 NaN         NaN        NaN        NaN        NaN
# 780 NaN         NaN        NaN        NaN        NaN
# 781 NaN         NaN        NaN        NaN        NaN
# 782 NaN         NaN        NaN        NaN        NaN
#
#      DOAJ_author_holds_copyright_without_restrictions  DOAJ_last_updated  \
# 0   NaN                                               NaN
# 1   NaN                                               NaN
# 2   NaN                                               NaN
# 3   NaN                                               NaN
# 4   NaN                                               NaN
# ..   ..                                                ..
# 778 NaN                                               NaN
# 779 NaN                                               NaN
# 780 NaN                                               NaN
# 781 NaN                                               NaN
# 782 NaN                                               NaN
#
#      DOAJ_APC  DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0   NaN       NaN   NaN           NaN                    NaN
# 1   NaN       NaN   NaN           NaN                    NaN
# 2   NaN       NaN   NaN           NaN                    NaN
# 3   NaN       NaN   NaN           NaN                    NaN
# 4   NaN       NaN   NaN           NaN                    NaN
# ..   ..        ..    ..            ..                    ...
# 778 NaN       NaN   NaN           NaN                    NaN
# 779 NaN       NaN   NaN           NaN                    NaN
# 780 NaN       NaN   NaN           NaN                    NaN
# 781 NaN       NaN   NaN           NaN                    NaN
# 782 NaN       NaN    1984.0        2005.0                Japan
#
#              society_affiliation  other_sci_affiliation flipped_journal_name  \
# 0    NaN                         NaN                     NaN
# 1    NaN                         NaN                     NaN
# 2    NaN                         NaN                     NaN
# 3    NaN                         NaN                     NaN
# 4    NaN                         NaN                     NaN
# ..   ...                          ..                     ...
# 778  NaN                         NaN                     NaN
# 779  NaN                         NaN                     NaN
# 780  NaN                         NaN                     NaN
# 781  NaN                         NaN                     NaN
# 782  Zoological Society of Japan  0.0                    Zoological Science
#
#              post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0    NaN                          NaN                 NaN       NaN
# 1    NaN                          NaN                 NaN       NaN
# 2    NaN                          NaN                 NaN       NaN
# 3    NaN                          NaN                 NaN       NaN
# 4    NaN                          NaN                 NaN       NaN
# ..   ...                          ...                  ..       ...
# 778  NaN                          NaN                 NaN       NaN
# 779  NaN                          NaN                 NaN       NaN
# 780  NaN                          NaN                 NaN       NaN
# 781  NaN                          NaN                 NaN       NaN
# 782  Zoological Society of Japan  Subscription        NaN       -
#
#     apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0    NaN     NaN       NaN         NaN              NaN
# 1    NaN     NaN       NaN         NaN              NaN
# 2    NaN     NaN       NaN         NaN              NaN
# 3    NaN     NaN       NaN         NaN              NaN
# 4    NaN     NaN       NaN         NaN              NaN
# ..   ...     ...        ..          ..               ..
# 778  NaN     NaN       NaN         NaN              NaN
# 779  NaN     NaN       NaN         NaN              NaN
# 780  NaN     NaN       NaN         NaN              NaN
# 781  NaN     NaN       NaN         NaN              NaN
# 782  -       LS         1.0         0.0             NaN
#
#     Reverse_Flip not_sherpa_and_not_doaj_or_not_oa
# 0    NaN          yes
# 1    NaN          yes
# 2    NaN          yes
# 3    NaN          yes
# 4    NaN          yes
# ..   ...          ...
# 778  NaN          yes
# 779  NaN          yes
# 780  NaN          yes
# 781  NaN          yes
# 782  yes          yes
#
# [783 rows x 69 columns]

# %%
df_unconquerables.loc[df_unconquerables['NlmUniqueID'].notna(), 'unconquerables'] = 1
df_unconquerables
# Out:
#     NlmUniqueID  \
# 0    101714112
# 1    101269322
# 2    0431420
# 3    101206716
# 4    101194794
# ..         ...
# 778  9425197
# 779  7511141
# 780  7904962
# 781  7910681
# 782  8702287
#
#                                                                                                            Title  \
# 0    A&A practice
# 1    AACN advanced critical care
# 2    AANA journal
# 3    Acta biochimica et biophysica Sinica
# 4    Acta of bioengineering and biomechanics
# ..                                       ...
# 778  Zhonghua yi xue yi chuan xue za zhi = Zhonghua yixue yichuanxue zazhi = Chinese journal of medical genetics
# 779  Zhonghua yi xue za zhi
# 780  Zhonghua yu fang yi xue za zhi [Chinese journal of preventive medicine]
# 781  Zhonghua zhong liu za zhi [Chinese journal of oncology]
# 782  Zoological science
#
#                                MedlineTA        Country  \
# 0    A A Pract                            United States
# 1    AACN Adv Crit Care                   United States
# 2    AANA J                               United States
# 3    Acta Biochim Biophys Sin (Shanghai)  China
# 4    Acta Bioeng Biomech                  Poland
# ..                   ...                     ...
# 778  Zhonghua Yi Xue Yi Chuan Xue Za Zhi  China
# 779  Zhonghua Yi Xue Za Zhi               China
# 780  Zhonghua Yu Fang Yi Xue Za Zhi       China
# 781  Zhonghua Zhong Liu Za Zhi            China
# 782  Zoolog Sci                           Japan
#
#                             Place  \
# 0    [Philadelphia, PA]
# 1    Aliso Viejo, CA
# 2    Park Ridge, Ill.
# 3    Shanghai
# 4    Wrocław
# ..       ...
# 778  Chengdu, Sichuan, P.R. China
# 779  Beijing
# 780  Beijing
# 781  Peking
# 782  Tokyo, Japan
#
#                                                Publisher PublicationFirstYear  \
# 0    Wolters Kluwer Health, Inc.                          2018
# 1    American Association of Critical-Care Nurses (AACN)  2006
# 2    American Association of Nurse Anesthetists           1974
# 3    China Science Publishing & Media Ltd.                2004
# 4    Oficyna Wydawnicza Politechniki Wrocławskiej         1999
# ..                                            ...          ...
# 778  Sichuan University                                   1992
# 779  Zhonghua yi xue hui                                  1960
# 780  Zhonghua yi xue hui                                  1967
# 781  Chinese Medical Association                          1979
# 782  Zoological Society of Japan                          1984
#
#      PublicationEndYear     Frequency ISSN-Electronic ISSN-Print ISSN-Linking  \
# 0   NaN                  Biweekly      2575-3126       NaN        2575-3126
# 1   NaN                  Quarterly     1559-7776       1559-7768  1559-7768
# 2   NaN                  Bimonthly     2162-5239       0094-6354  0094-6354
# 3   NaN                  Monthly       1745-7270       1672-9145  1672-9145
# 4   NaN                  Irregular     NaN             1509-409X  1509-409X
# ..   ..                        ...     ...                   ...        ...
# 778 NaN                  Bimonthly     NaN             1003-9406  1003-9406
# 779 NaN                  Semimonthly,  NaN             0376-2491  0376-2491
# 780 NaN                  Bimonthly     NaN             0253-9624  0253-9624
# 781 NaN                  Bimonthly     NaN             0253-3766  0253-3766
# 782 NaN                  Monthly,      NaN             0289-0003  0289-0003
#
#     Language TitleContinuationYN  IndexingStartDate CurrentlyIndexedYN  \
# 0    eng      Y                   2018.0             Y
# 1    eng      Y                   2006.0             Y
# 2    eng      N                   1974.0             Y
# 3    eng      Y                   2004.0             Y
# 4    eng      N                   2007.0             Y
# ..   ...     ..                      ...            ..
# 778  chi      N                   1998.0             Y
# 779  chi      N                   1973.0             Y
# 780  chi      N                   1979.0             Y
# 781  chi      N                   1979.0             Y
# 782  eng      N                   2002.0             Y
#
#     IndexOnlineYN IndexingSubset  \
# 0    Y             IM
# 1    Y             N
# 2    Y             N
# 3    Y             IM
# 4    Y             IM
# ..  ..             ..
# 778  N             IM
# 779  N             IM
# 780  N             IM
# 781  N             IM
# 782  Y             IM
#
#                                                                                 IndexingSelectedURL  \
# 0    https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 1    https://aacnjournals.org/aacnacconline
# 2    https://www.aana.com/publications/aana-journal
# 3    https://academic.oup.com/abbs
# 4    http://www.actabio.pwr.wroc.pl/archive.php
# ..                                          ...
# 778  NaN
# 779  NaN
# 780  NaN
# 781  NaN
# 782  http://www.bioone.org/loi/jzoo
#
#     ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0    Y                 2575-3126  NaN               NaN
# 1    Y                 1559-7776  yes               NaN
# 2    Y                 2162-5239  NaN               NaN
# 3    Y                 1745-7270  NaN               NaN
# 4    Y                 1509-409X  NaN               NaN
# ..  ..                       ...  ...                ..
# 778  Y                 1003-9406  NaN               NaN
# 779  Y                 0376-2491  NaN               NaN
# 780  Y                 0253-9624  NaN               NaN
# 781  Y                 0253-3766  NaN               NaN
# 782  Y                 0289-0003  NaN               NaN
#
#      embargo_published_version  embargo_accepted_version  sherpa_oa_green  \
# 0   NaN                        NaN                       NaN
# 1   NaN                        NaN                       NaN
# 2   NaN                        NaN                       NaN
# 3   NaN                        NaN                       NaN
# 4   NaN                        NaN                       NaN
# ..   ..                         ..                        ..
# 778 NaN                        NaN                       NaN
# 779 NaN                        NaN                       NaN
# 780 NaN                        NaN                       NaN
# 781 NaN                        NaN                       NaN
# 782 NaN                        NaN                       NaN
#
#      additional_oa_fee                 title_sherpa issne_sherpa issnp_sherpa  \
# 0   NaN                 NaN                          NaN          NaN
# 1   NaN                 AACN Advanced Critical Care  1559-7776    1559-7768
# 2   NaN                 NaN                          NaN          NaN
# 3   NaN                 NaN                          NaN          NaN
# 4   NaN                 NaN                          NaN          NaN
# ..   ..                 ...                          ...          ...
# 778 NaN                 NaN                          NaN          NaN
# 779 NaN                 NaN                          NaN          NaN
# 780 NaN                 NaN                          NaN          NaN
# 781 NaN                 NaN                          NaN          NaN
# 782 NaN                 NaN                          NaN          NaN
#
#                               url  publisher_id publisher_country  \
# 0    NaN                          NaN            NaN
# 1    http://acc.aacnjournals.org/  663.0         us
# 2    NaN                          NaN            NaN
# 3    NaN                          NaN            NaN
# 4    NaN                          NaN            NaN
# ..   ...                           ..            ...
# 778  NaN                          NaN            NaN
# 779  NaN                          NaN            NaN
# 780  NaN                          NaN            NaN
# 781  NaN                          NaN            NaN
# 782  NaN                          NaN            NaN
#
#         publisher_type          publisher_url  \
# 0    NaN                NaN
# 1    society_publisher  https://www.aacn.org/
# 2    NaN                NaN
# 3    NaN                NaN
# 4    NaN                NaN
# ..   ...                ...
# 778  NaN                NaN
# 779  NaN                NaN
# 780  NaN                NaN
# 781  NaN                NaN
# 782  NaN                NaN
#
#                                    publisher_name  \
# 0    NaN
# 1    American Association of Critical Care Nurses
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 778  NaN
# 779  NaN
# 780  NaN
# 781  NaN
# 782  NaN
#
#                                           sherpa_uri       sherpa_created  \
# 0    NaN                                              NaN
# 1    https://v2.sherpa.ac.uk/id/publisher_policy/663  2010-08-24 15:05:09
# 2    NaN                                              NaN
# 3    NaN                                              NaN
# 4    NaN                                              NaN
# ..   ...                                              ...
# 778  NaN                                              NaN
# 779  NaN                                              NaN
# 780  NaN                                              NaN
# 781  NaN                                              NaN
# 782  NaN                                              NaN
#
#     sherpa_last_modified  sherpa_id  DOAJ_pissn  ISSN_old  DOAJ_title  \
# 0    NaN                 NaN        NaN         NaN       NaN
# 1    2022-07-08 08:42:33  10921.0   NaN         NaN       NaN
# 2    NaN                 NaN        NaN         NaN       NaN
# 3    NaN                 NaN        NaN         NaN       NaN
# 4    NaN                 NaN        NaN         NaN       NaN
# ..   ...                  ..         ..          ..        ..
# 778  NaN                 NaN        NaN         NaN       NaN
# 779  NaN                 NaN        NaN         NaN       NaN
# 780  NaN                 NaN        NaN         NaN       NaN
# 781  NaN                 NaN        NaN         NaN       NaN
# 782  NaN                 NaN        NaN         NaN       NaN
#
#      DOAJ_eissn  DOAJ_Seal  DOAJ_date  DOAJ_year  DOAJ_license  \
# 0   NaN         NaN        NaN        NaN        NaN
# 1   NaN         NaN        NaN        NaN        NaN
# 2   NaN         NaN        NaN        NaN        NaN
# 3   NaN         NaN        NaN        NaN        NaN
# 4   NaN         NaN        NaN        NaN        NaN
# ..   ..          ..         ..         ..         ..
# 778 NaN         NaN        NaN        NaN        NaN
# 779 NaN         NaN        NaN        NaN        NaN
# 780 NaN         NaN        NaN        NaN        NaN
# 781 NaN         NaN        NaN        NaN        NaN
# 782 NaN         NaN        NaN        NaN        NaN
#
#      DOAJ_author_holds_copyright_without_restrictions  DOAJ_last_updated  \
# 0   NaN                                               NaN
# 1   NaN                                               NaN
# 2   NaN                                               NaN
# 3   NaN                                               NaN
# 4   NaN                                               NaN
# ..   ..                                                ..
# 778 NaN                                               NaN
# 779 NaN                                               NaN
# 780 NaN                                               NaN
# 781 NaN                                               NaN
# 782 NaN                                               NaN
#
#      DOAJ_APC  DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0   NaN       NaN   NaN           NaN                    NaN
# 1   NaN       NaN   NaN           NaN                    NaN
# 2   NaN       NaN   NaN           NaN                    NaN
# 3   NaN       NaN   NaN           NaN                    NaN
# 4   NaN       NaN   NaN           NaN                    NaN
# ..   ..        ..    ..            ..                    ...
# 778 NaN       NaN   NaN           NaN                    NaN
# 779 NaN       NaN   NaN           NaN                    NaN
# 780 NaN       NaN   NaN           NaN                    NaN
# 781 NaN       NaN   NaN           NaN                    NaN
# 782 NaN       NaN    1984.0        2005.0                Japan
#
#              society_affiliation  other_sci_affiliation flipped_journal_name  \
# 0    NaN                         NaN                     NaN
# 1    NaN                         NaN                     NaN
# 2    NaN                         NaN                     NaN
# 3    NaN                         NaN                     NaN
# 4    NaN                         NaN                     NaN
# ..   ...                          ..                     ...
# 778  NaN                         NaN                     NaN
# 779  NaN                         NaN                     NaN
# 780  NaN                         NaN                     NaN
# 781  NaN                         NaN                     NaN
# 782  Zoological Society of Japan  0.0                    Zoological Science
#
#              post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0    NaN                          NaN                 NaN       NaN
# 1    NaN                          NaN                 NaN       NaN
# 2    NaN                          NaN                 NaN       NaN
# 3    NaN                          NaN                 NaN       NaN
# 4    NaN                          NaN                 NaN       NaN
# ..   ...                          ...                  ..       ...
# 778  NaN                          NaN                 NaN       NaN
# 779  NaN                          NaN                 NaN       NaN
# 780  NaN                          NaN                 NaN       NaN
# 781  NaN                          NaN                 NaN       NaN
# 782  Zoological Society of Japan  Subscription        NaN       -
#
#     apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0    NaN     NaN       NaN         NaN              NaN
# 1    NaN     NaN       NaN         NaN              NaN
# 2    NaN     NaN       NaN         NaN              NaN
# 3    NaN     NaN       NaN         NaN              NaN
# 4    NaN     NaN       NaN         NaN              NaN
# ..   ...     ...        ..          ..               ..
# 778  NaN     NaN       NaN         NaN              NaN
# 779  NaN     NaN       NaN         NaN              NaN
# 780  NaN     NaN       NaN         NaN              NaN
# 781  NaN     NaN       NaN         NaN              NaN
# 782  -       LS         1.0         0.0             NaN
#
#     Reverse_Flip not_sherpa_and_not_doaj_or_not_oa  unconquerables
# 0    NaN          yes                               1.0
# 1    NaN          yes                               1.0
# 2    NaN          yes                               1.0
# 3    NaN          yes                               1.0
# 4    NaN          yes                               1.0
# ..   ...          ...                               ...
# 778  NaN          yes                               1.0
# 779  NaN          yes                               1.0
# 780  NaN          yes                               1.0
# 781  NaN          yes                               1.0
# 782  yes          yes                               1.0
#
# [783 rows x 70 columns]

# %%
# test types
df_unconquerables['NlmUniqueID'].dtypes
# Out:
# dtype('O')

# %%
# test empty IDs
df_unconquerables.loc[df_unconquerables['NlmUniqueID'].isna()]
# Out:
# Empty DataFrame
# Columns: [NlmUniqueID, Title, MedlineTA, Country, Place, Publisher, PublicationFirstYear, PublicationEndYear, Frequency, ISSN-Electronic, ISSN-Print, ISSN-Linking, Language, TitleContinuationYN, IndexingStartDate, CurrentlyIndexedYN, IndexOnlineYN, IndexingSubset, IndexingSelectedURL, ReportedMedlineYN, ISSN, sherpa_has_oa_path, embargo, embargo_published_version, embargo_accepted_version, sherpa_oa_green, additional_oa_fee, title_sherpa, issne_sherpa, issnp_sherpa, url, publisher_id, publisher_country, publisher_type, publisher_url, publisher_name, sherpa_uri, sherpa_created, sherpa_last_modified, sherpa_id, DOAJ_pissn, ISSN_old, DOAJ_title, DOAJ_eissn, DOAJ_Seal, DOAJ_date, DOAJ_year, DOAJ_license, DOAJ_author_holds_copyright_without_restrictions, DOAJ_last_updated, DOAJ_APC, DOAJ, year_founded, year_reverse_flipped, journal_location, society_affiliation, other_sci_affiliation, flipped_journal_name, post_flip_publisher, flipped_access_model, apc_pre, apc_post, apc_now, discipline, flipped_oa, flipped_born_oa, flipped_embargo, Reverse_Flip, not_sherpa_and_not_doaj_or_not_oa, unconquerables]
# Index: []

# %%
# convert NlmUniqueID to int
# ERROR: some journals have alpha in NlmUniqueID: 2985165R, etc.
# df_unconquerables.loc[df_unconquerables['NlmUniqueID'].notna(), 'NlmUniqueID'] = df_unconquerables['NlmUniqueID'].astype('int64')

# %%
# convert to str
df_unconquerables.loc[df_unconquerables['NlmUniqueID'].notna(), 'NlmUniqueID'] = df_unconquerables['NlmUniqueID'].astype(str)

# %%
# convert to str
df_journals.loc[df_journals['NlmUniqueID'].notna(), 'NlmUniqueID'] = df_journals['NlmUniqueID'].astype(str)

# %%
# convert to str
df_pubmed.loc[df_pubmed['NlmUniqueID'].notna(), 'NlmUniqueID'] = df_pubmed['NlmUniqueID'].astype(str)

# %%
# merge
df_pubmed = df_pubmed.merge(df_unconquerables[['NlmUniqueID', 'unconquerables']], on='NlmUniqueID', how='left')
df_pubmed
# Out:
#               PMID  Year NlmUniqueID  DOI  unconquerables
# 0         1         1975  0151424     1.0 NaN
# 1         2         1975  0372516     1.0 NaN
# 2         4         1975  0372516     1.0 NaN
# 3         3         1975  0372516     1.0 NaN
# 4         5         1975  0372516     1.0 NaN
# ...      ..          ...      ...     ...  ..
# 34960695  36475580  2022  101504991   1.0 NaN
# 34960696  36475581  2022  101504991   1.0 NaN
# 34960697  36475582  2022  101504991   1.0 NaN
# 34960698  36475583  2022  101504991   1.0 NaN
# 34960699  36475584  2022  101729147   1.0 NaN
#
# [34960700 rows x 5 columns]

# %%
# test unconquerables
df_pubmed.loc[df_pubmed['unconquerables'] == 1]
# Out:
#               PMID  Year NlmUniqueID  DOI  unconquerables
# 109       110       1975  7507032     0.0  1.0
# 145       146       1975  0004743     0.0  1.0
# 166       167       1975  0364441     0.0  1.0
# 276       277       1975  0374617     0.0  1.0
# 277       278       1975  0420550     0.0  1.0
# ...       ...        ...      ...     ...  ...
# 34960666  36475547  2022  101776555   1.0  1.0
# 34960667  36475548  2022  101776555   1.0  1.0
# 34960675  36475556  2022  101777295   1.0  1.0
# 34960676  36475557  2022  8904033     1.0  1.0
# 34960679  36475560  2022  8904033     1.0  1.0
#
# [2597738 rows x 5 columns]

# %%
df_unconquerables_years = df_unconquerables[['PublicationFirstYear', 'unconquerables']].groupby(by='PublicationFirstYear').count()

# %%
df_unconquerables_years.sort_values(by='PublicationFirstYear', ascending=False)
# Out:
#                       unconquerables
# PublicationFirstYear
# 20uu                  1
# 2023                  2
# 2022                  15
# 2021                  17
# 2020                  7
# ...                   ..
# 1872                  1
# 1862                  1
# 1859                  1
# 1845                  1
# 1839                  1
#
# [117 rows x 1 columns]

# %%
# attribution of 0 to other journals
df_pubmed.loc[df_pubmed['unconquerables'].isna(), 'unconquerables'] = 0
df_pubmed
# Out:
#               PMID  Year NlmUniqueID  DOI  unconquerables
# 0         1         1975  0151424     1.0  0.0
# 1         2         1975  0372516     1.0  0.0
# 2         4         1975  0372516     1.0  0.0
# 3         3         1975  0372516     1.0  0.0
# 4         5         1975  0372516     1.0  0.0
# ...      ..          ...      ...     ...  ...
# 34960695  36475580  2022  101504991   1.0  0.0
# 34960696  36475581  2022  101504991   1.0  0.0
# 34960697  36475582  2022  101504991   1.0  0.0
# 34960698  36475583  2022  101504991   1.0  0.0
# 34960699  36475584  2022  101729147   1.0  0.0
#
# [34960700 rows x 5 columns]

# %%
# export counts by year
counts_pubmed_by_year = df_pubmed['Year'].value_counts().rename_axis('Year').reset_index(name='counts')
df_pubmed_by_year = pd.DataFrame(counts_pubmed_by_year, columns=['Year', 'counts'])
df_pubmed_by_year.sort_values(by='Year', ascending=False).to_csv('results/2023/pubmed_counts_by_year.tsv', header=True, sep='\t', index=False)
df_pubmed_by_year
# Out:
#      Year   counts
# 0    2022  1595029
# 1    2021  1567593
# 2    2020  1404250
# 3    2019  1228698
# 4    2018  1173512
# ..    ...      ...
# 238  1798  19
# 239  1791  19
# 240  1794  18
# 241  1793  17
# 242  1795  13
#
# [243 rows x 2 columns]

# %%
# export counts by year for unconquerables
counts_pubmed_unconquerables_by_year = df_pubmed.loc[df_pubmed['unconquerables'] == 1]['Year'].value_counts().rename_axis('Year').reset_index(name='unconquerables_counts')
df_pubmed_unconquerables_by_year = pd.DataFrame(counts_pubmed_unconquerables_by_year, columns=['Year', 'unconquerables_counts'])
# df_pubmed_unconquerables_by_year.sort_values(by='Year', ascending=False).to_csv('results/2023/pubmed_unconquerables_counts_by_year.csv', header=True, sep='\t', index=False)
df_pubmed_unconquerables_by_year
# Out:
#     Year  unconquerables_counts
# 0   2021  90125
# 1   2020  86827
# 2   2019  84499
# 3   2018  84469
# 4   2022  84017
# ..   ...    ...
# 91  1932  45
# 92  1931  34
# 93  1929  32
# 94  1930  31
# 95  1928  7
#
# [96 rows x 2 columns]

# %%
# merge
df_pubmed_by_year = df_pubmed_by_year.merge(df_pubmed_unconquerables_by_year, on='Year', how='left')
df_pubmed_by_year
# Out:
#      Year   counts  unconquerables_counts
# 0    2022  1595029  84017.0
# 1    2021  1567593  90125.0
# 2    2020  1404250  86827.0
# 3    2019  1228698  84499.0
# 4    2018  1173512  84469.0
# ..    ...      ...      ...
# 238  1798  19      NaN
# 239  1791  19      NaN
# 240  1794  18      NaN
# 241  1793  17      NaN
# 242  1795  13      NaN
#
# [243 rows x 3 columns]

# %%
# replace NaN by 0
df_pubmed_by_year.loc[df_pubmed_by_year['unconquerables_counts'].isna(), 'unconquerables_counts'] = 0
df_pubmed_by_year.loc[df_pubmed_by_year['unconquerables_counts'].notna(), 'unconquerables_counts'] = df_pubmed_by_year['unconquerables_counts'].astype(int)

# %%
# add ratios
df_pubmed_by_year['ratio'] = df_pubmed_by_year['unconquerables_counts'] / df_pubmed_by_year['counts']
df_pubmed_by_year
# Out:
#      Year   counts  unconquerables_counts     ratio
# 0    2022  1595029  84017                  0.052674
# 1    2021  1567593  90125                  0.057493
# 2    2020  1404250  86827                  0.061832
# 3    2019  1228698  84499                  0.068771
# 4    2018  1173512  84469                  0.071980
# ..    ...      ...    ...                       ...
# 238  1798  19       0                      0.000000
# 239  1791  19       0                      0.000000
# 240  1794  18       0                      0.000000
# 241  1793  17       0                      0.000000
# 242  1795  13       0                      0.000000
#
# [243 rows x 4 columns]

# %%
# export
df_pubmed_by_year.sort_values(by='Year', ascending=False).to_csv('results/2023/pubmed_unconquerables_counts_by_year.tsv', sep='\t', index=False)
df_pubmed_by_year
# Out:
#      Year   counts  unconquerables_counts     ratio
# 0    2022  1595029  84017                  0.052674
# 1    2021  1567593  90125                  0.057493
# 2    2020  1404250  86827                  0.061832
# 3    2019  1228698  84499                  0.068771
# 4    2018  1173512  84469                  0.071980
# ..    ...      ...    ...                       ...
# 238  1798  19       0                      0.000000
# 239  1791  19       0                      0.000000
# 240  1794  18       0                      0.000000
# 241  1793  17       0                      0.000000
# 242  1795  13       0                      0.000000
#
# [243 rows x 4 columns]

# %% [markdown]
# ## Compare PubMed data for currently indexed journals only

# %%
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 5274  yes
# 5275  NaN
# 5276  NaN
# 5277  NaN
# 5278  NaN
#
# [5279 rows x 68 columns]

# %%
# test currently indexed
df_journals.loc[df_journals['CurrentlyIndexedYN'] == 'N']
# Out:
# Empty DataFrame
# Columns: [NlmUniqueID, Title, MedlineTA, Country, Place, Publisher, PublicationFirstYear, PublicationEndYear, Frequency, ISSN-Electronic, ISSN-Print, ISSN-Linking, Language, TitleContinuationYN, IndexingStartDate, CurrentlyIndexedYN, IndexOnlineYN, IndexingSubset, IndexingSelectedURL, ReportedMedlineYN, ISSN, sherpa_has_oa_path, embargo, embargo_published_version, embargo_accepted_version, sherpa_oa_green, additional_oa_fee, title_sherpa, issne_sherpa, issnp_sherpa, url, publisher_id, publisher_country, publisher_type, publisher_url, publisher_name, sherpa_uri, sherpa_created, sherpa_last_modified, sherpa_id, DOAJ_pissn, ISSN_old, DOAJ_title, DOAJ_eissn, DOAJ_Seal, DOAJ_date, DOAJ_year, DOAJ_license, DOAJ_author_holds_copyright_without_restrictions, DOAJ_last_updated, DOAJ_APC, DOAJ, year_founded, year_reverse_flipped, journal_location, society_affiliation, other_sci_affiliation, flipped_journal_name, post_flip_publisher, flipped_access_model, apc_pre, apc_post, apc_now, discipline, flipped_oa, flipped_born_oa, flipped_embargo, Reverse_Flip]
# Index: []

# %%
# test currently indexed
df_journals.loc[df_journals['CurrentlyIndexedYN'].isna()]
# Out:
# Empty DataFrame
# Columns: [NlmUniqueID, Title, MedlineTA, Country, Place, Publisher, PublicationFirstYear, PublicationEndYear, Frequency, ISSN-Electronic, ISSN-Print, ISSN-Linking, Language, TitleContinuationYN, IndexingStartDate, CurrentlyIndexedYN, IndexOnlineYN, IndexingSubset, IndexingSelectedURL, ReportedMedlineYN, ISSN, sherpa_has_oa_path, embargo, embargo_published_version, embargo_accepted_version, sherpa_oa_green, additional_oa_fee, title_sherpa, issne_sherpa, issnp_sherpa, url, publisher_id, publisher_country, publisher_type, publisher_url, publisher_name, sherpa_uri, sherpa_created, sherpa_last_modified, sherpa_id, DOAJ_pissn, ISSN_old, DOAJ_title, DOAJ_eissn, DOAJ_Seal, DOAJ_date, DOAJ_year, DOAJ_license, DOAJ_author_holds_copyright_without_restrictions, DOAJ_last_updated, DOAJ_APC, DOAJ, year_founded, year_reverse_flipped, journal_location, society_affiliation, other_sci_affiliation, flipped_journal_name, post_flip_publisher, flipped_access_model, apc_pre, apc_post, apc_now, discipline, flipped_oa, flipped_born_oa, flipped_embargo, Reverse_Flip]
# Index: []

# %%
# add 1
df_journals.loc[df_journals['NlmUniqueID'].notna(), 'CurrentlyIndexed'] = 1
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip  CurrentlyIndexed
# 0     NaN          1.0
# 1     NaN          1.0
# 2     NaN          1.0
# 3     NaN          1.0
# 4     NaN          1.0
# ...   ...          ...
# 5274  yes          1.0
# 5275  NaN          1.0
# 5276  NaN          1.0
# 5277  NaN          1.0
# 5278  NaN          1.0
#
# [5279 rows x 69 columns]

# %%
# merge
df_pubmed = df_pubmed.merge(df_journals[['NlmUniqueID', 'CurrentlyIndexed']], on='NlmUniqueID', how='left')
df_pubmed
# Out:
#               PMID  Year NlmUniqueID  DOI  unconquerables  CurrentlyIndexed
# 0         1         1975  0151424     1.0  0.0            NaN
# 1         2         1975  0372516     1.0  0.0             1.0
# 2         4         1975  0372516     1.0  0.0             1.0
# 3         3         1975  0372516     1.0  0.0             1.0
# 4         5         1975  0372516     1.0  0.0             1.0
# ...      ..          ...      ...     ...  ...             ...
# 34960695  36475580  2022  101504991   1.0  0.0             1.0
# 34960696  36475581  2022  101504991   1.0  0.0             1.0
# 34960697  36475582  2022  101504991   1.0  0.0             1.0
# 34960698  36475583  2022  101504991   1.0  0.0             1.0
# 34960699  36475584  2022  101729147   1.0  0.0             1.0
#
# [34960700 rows x 6 columns]

# %%
# attribution of 0 to other journals
df_pubmed.loc[df_pubmed['CurrentlyIndexed'].isna(), 'CurrentlyIndexed'] = 0
df_pubmed
# Out:
#               PMID  Year NlmUniqueID  DOI  unconquerables  CurrentlyIndexed
# 0         1         1975  0151424     1.0  0.0             0.0
# 1         2         1975  0372516     1.0  0.0             1.0
# 2         4         1975  0372516     1.0  0.0             1.0
# 3         3         1975  0372516     1.0  0.0             1.0
# 4         5         1975  0372516     1.0  0.0             1.0
# ...      ..          ...      ...     ...  ...             ...
# 34960695  36475580  2022  101504991   1.0  0.0             1.0
# 34960696  36475581  2022  101504991   1.0  0.0             1.0
# 34960697  36475582  2022  101504991   1.0  0.0             1.0
# 34960698  36475583  2022  101504991   1.0  0.0             1.0
# 34960699  36475584  2022  101729147   1.0  0.0             1.0
#
# [34960700 rows x 6 columns]

# %%
# export counts by year for currently indexed
counts_pubmed_currently_indexed_by_year = df_pubmed.loc[df_pubmed['CurrentlyIndexed'] == 1]['Year'].value_counts().rename_axis('Year').reset_index(name='counts_currently_indexed')
df_pubmed_currently_indexed_by_year = pd.DataFrame(counts_pubmed_currently_indexed_by_year, columns=['Year', 'counts_currently_indexed'])
df_pubmed_currently_indexed_by_year.sort_values(by='Year', ascending=False).to_csv('results/2023/pubmed_currently_indexed_counts_by_year.tsv', header=True, sep='\t', index=False)
df_pubmed_currently_indexed_by_year
# Out:
#      Year  counts_currently_indexed
# 0    2022  1244839
# 1    2021  1205319
# 2    2020  1119747
# 3    2019  1021270
# 4    2018  991396
# ..    ...     ...
# 141  1894  333
# 142  1880  325
# 143  1879  31
# 144  1878  30
# 145  1882  21
#
# [146 rows x 2 columns]

# %%
# merge
df_pubmed_by_year = df_pubmed_by_year.merge(df_pubmed_currently_indexed_by_year, on='Year', how='left')
df_pubmed_by_year
# Out:
#      Year   counts  unconquerables_counts     ratio  counts_currently_indexed
# 0    2022  1595029  84017                  0.052674  1244839.0
# 1    2021  1567593  90125                  0.057493  1205319.0
# 2    2020  1404250  86827                  0.061832  1119747.0
# 3    2019  1228698  84499                  0.068771  1021270.0
# 4    2018  1173512  84469                  0.071980  991396.0
# ..    ...      ...    ...                       ...       ...
# 238  1798  19       0                      0.000000 NaN
# 239  1791  19       0                      0.000000 NaN
# 240  1794  18       0                      0.000000 NaN
# 241  1793  17       0                      0.000000 NaN
# 242  1795  13       0                      0.000000 NaN
#
# [243 rows x 5 columns]

# %%
# replace NaN by 0
df_pubmed_by_year.loc[df_pubmed_by_year['counts_currently_indexed'].isna(), 'counts_currently_indexed'] = 0
df_pubmed_by_year.loc[df_pubmed_by_year['counts_currently_indexed'].notna(), 'counts_currently_indexed'] = df_pubmed_by_year['counts_currently_indexed'].astype(int)

# %%
# add ratios
df_pubmed_by_year['ratio2'] = df_pubmed_by_year['unconquerables_counts'] / df_pubmed_by_year['counts_currently_indexed']
df_pubmed_by_year
# Out:
#      Year   counts  unconquerables_counts     ratio  counts_currently_indexed  \
# 0    2022  1595029  84017                  0.052674  1244839
# 1    2021  1567593  90125                  0.057493  1205319
# 2    2020  1404250  86827                  0.061832  1119747
# 3    2019  1228698  84499                  0.068771  1021270
# 4    2018  1173512  84469                  0.071980  991396
# ..    ...      ...    ...                       ...     ...
# 238  1798  19       0                      0.000000  0
# 239  1791  19       0                      0.000000  0
# 240  1794  18       0                      0.000000  0
# 241  1793  17       0                      0.000000  0
# 242  1795  13       0                      0.000000  0
#
#        ratio2
# 0    0.067492
# 1    0.074773
# 2    0.077542
# 3    0.082739
# 4    0.085202
# ..        ...
# 238 NaN
# 239 NaN
# 240 NaN
# 241 NaN
# 242 NaN
#
# [243 rows x 6 columns]

# %%
# export
df_pubmed_by_year.sort_values(by='Year', ascending=False).to_csv('results/2023/pubmed_unconquerables_counts_by_year.tsv', sep='\t', index=False)
df_pubmed_by_year
# Out:
#      Year   counts  unconquerables_counts     ratio  counts_currently_indexed  \
# 0    2022  1595029  84017                  0.052674  1244839
# 1    2021  1567593  90125                  0.057493  1205319
# 2    2020  1404250  86827                  0.061832  1119747
# 3    2019  1228698  84499                  0.068771  1021270
# 4    2018  1173512  84469                  0.071980  991396
# ..    ...      ...    ...                       ...     ...
# 238  1798  19       0                      0.000000  0
# 239  1791  19       0                      0.000000  0
# 240  1794  18       0                      0.000000  0
# 241  1793  17       0                      0.000000  0
# 242  1795  13       0                      0.000000  0
#
#        ratio2
# 0    0.067492
# 1    0.074773
# 2    0.077542
# 3    0.082739
# 4    0.085202
# ..        ...
# 238 NaN
# 239 NaN
# 240 NaN
# 241 NaN
# 242 NaN
#
# [243 rows x 6 columns]

# %%
df_pubmed
# Out:
#               PMID  Year NlmUniqueID  DOI  unconquerables  CurrentlyIndexed
# 0         1         1975  0151424     1.0  0.0             0.0
# 1         2         1975  0372516     1.0  0.0             1.0
# 2         4         1975  0372516     1.0  0.0             1.0
# 3         3         1975  0372516     1.0  0.0             1.0
# 4         5         1975  0372516     1.0  0.0             1.0
# ...      ..          ...      ...     ...  ...             ...
# 34960695  36475580  2022  101504991   1.0  0.0             1.0
# 34960696  36475581  2022  101504991   1.0  0.0             1.0
# 34960697  36475582  2022  101504991   1.0  0.0             1.0
# 34960698  36475583  2022  101504991   1.0  0.0             1.0
# 34960699  36475584  2022  101729147   1.0  0.0             1.0
#
# [34960700 rows x 6 columns]

# %%
# csv export
df_pubmed.to_csv('results/2023/pubmed_merged_unconquerables_and_currently_indexed.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# ## Import PubMed publication first and last year for each journal

# %%
# take the first publication year for each journal
df_pubmed_journals_first_year = df_pubmed[['Year', 'NlmUniqueID']].groupby(by='NlmUniqueID').min()
df_pubmed_journals_first_year.sort_values(by='NlmUniqueID', ascending=True).to_csv('results/2023/pubmed_journals_first_year.tsv', sep='\t', index=True)
df_pubmed_journals_first_year
# Out:
#                   Year
# NlmUniqueID
# 0000201           1963
# 0000211           1965
# 0000212           1965
# 0000213           1945
# 0000216           1964
# ...                ...
# 9918505287106676  2022
# 9918505588006676  2023
# 9918505588106676  2022
# 9918505688506676  2022
# 9918506286206676  2022
#
# [35640 rows x 1 columns]

# %%
# take the last publication year for each journal
df_pubmed_journals_last_year = df_pubmed[['Year', 'NlmUniqueID']].groupby(by='NlmUniqueID').max()
df_pubmed_journals_last_year.sort_values(by='NlmUniqueID', ascending=True).to_csv('results/2023/pubmed_journals_last_year.tsv', sep='\t', index=True)
df_pubmed_journals_last_year
# Out:
#                   Year
# NlmUniqueID
# 0000201           1977
# 0000211           1991
# 0000212           1971
# 0000213           1992
# 0000216           1988
# ...                ...
# 9918505287106676  2022
# 9918505588006676  2023
# 9918505588106676  2022
# 9918505688506676  2022
# 9918506286206676  2022
#
# [35640 rows x 1 columns]

# %%
# reset index and rename columns
df_pubmed_journals_first_year = df_pubmed_journals_first_year.reset_index(drop=False)
df_pubmed_journals_last_year = df_pubmed_journals_last_year.reset_index(drop=False)
df_pubmed_journals_first_year = df_pubmed_journals_first_year.rename(columns={'Year' : 'first_year'})
df_pubmed_journals_last_year = df_pubmed_journals_last_year.rename(columns={'Year' : 'last_year'})

# %%
df_pubmed_journals_first_year
# Out:
#             NlmUniqueID  first_year
# 0      0000201           1963
# 1      0000211           1965
# 2      0000212           1965
# 3      0000213           1945
# 4      0000216           1964
# ...        ...            ...
# 35635  9918505287106676  2022
# 35636  9918505588006676  2023
# 35637  9918505588106676  2022
# 35638  9918505688506676  2022
# 35639  9918506286206676  2022
#
# [35640 rows x 2 columns]

# %%
df_pubmed_journals_last_year
# Out:
#             NlmUniqueID  last_year
# 0      0000201           1977
# 1      0000211           1991
# 2      0000212           1971
# 3      0000213           1992
# 4      0000216           1988
# ...        ...            ...
# 35635  9918505287106676  2022
# 35636  9918505588006676  2023
# 35637  9918505588106676  2022
# 35638  9918505688506676  2022
# 35639  9918506286206676  2022
#
# [35640 rows x 2 columns]

# %%
# merge first and last year infos for each journal
df_journals = df_journals.merge(df_pubmed_journals_first_year, on='NlmUniqueID', how='left')
df_journals = df_journals.merge(df_pubmed_journals_last_year, on='NlmUniqueID', how='left')
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip  CurrentlyIndexed  first_year  last_year
# 0     NaN          1.0               1990.0      2019.0
# 1     NaN          1.0               2018.0      2022.0
# 2     NaN          1.0               2006.0      2022.0
# 3     NaN          1.0               1974.0      2022.0
# 4     NaN          1.0               2004.0      2022.0
# ...   ...          ...                  ...         ...
# 5274  yes          1.0               1987.0      2022.0
# 5275  NaN          1.0               2001.0      2022.0
# 5276  NaN          1.0               2007.0      2022.0
# 5277  NaN          1.0               2008.0      2022.0
# 5278  NaN          1.0               1993.0      2022.0
#
# [5279 rows x 71 columns]

# %%
# test empty values
df_journals.loc[df_journals['first_year'].isna()]
# Out:
#            NlmUniqueID  \
# 134   9918523075306676
# 713   9918522188506676
# 930   9918418287206676
# 2451  9918487342606676
# 2494  9918540787006676
#
#                                                                               Title  \
# 134   Advances in kidney disease and health
# 713   Biomolecules and biomedicine
# 930   Canadian journal of health history = Revue canadienne d'histoire de la santé
# 2451  International journal of social determinants of health and health services
# 2494  Interdisciplinary cardiovascular and thoracic surgery
#
#                                       MedlineTA                 Country  \
# 134   Adv Kidney Dis Health                      United States
# 713   Biomol Biomed                              Bosnia and Herzegovina
# 930   Can J Health Hist                          Canada
# 2451  Int J Soc Determinants Health Health Serv  United States
# 2494  Interdiscip Cardiovasc Thorac Surg         England
#
#                   Place                                      Publisher  \
# 134   [New York]         Elsevier Inc.
# 713   Sarajevo           Association of Basic Medical Sciences of FBIH
# 930   Toronto            University of Toronto Press
# 2451  Thousand Oaks, CA  SAGE Publishing
# 2494  [Oxford]           Oxford University Press
#
#      PublicationFirstYear  PublicationEndYear  Frequency ISSN-Electronic  \
# 134   2023                NaN                  Bimonthly  2949-8139
# 713   2023                NaN                  NaN        2831-090X
# 930   2022                NaN                  NaN        2816-6477
# 2451  2023                NaN                  Quarterly  2755-1946
# 2494  2023                NaN                  Monthly    2753-670X
#
#      ISSN-Print ISSN-Linking Language TitleContinuationYN  IndexingStartDate  \
# 134   2949-8147  2949-8139    eng      Y                   2023.0
# 713   2831-0896  2831-0896    eng      Y                   2023.0
# 930   2816-6469  NaN          eng      Y                   2022.0
# 2451  2755-1938  2755-1938    eng      Y                   2023.0
# 2494  NaN        2753-670X    eng      Y                   2023.0
#
#      CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 134   Y                  Y             IM
# 713   Y                  Y             IM
# 930   Y                  Y             QIS
# 2451  Y                  Y             IM
# 2494  Y                  Y             IM
#
#                                                               IndexingSelectedURL  \
# 134   https://www.sciencedirect.com/journal/advances-in-kidney-disease-and-health
# 713   http://bjbms.org/ojs/index.php/bjbms/issue/archive
# 930   https://www.utpjournals.press/loi/cjhh
# 2451  https://journals.sagepub.com/home/joh
# 2494  https://academic.oup.com/icvts
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 134   Y                 2949-8139  NaN               NaN
# 713   Y                 2831-090X  yes                0.0
# 930   Y                 2816-6477  NaN               NaN
# 2451  Y                 2755-1946  yes                0.0
# 2494  Y                 2753-670X  NaN               NaN
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 134  NaN                        NaN                        NaN
# 713   0.0                        0.0                       yes
# 930  NaN                        NaN                        NaN
# 2451 NaN                         0.0                       yes
# 2494 NaN                        NaN                        NaN
#
#      additional_oa_fee  \
# 134   NaN
# 713   NaN
# 930   NaN
# 2451  yes
# 2494  NaN
#
#                                                                     title_sherpa  \
# 134   NaN
# 713   Biomolecules and Biomedicine
# 930   NaN
# 2451  International Journal of Social Determinants of Health and Health Services
# 2494  NaN
#
#      issne_sherpa issnp_sherpa                                        url  \
# 134   NaN          NaN          NaN
# 713   2831-090X    2831-0896    https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN          NaN          NaN
# 2451  2755-1946    2755-1938    https://journals.sagepub.com/home/joh
# 2494  NaN          NaN          NaN
#
#       publisher_id publisher_country        publisher_type  \
# 134  NaN            NaN               NaN
# 713   2417.0        ba                society_publisher
# 930  NaN            NaN               NaN
# 2451  65.0          gb                commercial_publisher
# 2494 NaN            NaN               NaN
#
#                                   publisher_url  \
# 134   NaN
# 713   https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN
# 2451  https://uk.sagepub.com/en-gb/eur/home
# 2494  NaN
#
#                                                                      publisher_name  \
# 134   NaN
# 713   Association of Basic Medical Sciences of Federation of Bosnia and Herzegovina
# 930   NaN
# 2451  SAGE Publications
# 2494  NaN
#
#                                             sherpa_uri       sherpa_created  \
# 134   NaN                                               NaN
# 713   https://v2.sherpa.ac.uk/id/publisher_policy/2417  2015-07-22 13:37:57
# 930   NaN                                               NaN
# 2451  https://v2.sherpa.ac.uk/id/publisher_policy/65    2010-08-05 10:52:45
# 2494  NaN                                               NaN
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old  \
# 134   NaN                 NaN         NaN        NaN
# 713   2023-02-28 06:23:38  29978.0    2831-090X  NaN
# 930   NaN                 NaN         NaN        NaN
# 2451  2023-01-12 09:47:57  7349.0     NaN        NaN
# 2494  NaN                 NaN         NaN        NaN
#
#                       DOAJ_title DOAJ_eissn DOAJ_Seal             DOAJ_date  \
# 134   NaN                         NaN        NaN       NaN
# 713   Biomolecules & Biomedicine  2831-090X  No        2023-02-27T13:14:38Z
# 930   NaN                         NaN        NaN       NaN
# 2451  NaN                         NaN        NaN       NaN
# 2494  NaN                         NaN        NaN       NaN
#
#       DOAJ_year DOAJ_license DOAJ_author_holds_copyright_without_restrictions  \
# 134  NaN         NaN          NaN
# 713   2023.0     CC BY        Yes
# 930  NaN         NaN          NaN
# 2451 NaN         NaN          NaN
# 2494 NaN         NaN          NaN
#
#          DOAJ_last_updated DOAJ_APC DOAJ  year_founded  year_reverse_flipped  \
# 134   NaN                   NaN      NaN NaN           NaN
# 713   2023-02-27T13:14:38Z  Yes      yes NaN           NaN
# 930   NaN                   NaN      NaN NaN           NaN
# 2451  NaN                   NaN      NaN NaN           NaN
# 2494  NaN                   NaN      NaN NaN           NaN
#
#      journal_location society_affiliation other_sci_affiliation  \
# 134   NaN              NaN                 NaN
# 713   NaN              NaN                 NaN
# 930   NaN              NaN                 NaN
# 2451  NaN              NaN                 NaN
# 2494  NaN              NaN                 NaN
#
#      flipped_journal_name post_flip_publisher flipped_access_model  apc_pre  \
# 134   NaN                  NaN                 NaN                 NaN
# 713   NaN                  NaN                 NaN                 NaN
# 930   NaN                  NaN                 NaN                 NaN
# 2451  NaN                  NaN                 NaN                 NaN
# 2494  NaN                  NaN                 NaN                 NaN
#
#      apc_post apc_now discipline  flipped_oa  flipped_born_oa  \
# 134   NaN      NaN     NaN       NaN         NaN
# 713   NaN      NaN     NaN       NaN         NaN
# 930   NaN      NaN     NaN       NaN         NaN
# 2451  NaN      NaN     NaN       NaN         NaN
# 2494  NaN      NaN     NaN       NaN         NaN
#
#       flipped_embargo Reverse_Flip  CurrentlyIndexed  first_year  last_year
# 134  NaN               NaN          1.0              NaN         NaN
# 713  NaN               NaN          1.0              NaN         NaN
# 930  NaN               NaN          1.0              NaN         NaN
# 2451 NaN               NaN          1.0              NaN         NaN
# 2494 NaN               NaN          1.0              NaN         NaN

# %%
# test empty values
df_journals.loc[df_journals['last_year'].isna()]
# Out:
#            NlmUniqueID  \
# 134   9918523075306676
# 713   9918522188506676
# 930   9918418287206676
# 2451  9918487342606676
# 2494  9918540787006676
#
#                                                                               Title  \
# 134   Advances in kidney disease and health
# 713   Biomolecules and biomedicine
# 930   Canadian journal of health history = Revue canadienne d'histoire de la santé
# 2451  International journal of social determinants of health and health services
# 2494  Interdisciplinary cardiovascular and thoracic surgery
#
#                                       MedlineTA                 Country  \
# 134   Adv Kidney Dis Health                      United States
# 713   Biomol Biomed                              Bosnia and Herzegovina
# 930   Can J Health Hist                          Canada
# 2451  Int J Soc Determinants Health Health Serv  United States
# 2494  Interdiscip Cardiovasc Thorac Surg         England
#
#                   Place                                      Publisher  \
# 134   [New York]         Elsevier Inc.
# 713   Sarajevo           Association of Basic Medical Sciences of FBIH
# 930   Toronto            University of Toronto Press
# 2451  Thousand Oaks, CA  SAGE Publishing
# 2494  [Oxford]           Oxford University Press
#
#      PublicationFirstYear  PublicationEndYear  Frequency ISSN-Electronic  \
# 134   2023                NaN                  Bimonthly  2949-8139
# 713   2023                NaN                  NaN        2831-090X
# 930   2022                NaN                  NaN        2816-6477
# 2451  2023                NaN                  Quarterly  2755-1946
# 2494  2023                NaN                  Monthly    2753-670X
#
#      ISSN-Print ISSN-Linking Language TitleContinuationYN  IndexingStartDate  \
# 134   2949-8147  2949-8139    eng      Y                   2023.0
# 713   2831-0896  2831-0896    eng      Y                   2023.0
# 930   2816-6469  NaN          eng      Y                   2022.0
# 2451  2755-1938  2755-1938    eng      Y                   2023.0
# 2494  NaN        2753-670X    eng      Y                   2023.0
#
#      CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 134   Y                  Y             IM
# 713   Y                  Y             IM
# 930   Y                  Y             QIS
# 2451  Y                  Y             IM
# 2494  Y                  Y             IM
#
#                                                               IndexingSelectedURL  \
# 134   https://www.sciencedirect.com/journal/advances-in-kidney-disease-and-health
# 713   http://bjbms.org/ojs/index.php/bjbms/issue/archive
# 930   https://www.utpjournals.press/loi/cjhh
# 2451  https://journals.sagepub.com/home/joh
# 2494  https://academic.oup.com/icvts
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 134   Y                 2949-8139  NaN               NaN
# 713   Y                 2831-090X  yes                0.0
# 930   Y                 2816-6477  NaN               NaN
# 2451  Y                 2755-1946  yes                0.0
# 2494  Y                 2753-670X  NaN               NaN
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 134  NaN                        NaN                        NaN
# 713   0.0                        0.0                       yes
# 930  NaN                        NaN                        NaN
# 2451 NaN                         0.0                       yes
# 2494 NaN                        NaN                        NaN
#
#      additional_oa_fee  \
# 134   NaN
# 713   NaN
# 930   NaN
# 2451  yes
# 2494  NaN
#
#                                                                     title_sherpa  \
# 134   NaN
# 713   Biomolecules and Biomedicine
# 930   NaN
# 2451  International Journal of Social Determinants of Health and Health Services
# 2494  NaN
#
#      issne_sherpa issnp_sherpa                                        url  \
# 134   NaN          NaN          NaN
# 713   2831-090X    2831-0896    https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN          NaN          NaN
# 2451  2755-1946    2755-1938    https://journals.sagepub.com/home/joh
# 2494  NaN          NaN          NaN
#
#       publisher_id publisher_country        publisher_type  \
# 134  NaN            NaN               NaN
# 713   2417.0        ba                society_publisher
# 930  NaN            NaN               NaN
# 2451  65.0          gb                commercial_publisher
# 2494 NaN            NaN               NaN
#
#                                   publisher_url  \
# 134   NaN
# 713   https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN
# 2451  https://uk.sagepub.com/en-gb/eur/home
# 2494  NaN
#
#                                                                      publisher_name  \
# 134   NaN
# 713   Association of Basic Medical Sciences of Federation of Bosnia and Herzegovina
# 930   NaN
# 2451  SAGE Publications
# 2494  NaN
#
#                                             sherpa_uri       sherpa_created  \
# 134   NaN                                               NaN
# 713   https://v2.sherpa.ac.uk/id/publisher_policy/2417  2015-07-22 13:37:57
# 930   NaN                                               NaN
# 2451  https://v2.sherpa.ac.uk/id/publisher_policy/65    2010-08-05 10:52:45
# 2494  NaN                                               NaN
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old  \
# 134   NaN                 NaN         NaN        NaN
# 713   2023-02-28 06:23:38  29978.0    2831-090X  NaN
# 930   NaN                 NaN         NaN        NaN
# 2451  2023-01-12 09:47:57  7349.0     NaN        NaN
# 2494  NaN                 NaN         NaN        NaN
#
#                       DOAJ_title DOAJ_eissn DOAJ_Seal             DOAJ_date  \
# 134   NaN                         NaN        NaN       NaN
# 713   Biomolecules & Biomedicine  2831-090X  No        2023-02-27T13:14:38Z
# 930   NaN                         NaN        NaN       NaN
# 2451  NaN                         NaN        NaN       NaN
# 2494  NaN                         NaN        NaN       NaN
#
#       DOAJ_year DOAJ_license DOAJ_author_holds_copyright_without_restrictions  \
# 134  NaN         NaN          NaN
# 713   2023.0     CC BY        Yes
# 930  NaN         NaN          NaN
# 2451 NaN         NaN          NaN
# 2494 NaN         NaN          NaN
#
#          DOAJ_last_updated DOAJ_APC DOAJ  year_founded  year_reverse_flipped  \
# 134   NaN                   NaN      NaN NaN           NaN
# 713   2023-02-27T13:14:38Z  Yes      yes NaN           NaN
# 930   NaN                   NaN      NaN NaN           NaN
# 2451  NaN                   NaN      NaN NaN           NaN
# 2494  NaN                   NaN      NaN NaN           NaN
#
#      journal_location society_affiliation other_sci_affiliation  \
# 134   NaN              NaN                 NaN
# 713   NaN              NaN                 NaN
# 930   NaN              NaN                 NaN
# 2451  NaN              NaN                 NaN
# 2494  NaN              NaN                 NaN
#
#      flipped_journal_name post_flip_publisher flipped_access_model  apc_pre  \
# 134   NaN                  NaN                 NaN                 NaN
# 713   NaN                  NaN                 NaN                 NaN
# 930   NaN                  NaN                 NaN                 NaN
# 2451  NaN                  NaN                 NaN                 NaN
# 2494  NaN                  NaN                 NaN                 NaN
#
#      apc_post apc_now discipline  flipped_oa  flipped_born_oa  \
# 134   NaN      NaN     NaN       NaN         NaN
# 713   NaN      NaN     NaN       NaN         NaN
# 930   NaN      NaN     NaN       NaN         NaN
# 2451  NaN      NaN     NaN       NaN         NaN
# 2494  NaN      NaN     NaN       NaN         NaN
#
#       flipped_embargo Reverse_Flip  CurrentlyIndexed  first_year  last_year
# 134  NaN               NaN          1.0              NaN         NaN
# 713  NaN               NaN          1.0              NaN         NaN
# 930  NaN               NaN          1.0              NaN         NaN
# 2451 NaN               NaN          1.0              NaN         NaN
# 2494 NaN               NaN          1.0              NaN         NaN

# %% [markdown]
# ## Import PubMed publication volume for each journal

# %%
# take the number of publications year for each journal
df_pubmed_journals_volume = df_pubmed[['PMID', 'NlmUniqueID']].groupby(by='NlmUniqueID').count()
df_pubmed_journals_volume.sort_values(by='NlmUniqueID', ascending=True).to_csv('results/2023/pubmed_journals_volume.tsv', sep='\t', index=True)
df_pubmed_journals_volume
# Out:
#                   PMID
# NlmUniqueID
# 0000201           739
# 0000211           4181
# 0000212           213
# 0000213           1154
# 0000216           1058
# ...                ...
# 9918505287106676  1
# 9918505588006676  1
# 9918505588106676  1
# 9918505688506676  1
# 9918506286206676  1
#
# [35640 rows x 1 columns]

# %%
# reset index and rename columns
df_pubmed_journals_volume = df_pubmed_journals_volume.reset_index(drop=False)
df_pubmed_journals_volume = df_pubmed_journals_volume.rename(columns={'PMID' : 'PMIDs'})

# %%
df_pubmed_journals_volume
# Out:
#             NlmUniqueID  PMIDs
# 0      0000201           739
# 1      0000211           4181
# 2      0000212           213
# 3      0000213           1154
# 4      0000216           1058
# ...        ...            ...
# 35635  9918505287106676  1
# 35636  9918505588006676  1
# 35637  9918505588106676  1
# 35638  9918505688506676  1
# 35639  9918506286206676  1
#
# [35640 rows x 2 columns]

# %%
# merge PMIDs infos for each journal
df_journals = df_journals.merge(df_pubmed_journals_volume, on='NlmUniqueID', how='left')
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip  CurrentlyIndexed  first_year  last_year    PMIDs
# 0     NaN          1.0               1990.0      2019.0     145.0
# 1     NaN          1.0               2018.0      2022.0     999.0
# 2     NaN          1.0               2006.0      2022.0     851.0
# 3     NaN          1.0               1974.0      2022.0     2547.0
# 4     NaN          1.0               2004.0      2022.0     1976.0
# ...   ...          ...                  ...         ...        ...
# 5274  yes          1.0               1987.0      2022.0     2680.0
# 5275  NaN          1.0               2001.0      2022.0     1019.0
# 5276  NaN          1.0               2007.0      2022.0     1445.0
# 5277  NaN          1.0               2008.0      2022.0     20965.0
# 5278  NaN          1.0               1993.0      2022.0     1709.0
#
# [5279 rows x 72 columns]

# %%
# test empty values
df_journals.loc[df_journals['PMIDs'].isna()]
# Out:
#            NlmUniqueID  \
# 134   9918523075306676
# 713   9918522188506676
# 930   9918418287206676
# 2451  9918487342606676
# 2494  9918540787006676
#
#                                                                               Title  \
# 134   Advances in kidney disease and health
# 713   Biomolecules and biomedicine
# 930   Canadian journal of health history = Revue canadienne d'histoire de la santé
# 2451  International journal of social determinants of health and health services
# 2494  Interdisciplinary cardiovascular and thoracic surgery
#
#                                       MedlineTA                 Country  \
# 134   Adv Kidney Dis Health                      United States
# 713   Biomol Biomed                              Bosnia and Herzegovina
# 930   Can J Health Hist                          Canada
# 2451  Int J Soc Determinants Health Health Serv  United States
# 2494  Interdiscip Cardiovasc Thorac Surg         England
#
#                   Place                                      Publisher  \
# 134   [New York]         Elsevier Inc.
# 713   Sarajevo           Association of Basic Medical Sciences of FBIH
# 930   Toronto            University of Toronto Press
# 2451  Thousand Oaks, CA  SAGE Publishing
# 2494  [Oxford]           Oxford University Press
#
#      PublicationFirstYear  PublicationEndYear  Frequency ISSN-Electronic  \
# 134   2023                NaN                  Bimonthly  2949-8139
# 713   2023                NaN                  NaN        2831-090X
# 930   2022                NaN                  NaN        2816-6477
# 2451  2023                NaN                  Quarterly  2755-1946
# 2494  2023                NaN                  Monthly    2753-670X
#
#      ISSN-Print ISSN-Linking Language TitleContinuationYN  IndexingStartDate  \
# 134   2949-8147  2949-8139    eng      Y                   2023.0
# 713   2831-0896  2831-0896    eng      Y                   2023.0
# 930   2816-6469  NaN          eng      Y                   2022.0
# 2451  2755-1938  2755-1938    eng      Y                   2023.0
# 2494  NaN        2753-670X    eng      Y                   2023.0
#
#      CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 134   Y                  Y             IM
# 713   Y                  Y             IM
# 930   Y                  Y             QIS
# 2451  Y                  Y             IM
# 2494  Y                  Y             IM
#
#                                                               IndexingSelectedURL  \
# 134   https://www.sciencedirect.com/journal/advances-in-kidney-disease-and-health
# 713   http://bjbms.org/ojs/index.php/bjbms/issue/archive
# 930   https://www.utpjournals.press/loi/cjhh
# 2451  https://journals.sagepub.com/home/joh
# 2494  https://academic.oup.com/icvts
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 134   Y                 2949-8139  NaN               NaN
# 713   Y                 2831-090X  yes                0.0
# 930   Y                 2816-6477  NaN               NaN
# 2451  Y                 2755-1946  yes                0.0
# 2494  Y                 2753-670X  NaN               NaN
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 134  NaN                        NaN                        NaN
# 713   0.0                        0.0                       yes
# 930  NaN                        NaN                        NaN
# 2451 NaN                         0.0                       yes
# 2494 NaN                        NaN                        NaN
#
#      additional_oa_fee  \
# 134   NaN
# 713   NaN
# 930   NaN
# 2451  yes
# 2494  NaN
#
#                                                                     title_sherpa  \
# 134   NaN
# 713   Biomolecules and Biomedicine
# 930   NaN
# 2451  International Journal of Social Determinants of Health and Health Services
# 2494  NaN
#
#      issne_sherpa issnp_sherpa                                        url  \
# 134   NaN          NaN          NaN
# 713   2831-090X    2831-0896    https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN          NaN          NaN
# 2451  2755-1946    2755-1938    https://journals.sagepub.com/home/joh
# 2494  NaN          NaN          NaN
#
#       publisher_id publisher_country        publisher_type  \
# 134  NaN            NaN               NaN
# 713   2417.0        ba                society_publisher
# 930  NaN            NaN               NaN
# 2451  65.0          gb                commercial_publisher
# 2494 NaN            NaN               NaN
#
#                                   publisher_url  \
# 134   NaN
# 713   https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN
# 2451  https://uk.sagepub.com/en-gb/eur/home
# 2494  NaN
#
#                                                                      publisher_name  \
# 134   NaN
# 713   Association of Basic Medical Sciences of Federation of Bosnia and Herzegovina
# 930   NaN
# 2451  SAGE Publications
# 2494  NaN
#
#                                             sherpa_uri       sherpa_created  \
# 134   NaN                                               NaN
# 713   https://v2.sherpa.ac.uk/id/publisher_policy/2417  2015-07-22 13:37:57
# 930   NaN                                               NaN
# 2451  https://v2.sherpa.ac.uk/id/publisher_policy/65    2010-08-05 10:52:45
# 2494  NaN                                               NaN
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old  \
# 134   NaN                 NaN         NaN        NaN
# 713   2023-02-28 06:23:38  29978.0    2831-090X  NaN
# 930   NaN                 NaN         NaN        NaN
# 2451  2023-01-12 09:47:57  7349.0     NaN        NaN
# 2494  NaN                 NaN         NaN        NaN
#
#                       DOAJ_title DOAJ_eissn DOAJ_Seal             DOAJ_date  \
# 134   NaN                         NaN        NaN       NaN
# 713   Biomolecules & Biomedicine  2831-090X  No        2023-02-27T13:14:38Z
# 930   NaN                         NaN        NaN       NaN
# 2451  NaN                         NaN        NaN       NaN
# 2494  NaN                         NaN        NaN       NaN
#
#       DOAJ_year DOAJ_license DOAJ_author_holds_copyright_without_restrictions  \
# 134  NaN         NaN          NaN
# 713   2023.0     CC BY        Yes
# 930  NaN         NaN          NaN
# 2451 NaN         NaN          NaN
# 2494 NaN         NaN          NaN
#
#          DOAJ_last_updated DOAJ_APC DOAJ  year_founded  year_reverse_flipped  \
# 134   NaN                   NaN      NaN NaN           NaN
# 713   2023-02-27T13:14:38Z  Yes      yes NaN           NaN
# 930   NaN                   NaN      NaN NaN           NaN
# 2451  NaN                   NaN      NaN NaN           NaN
# 2494  NaN                   NaN      NaN NaN           NaN
#
#      journal_location society_affiliation other_sci_affiliation  \
# 134   NaN              NaN                 NaN
# 713   NaN              NaN                 NaN
# 930   NaN              NaN                 NaN
# 2451  NaN              NaN                 NaN
# 2494  NaN              NaN                 NaN
#
#      flipped_journal_name post_flip_publisher flipped_access_model  apc_pre  \
# 134   NaN                  NaN                 NaN                 NaN
# 713   NaN                  NaN                 NaN                 NaN
# 930   NaN                  NaN                 NaN                 NaN
# 2451  NaN                  NaN                 NaN                 NaN
# 2494  NaN                  NaN                 NaN                 NaN
#
#      apc_post apc_now discipline  flipped_oa  flipped_born_oa  \
# 134   NaN      NaN     NaN       NaN         NaN
# 713   NaN      NaN     NaN       NaN         NaN
# 930   NaN      NaN     NaN       NaN         NaN
# 2451  NaN      NaN     NaN       NaN         NaN
# 2494  NaN      NaN     NaN       NaN         NaN
#
#       flipped_embargo Reverse_Flip  CurrentlyIndexed  first_year  last_year  \
# 134  NaN               NaN          1.0              NaN         NaN
# 713  NaN               NaN          1.0              NaN         NaN
# 930  NaN               NaN          1.0              NaN         NaN
# 2451 NaN               NaN          1.0              NaN         NaN
# 2494 NaN               NaN          1.0              NaN         NaN
#
#       PMIDs
# 134  NaN
# 713  NaN
# 930  NaN
# 2451 NaN
# 2494 NaN

# %% [markdown]
# ## Import PubMed publications number of DOIs for each journal

# %%
# take the number of publications year for each journal
df_pubmed_journals_dois = df_pubmed[['DOI', 'NlmUniqueID']].groupby(by='NlmUniqueID').sum()
df_pubmed_journals_dois.sort_values(by='NlmUniqueID', ascending=True).to_csv('results/2023/pubmed_journals_dois.tsv', sep='\t', index=True)
df_pubmed_journals_dois
# Out:
#                      DOI
# NlmUniqueID
# 0000201           709.0
# 0000211           4026.0
# 0000212           0.0
# 0000213           1015.0
# 0000216           0.0
# ...                  ...
# 9918505287106676  1.0
# 9918505588006676  1.0
# 9918505588106676  1.0
# 9918505688506676  1.0
# 9918506286206676  1.0
#
# [35640 rows x 1 columns]

# %%
# reset index and rename columns
df_pubmed_journals_dois = df_pubmed_journals_dois.reset_index(drop=False)
df_pubmed_journals_dois = df_pubmed_journals_dois.rename(columns={'DOI' : 'DOIs'})

# %%
df_pubmed_journals_dois
# Out:
#             NlmUniqueID    DOIs
# 0      0000201           709.0
# 1      0000211           4026.0
# 2      0000212           0.0
# 3      0000213           1015.0
# 4      0000216           0.0
# ...        ...           ...
# 35635  9918505287106676  1.0
# 35636  9918505588006676  1.0
# 35637  9918505588106676  1.0
# 35638  9918505688506676  1.0
# 35639  9918506286206676  1.0
#
# [35640 rows x 2 columns]

# %%
# merge PMIDs infos for each journal
df_journals = df_journals.merge(df_pubmed_journals_dois, on='NlmUniqueID', how='left')
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip  CurrentlyIndexed  first_year  last_year    PMIDs     DOIs
# 0     NaN          1.0               1990.0      2019.0     145.0    144.0
# 1     NaN          1.0               2018.0      2022.0     999.0    999.0
# 2     NaN          1.0               2006.0      2022.0     851.0    837.0
# 3     NaN          1.0               1974.0      2022.0     2547.0   0.0
# 4     NaN          1.0               2004.0      2022.0     1976.0   1976.0
# ...   ...          ...                  ...         ...        ...      ...
# 5274  yes          1.0               1987.0      2022.0     2680.0   2635.0
# 5275  NaN          1.0               2001.0      2022.0     1019.0   1017.0
# 5276  NaN          1.0               2007.0      2022.0     1445.0   1444.0
# 5277  NaN          1.0               2008.0      2022.0     20965.0  20886.0
# 5278  NaN          1.0               1993.0      2022.0     1709.0   1641.0
#
# [5279 rows x 73 columns]

# %%
# test empty values
df_journals.loc[df_journals['DOIs'].isna()]
# Out:
#            NlmUniqueID  \
# 134   9918523075306676
# 713   9918522188506676
# 930   9918418287206676
# 2451  9918487342606676
# 2494  9918540787006676
#
#                                                                               Title  \
# 134   Advances in kidney disease and health
# 713   Biomolecules and biomedicine
# 930   Canadian journal of health history = Revue canadienne d'histoire de la santé
# 2451  International journal of social determinants of health and health services
# 2494  Interdisciplinary cardiovascular and thoracic surgery
#
#                                       MedlineTA                 Country  \
# 134   Adv Kidney Dis Health                      United States
# 713   Biomol Biomed                              Bosnia and Herzegovina
# 930   Can J Health Hist                          Canada
# 2451  Int J Soc Determinants Health Health Serv  United States
# 2494  Interdiscip Cardiovasc Thorac Surg         England
#
#                   Place                                      Publisher  \
# 134   [New York]         Elsevier Inc.
# 713   Sarajevo           Association of Basic Medical Sciences of FBIH
# 930   Toronto            University of Toronto Press
# 2451  Thousand Oaks, CA  SAGE Publishing
# 2494  [Oxford]           Oxford University Press
#
#      PublicationFirstYear  PublicationEndYear  Frequency ISSN-Electronic  \
# 134   2023                NaN                  Bimonthly  2949-8139
# 713   2023                NaN                  NaN        2831-090X
# 930   2022                NaN                  NaN        2816-6477
# 2451  2023                NaN                  Quarterly  2755-1946
# 2494  2023                NaN                  Monthly    2753-670X
#
#      ISSN-Print ISSN-Linking Language TitleContinuationYN  IndexingStartDate  \
# 134   2949-8147  2949-8139    eng      Y                   2023.0
# 713   2831-0896  2831-0896    eng      Y                   2023.0
# 930   2816-6469  NaN          eng      Y                   2022.0
# 2451  2755-1938  2755-1938    eng      Y                   2023.0
# 2494  NaN        2753-670X    eng      Y                   2023.0
#
#      CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 134   Y                  Y             IM
# 713   Y                  Y             IM
# 930   Y                  Y             QIS
# 2451  Y                  Y             IM
# 2494  Y                  Y             IM
#
#                                                               IndexingSelectedURL  \
# 134   https://www.sciencedirect.com/journal/advances-in-kidney-disease-and-health
# 713   http://bjbms.org/ojs/index.php/bjbms/issue/archive
# 930   https://www.utpjournals.press/loi/cjhh
# 2451  https://journals.sagepub.com/home/joh
# 2494  https://academic.oup.com/icvts
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 134   Y                 2949-8139  NaN               NaN
# 713   Y                 2831-090X  yes                0.0
# 930   Y                 2816-6477  NaN               NaN
# 2451  Y                 2755-1946  yes                0.0
# 2494  Y                 2753-670X  NaN               NaN
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 134  NaN                        NaN                        NaN
# 713   0.0                        0.0                       yes
# 930  NaN                        NaN                        NaN
# 2451 NaN                         0.0                       yes
# 2494 NaN                        NaN                        NaN
#
#      additional_oa_fee  \
# 134   NaN
# 713   NaN
# 930   NaN
# 2451  yes
# 2494  NaN
#
#                                                                     title_sherpa  \
# 134   NaN
# 713   Biomolecules and Biomedicine
# 930   NaN
# 2451  International Journal of Social Determinants of Health and Health Services
# 2494  NaN
#
#      issne_sherpa issnp_sherpa                                        url  \
# 134   NaN          NaN          NaN
# 713   2831-090X    2831-0896    https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN          NaN          NaN
# 2451  2755-1946    2755-1938    https://journals.sagepub.com/home/joh
# 2494  NaN          NaN          NaN
#
#       publisher_id publisher_country        publisher_type  \
# 134  NaN            NaN               NaN
# 713   2417.0        ba                society_publisher
# 930  NaN            NaN               NaN
# 2451  65.0          gb                commercial_publisher
# 2494 NaN            NaN               NaN
#
#                                   publisher_url  \
# 134   NaN
# 713   https://www.bjbms.org/ojs/index.php/bjbms
# 930   NaN
# 2451  https://uk.sagepub.com/en-gb/eur/home
# 2494  NaN
#
#                                                                      publisher_name  \
# 134   NaN
# 713   Association of Basic Medical Sciences of Federation of Bosnia and Herzegovina
# 930   NaN
# 2451  SAGE Publications
# 2494  NaN
#
#                                             sherpa_uri       sherpa_created  \
# 134   NaN                                               NaN
# 713   https://v2.sherpa.ac.uk/id/publisher_policy/2417  2015-07-22 13:37:57
# 930   NaN                                               NaN
# 2451  https://v2.sherpa.ac.uk/id/publisher_policy/65    2010-08-05 10:52:45
# 2494  NaN                                               NaN
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old  \
# 134   NaN                 NaN         NaN        NaN
# 713   2023-02-28 06:23:38  29978.0    2831-090X  NaN
# 930   NaN                 NaN         NaN        NaN
# 2451  2023-01-12 09:47:57  7349.0     NaN        NaN
# 2494  NaN                 NaN         NaN        NaN
#
#                       DOAJ_title DOAJ_eissn DOAJ_Seal             DOAJ_date  \
# 134   NaN                         NaN        NaN       NaN
# 713   Biomolecules & Biomedicine  2831-090X  No        2023-02-27T13:14:38Z
# 930   NaN                         NaN        NaN       NaN
# 2451  NaN                         NaN        NaN       NaN
# 2494  NaN                         NaN        NaN       NaN
#
#       DOAJ_year DOAJ_license DOAJ_author_holds_copyright_without_restrictions  \
# 134  NaN         NaN          NaN
# 713   2023.0     CC BY        Yes
# 930  NaN         NaN          NaN
# 2451 NaN         NaN          NaN
# 2494 NaN         NaN          NaN
#
#          DOAJ_last_updated DOAJ_APC DOAJ  year_founded  year_reverse_flipped  \
# 134   NaN                   NaN      NaN NaN           NaN
# 713   2023-02-27T13:14:38Z  Yes      yes NaN           NaN
# 930   NaN                   NaN      NaN NaN           NaN
# 2451  NaN                   NaN      NaN NaN           NaN
# 2494  NaN                   NaN      NaN NaN           NaN
#
#      journal_location society_affiliation other_sci_affiliation  \
# 134   NaN              NaN                 NaN
# 713   NaN              NaN                 NaN
# 930   NaN              NaN                 NaN
# 2451  NaN              NaN                 NaN
# 2494  NaN              NaN                 NaN
#
#      flipped_journal_name post_flip_publisher flipped_access_model  apc_pre  \
# 134   NaN                  NaN                 NaN                 NaN
# 713   NaN                  NaN                 NaN                 NaN
# 930   NaN                  NaN                 NaN                 NaN
# 2451  NaN                  NaN                 NaN                 NaN
# 2494  NaN                  NaN                 NaN                 NaN
#
#      apc_post apc_now discipline  flipped_oa  flipped_born_oa  \
# 134   NaN      NaN     NaN       NaN         NaN
# 713   NaN      NaN     NaN       NaN         NaN
# 930   NaN      NaN     NaN       NaN         NaN
# 2451  NaN      NaN     NaN       NaN         NaN
# 2494  NaN      NaN     NaN       NaN         NaN
#
#       flipped_embargo Reverse_Flip  CurrentlyIndexed  first_year  last_year  \
# 134  NaN               NaN          1.0              NaN         NaN
# 713  NaN               NaN          1.0              NaN         NaN
# 930  NaN               NaN          1.0              NaN         NaN
# 2451 NaN               NaN          1.0              NaN         NaN
# 2494 NaN               NaN          1.0              NaN         NaN
#
#       PMIDs  DOIs
# 134  NaN    NaN
# 713  NaN    NaN
# 930  NaN    NaN
# 2451 NaN    NaN
# 2494 NaN    NaN

# %% [markdown]
# ## Import number of PubMed refs for 2021 and 2022

# %%
# take the number of publications year for each journal
df_pubmed_journals_pmids_2021 = df_pubmed.loc[df_pubmed['Year'] == 2021][['PMID', 'NlmUniqueID']].groupby(by='NlmUniqueID').count()
df_pubmed_journals_pmids_2021.sort_values(by='NlmUniqueID', ascending=True).to_csv('results/2023/pubmed_journals_pmids_2021.tsv', sep='\t', index=True)
df_pubmed_journals_pmids_2021
# Out:
#                   PMID
# NlmUniqueID
# 0001027           161
# 0004041           627
# 0004047           34
# 0004653           189
# 0004743           37
# ...               ...
# 9918486785306676  37
# 9918486785406676  1
# 9918487388606676  1
# 9918487580106676  1
# 9918504887506676  1
#
# [11002 rows x 1 columns]

# %%
# take the number of publications year for each journal
df_pubmed_journals_pmids_2022 = df_pubmed.loc[df_pubmed['Year'] == 2022][['PMID', 'NlmUniqueID']].groupby(by='NlmUniqueID').count()
df_pubmed_journals_pmids_2022.sort_values(by='NlmUniqueID', ascending=True).to_csv('results/2023/pubmed_journals_pmids_2022.tsv', sep='\t', index=True)
df_pubmed_journals_pmids_2022
# Out:
#                   PMID
# NlmUniqueID
# 0001027           186
# 0004041           521
# 0004047           43
# 0004653           187
# 0004743           35
# ...               ...
# 9918505286106676  2
# 9918505287106676  1
# 9918505588106676  1
# 9918505688506676  1
# 9918506286206676  1
#
# [10530 rows x 1 columns]

# %%
# reset index and rename columns
df_pubmed_journals_pmids_2021 = df_pubmed_journals_pmids_2021.reset_index(drop=False)
df_pubmed_journals_pmids_2021 = df_pubmed_journals_pmids_2021.rename(columns={'PMID' : 'PMIDs_2021'})
df_pubmed_journals_pmids_2022 = df_pubmed_journals_pmids_2022.reset_index(drop=False)
df_pubmed_journals_pmids_2022 = df_pubmed_journals_pmids_2022.rename(columns={'PMID' : 'PMIDs_2022'})

# %%
df_pubmed_journals_pmids_2022
# Out:
#             NlmUniqueID  PMIDs_2022
# 0      0001027           186
# 1      0004041           521
# 2      0004047           43
# 3      0004653           187
# 4      0004743           35
# ...        ...           ..
# 10525  9918505286106676  2
# 10526  9918505287106676  1
# 10527  9918505588106676  1
# 10528  9918505688506676  1
# 10529  9918506286206676  1
#
# [10530 rows x 2 columns]

# %%
# merge PMIDs infos for each journal
df_journals = df_journals.merge(df_pubmed_journals_pmids_2021, on='NlmUniqueID', how='left')
df_journals = df_journals.merge(df_pubmed_journals_pmids_2022, on='NlmUniqueID', how='left')
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip  CurrentlyIndexed  first_year  last_year    PMIDs     DOIs  \
# 0     NaN          1.0               1990.0      2019.0     145.0    144.0
# 1     NaN          1.0               2018.0      2022.0     999.0    999.0
# 2     NaN          1.0               2006.0      2022.0     851.0    837.0
# 3     NaN          1.0               1974.0      2022.0     2547.0   0.0
# 4     NaN          1.0               2004.0      2022.0     1976.0   1976.0
# ...   ...          ...                  ...         ...        ...      ...
# 5274  yes          1.0               1987.0      2022.0     2680.0   2635.0
# 5275  NaN          1.0               2001.0      2022.0     1019.0   1017.0
# 5276  NaN          1.0               2007.0      2022.0     1445.0   1444.0
# 5277  NaN          1.0               2008.0      2022.0     20965.0  20886.0
# 5278  NaN          1.0               1993.0      2022.0     1709.0   1641.0
#
#       PMIDs_2021  PMIDs_2022
# 0    NaN         NaN
# 1     187.0       73.0
# 2     59.0        37.0
# 3     75.0        60.0
# 4     123.0       109.0
# ...     ...         ...
# 5274  62.0        53.0
# 5275  74.0        41.0
# 5276  102.0       117.0
# 5277  2316.0      1315.0
# 5278  75.0        126.0
#
# [5279 rows x 75 columns]

# %%
# test empty values
df_journals.loc[df_journals['PMIDs_2022'].isna()]
# Out:
#      NlmUniqueID  \
# 0     9015384
# 28    101194794
# 84    9303678
# 88    0370365
# 109   0407712
# ...       ...
# 4951  0051012
# 5081  0417475
# 5161  0330122
# 5187  9607541
# 5258  101093592
#
#                                                                             Title  \
# 0     20 century British history
# 28    Acta of bioengineering and biomechanics
# 84    Acta pharmaceutica (Zagreb, Croatia)
# 88    Acta psychiatrica Scandinavica. Supplementum
# 109   Advances in anatomy, embryology, and cell biology
# ...                                                 ...
# 4951  Texas medicine
# 5081  Uirusu
# 5161  Vital and health statistics. Series 2, Data evaluation and methods research
# 5187  Windows in time
# 5258  Zhonghua nan ke xue = National journal of andrology
#
#                        MedlineTA        Country                 Place  \
# 0     20 Century Br Hist          England        Eynsham, Oxford
# 28    Acta Bioeng Biomech         Poland         Wrocław
# 84    Acta Pharm                  Poland         Warsaw, Poland
# 88    Acta Psychiatr Scand Suppl  Denmark        Malden, MA
# 109   Adv Anat Embryol Cell Biol  Germany        Berlin
# ...                          ...      ...           ...
# 4951  Tex Med                     United States  Austin
# 5081  Uirusu                      Japan          Kyoto
# 5161  Vital Health Stat 2         United States  Hyattsville, Md.
# 5187  Windows Time                United States  Charlottesville, Va.
# 5258  Zhonghua Nan Ke Xue         China          Nanjing
#
#                                                                                                Publisher  \
# 0     Oxford University Press
# 28    Oficyna Wydawnicza Politechniki Wrocławskiej
# 84    Sciendo
# 88    Wiley-Blackwell
# 109   Springer Verlag
# ...               ...
# 4951  Texas Medical Assn.
# 5081  Society Of Japanese Virologists
# 5161  U.S. National Center for Health Statistics
# 5187  Center for Nursing Historical Inquiry, University of Virginia, School of Nursing
# 5258  Nanjing Jun Qu Nanjing Zong Yi Yuan zhu ban, Zhonghua Nan Ke Xue Za Zhi Bian Ji Bu bian ji chu ban
#
#      PublicationFirstYear  PublicationEndYear      Frequency ISSN-Electronic  \
# 0     1990                NaN                  4 no. a year,  1477-4674
# 28    1999                NaN                  Irregular      NaN
# 84    1992                NaN                  Quarterly      1846-9558
# 88    1961                NaN                  Irregular      1600-5473
# 109   1973                NaN                  Irregular      NaN
# ...    ...                 ..                        ...      ...
# 4951  1966                NaN                  Monthly        1938-3223
# 5081  1958                NaN                  Semiannual     NaN
# 5161  1963                NaN                  Irregular      2333-0872
# 5187  1993                NaN                  Semiannual     2576-5221
# 5258  1995                NaN                  Bimonthly,     NaN
#
#      ISSN-Print ISSN-Linking Language TitleContinuationYN  IndexingStartDate  \
# 0     0955-2359  0955-2359    eng      N                   1990.0
# 28    1509-409X  1509-409X    eng      N                   2007.0
# 84    1330-0075  1330-0075    eng      N                   2003.0
# 88    0065-1591  0065-1591    eng      N                   1965.0
# 109   0301-5556  0301-5556    eng      N                   1965.0
# ...         ...        ...    ...     ..                      ...
# 4951  0040-4470  0040-4470    eng      N                   1965.0
# 5081  0042-6857  0042-6857    jpn      N                   1972.0
# 5161  0083-2057  0083-2057    eng      N                   1977.0
# 5187  2576-5213  2576-5213    eng      N                  NaN
# 5258  1009-3591  1009-3591    chi      N                   2002.0
#
#      CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     Y                  N             QIS
# 28    Y                  Y             IM
# 84    Y                  Y             IM
# 88    Y                  Y             IM
# 109   Y                  Y             IM
# ...  ..                 ..             ..
# 4951  Y                  Y             IM
# 5081  Y                  Y             IM
# 5161  Y                  Y             IM
# 5187  Y                  Y             QIS
# 5258  Y                  Y             IM
#
#                                                                IndexingSelectedURL  \
# 0     NaN
# 28    http://www.actabio.pwr.wroc.pl/archive.php
# 84    https://sciendo.com/journal/ACPH
# 88    http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1600-0447
# 109   https://link.springer.com/bookseries/102
# ...                                        ...
# 4951  http://www.texmed.org/Template.aspx?id=552
# 5081  https://www.jstage.jst.go.jp/browse/jsv
# 5161  http://www.cdc.gov/nchs/products/series/series02.htm
# 5187  https://www.nursing.virginia.edu/nursing-history/nursing-history-newsletter/
# 5258  NaN
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 28    Y                 1509-409X  NaN               NaN
# 84    Y                 1846-9558  yes                0.0
# 88    Y                 1600-5473  NaN               NaN
# 109   Y                 0301-5556  NaN               NaN
# ...  ..                       ...  ...                ..
# 4951  Y                 1938-3223  NaN               NaN
# 5081  Y                 0042-6857  NaN               NaN
# 5161  Y                 2333-0872  NaN               NaN
# 5187  Y                 2576-5221  NaN               NaN
# 5258  Y                 1009-3591  NaN               NaN
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 28   NaN                        NaN                        NaN
# 84    0.0                       NaN                        yes
# 88   NaN                        NaN                        NaN
# 109  NaN                        NaN                        NaN
# ...   ..                         ..                        ...
# 4951 NaN                        NaN                        NaN
# 5081 NaN                        NaN                        NaN
# 5161 NaN                        NaN                        NaN
# 5187 NaN                        NaN                        NaN
# 5258 NaN                        NaN                        NaN
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 28    NaN               NaN                                NaN
# 84    NaN               Acta Pharmaceutica                 1846-9558
# 88    NaN               NaN                                NaN
# 109   NaN               NaN                                NaN
# ...   ...               ...                                ...
# 4951  NaN               NaN                                NaN
# 5081  NaN               NaN                                NaN
# 5161  NaN               NaN                                NaN
# 5187  NaN               NaN                                NaN
# 5258  NaN               NaN                                NaN
#
#      issnp_sherpa                               url  publisher_id  \
# 0     0955-2359    https://academic.oup.com/tcbh     55.0
# 28    NaN          NaN                              NaN
# 84    NaN          https://sciendo.com/journal/ACPH  62066.0
# 88    NaN          NaN                              NaN
# 109   NaN          NaN                              NaN
# ...   ...          ...                               ..
# 4951  NaN          NaN                              NaN
# 5081  NaN          NaN                              NaN
# 5161  NaN          NaN                              NaN
# 5187  NaN          NaN                              NaN
# 5258  NaN          NaN                              NaN
#
#      publisher_country        publisher_type  \
# 0     gb                university_publisher
# 28    NaN               NaN
# 84    pl                commercial_publisher
# 88    NaN               NaN
# 109   NaN               NaN
# ...   ...               ...
# 4951  NaN               NaN
# 5081  NaN               NaN
# 5161  NaN               NaN
# 5187  NaN               NaN
# 5258  NaN               NaN
#
#                            publisher_url           publisher_name  \
# 0     https://academic.oup.com/journals/  Oxford University Press
# 28    NaN                                 NaN
# 84    https://sciendo.com/                Sciendo
# 88    NaN                                 NaN
# 109   NaN                                 NaN
# ...   ...                                 ...
# 4951  NaN                                 NaN
# 5081  NaN                                 NaN
# 5161  NaN                                 NaN
# 5187  NaN                                 NaN
# 5258  NaN                                 NaN
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 28    NaN                                               NaN
# 84    https://v2.sherpa.ac.uk/id/publisher_policy/3523  2014-04-10 10:12:04
# 88    NaN                                               NaN
# 109   NaN                                               NaN
# ...   ...                                               ...
# 4951  NaN                                               NaN
# 5081  NaN                                               NaN
# 5161  NaN                                               NaN
# 5187  NaN                                               NaN
# 5258  NaN                                               NaN
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old          DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 28    NaN                 NaN         NaN        NaN      NaN
# 84    2022-12-23 09:58:33  26385.0    1846-9558  NaN      Acta Pharmaceutica
# 88    NaN                 NaN         NaN        NaN      NaN
# 109   NaN                 NaN         NaN        NaN      NaN
# ...   ...                  ..         ...        ...      ...
# 4951  NaN                 NaN         NaN        NaN      NaN
# 5081  NaN                 NaN         NaN        NaN      NaN
# 5161  NaN                 NaN         NaN        NaN      NaN
# 5187  NaN                 NaN         NaN        NaN      NaN
# 5258  NaN                 NaN         NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal             DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN                  NaN         NaN
# 28    NaN        NaN       NaN                  NaN         NaN
# 84    1846-9558  No        2007-11-23T10:28:44Z  2007.0     CC BY-NC-ND
# 88    NaN        NaN       NaN                  NaN         NaN
# 109   NaN        NaN       NaN                  NaN         NaN
# ...   ...        ...       ...                   ..         ...
# 4951  NaN        NaN       NaN                  NaN         NaN
# 5081  NaN        NaN       NaN                  NaN         NaN
# 5161  NaN        NaN       NaN                  NaN         NaN
# 5187  NaN        NaN       NaN                  NaN         NaN
# 5258  NaN        NaN       NaN                  NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions     DOAJ_last_updated  \
# 0     NaN                                              NaN
# 28    NaN                                              NaN
# 84    No                                               2022-02-28T14:12:39Z
# 88    NaN                                              NaN
# 109   NaN                                              NaN
# ...   ...                                              ...
# 4951  NaN                                              NaN
# 5081  NaN                                              NaN
# 5161  NaN                                              NaN
# 5187  NaN                                              NaN
# 5258  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 28    NaN      NaN NaN           NaN                    NaN
# 84    Yes      yes NaN           NaN                    NaN
# 88    NaN      NaN NaN           NaN                    NaN
# 109   NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 4951  NaN      NaN NaN           NaN                    NaN
# 5081  NaN      NaN NaN           NaN                    NaN
# 5161  NaN      NaN NaN           NaN                    NaN
# 5187  NaN      NaN NaN           NaN                    NaN
# 5258  NaN      NaN NaN           NaN                    NaN
#
#      society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                 NaN                   NaN
# 28    NaN                 NaN                   NaN
# 84    NaN                 NaN                   NaN
# 88    NaN                 NaN                   NaN
# 109   NaN                 NaN                   NaN
# ...   ...                 ...                   ...
# 4951  NaN                 NaN                   NaN
# 5081  NaN                 NaN                   NaN
# 5161  NaN                 NaN                   NaN
# 5187  NaN                 NaN                   NaN
# 5258  NaN                 NaN                   NaN
#
#      post_flip_publisher flipped_access_model  apc_pre apc_post apc_now  \
# 0     NaN                 NaN                 NaN       NaN      NaN
# 28    NaN                 NaN                 NaN       NaN      NaN
# 84    NaN                 NaN                 NaN       NaN      NaN
# 88    NaN                 NaN                 NaN       NaN      NaN
# 109   NaN                 NaN                 NaN       NaN      NaN
# ...   ...                 ...                  ..       ...      ...
# 4951  NaN                 NaN                 NaN       NaN      NaN
# 5081  NaN                 NaN                 NaN       NaN      NaN
# 5161  NaN                 NaN                 NaN       NaN      NaN
# 5187  NaN                 NaN                 NaN       NaN      NaN
# 5258  NaN                 NaN                 NaN       NaN      NaN
#
#      discipline  flipped_oa  flipped_born_oa  flipped_embargo Reverse_Flip  \
# 0     NaN       NaN         NaN              NaN               NaN
# 28    NaN       NaN         NaN              NaN               NaN
# 84    NaN       NaN         NaN              NaN               NaN
# 88    NaN       NaN         NaN              NaN               NaN
# 109   NaN       NaN         NaN              NaN               NaN
# ...   ...        ..          ..               ..               ...
# 4951  NaN       NaN         NaN              NaN               NaN
# 5081  NaN       NaN         NaN              NaN               NaN
# 5161  NaN       NaN         NaN              NaN               NaN
# 5187  NaN       NaN         NaN              NaN               NaN
# 5258  NaN       NaN         NaN              NaN               NaN
#
#       CurrentlyIndexed  first_year  last_year   PMIDs    DOIs  PMIDs_2021  \
# 0     1.0               1990.0      2019.0     145.0   144.0  NaN
# 28    1.0               2007.0      2021.0     847.0   0.0     54.0
# 84    1.0               2003.0      2021.0     735.0   590.0   20.0
# 88    1.0               1959.0      2015.0     1664.0  1292.0 NaN
# 109   1.0               1973.0      2021.0     345.0   249.0   18.0
# ...   ...                  ...         ...       ...     ...    ...
# 4951  1.0               1965.0      2021.0     5615.0  0.0     50.0
# 5081  1.0               1972.0      2021.0     989.0   756.0   11.0
# 5161  1.0               1965.0      2021.0     185.0   9.0     1.0
# 5187  1.0               1999.0      2018.0     38.0    0.0    NaN
# 5258  1.0               2002.0      2021.0     3924.0  0.0     128.0
#
#       PMIDs_2022
# 0    NaN
# 28   NaN
# 84   NaN
# 88   NaN
# 109  NaN
# ...   ..
# 4951 NaN
# 5081 NaN
# 5161 NaN
# 5187 NaN
# 5258 NaN
#
# [95 rows x 75 columns]

# %% [markdown]
# ## Add unconquerable tag to journals

# %%
df_unconquerables
# Out:
#     NlmUniqueID  \
# 0    101714112
# 1    101269322
# 2    0431420
# 3    101206716
# 4    101194794
# ..         ...
# 778  9425197
# 779  7511141
# 780  7904962
# 781  7910681
# 782  8702287
#
#                                                                                                            Title  \
# 0    A&A practice
# 1    AACN advanced critical care
# 2    AANA journal
# 3    Acta biochimica et biophysica Sinica
# 4    Acta of bioengineering and biomechanics
# ..                                       ...
# 778  Zhonghua yi xue yi chuan xue za zhi = Zhonghua yixue yichuanxue zazhi = Chinese journal of medical genetics
# 779  Zhonghua yi xue za zhi
# 780  Zhonghua yu fang yi xue za zhi [Chinese journal of preventive medicine]
# 781  Zhonghua zhong liu za zhi [Chinese journal of oncology]
# 782  Zoological science
#
#                                MedlineTA        Country  \
# 0    A A Pract                            United States
# 1    AACN Adv Crit Care                   United States
# 2    AANA J                               United States
# 3    Acta Biochim Biophys Sin (Shanghai)  China
# 4    Acta Bioeng Biomech                  Poland
# ..                   ...                     ...
# 778  Zhonghua Yi Xue Yi Chuan Xue Za Zhi  China
# 779  Zhonghua Yi Xue Za Zhi               China
# 780  Zhonghua Yu Fang Yi Xue Za Zhi       China
# 781  Zhonghua Zhong Liu Za Zhi            China
# 782  Zoolog Sci                           Japan
#
#                             Place  \
# 0    [Philadelphia, PA]
# 1    Aliso Viejo, CA
# 2    Park Ridge, Ill.
# 3    Shanghai
# 4    Wrocław
# ..       ...
# 778  Chengdu, Sichuan, P.R. China
# 779  Beijing
# 780  Beijing
# 781  Peking
# 782  Tokyo, Japan
#
#                                                Publisher PublicationFirstYear  \
# 0    Wolters Kluwer Health, Inc.                          2018
# 1    American Association of Critical-Care Nurses (AACN)  2006
# 2    American Association of Nurse Anesthetists           1974
# 3    China Science Publishing & Media Ltd.                2004
# 4    Oficyna Wydawnicza Politechniki Wrocławskiej         1999
# ..                                            ...          ...
# 778  Sichuan University                                   1992
# 779  Zhonghua yi xue hui                                  1960
# 780  Zhonghua yi xue hui                                  1967
# 781  Chinese Medical Association                          1979
# 782  Zoological Society of Japan                          1984
#
#      PublicationEndYear     Frequency ISSN-Electronic ISSN-Print ISSN-Linking  \
# 0   NaN                  Biweekly      2575-3126       NaN        2575-3126
# 1   NaN                  Quarterly     1559-7776       1559-7768  1559-7768
# 2   NaN                  Bimonthly     2162-5239       0094-6354  0094-6354
# 3   NaN                  Monthly       1745-7270       1672-9145  1672-9145
# 4   NaN                  Irregular     NaN             1509-409X  1509-409X
# ..   ..                        ...     ...                   ...        ...
# 778 NaN                  Bimonthly     NaN             1003-9406  1003-9406
# 779 NaN                  Semimonthly,  NaN             0376-2491  0376-2491
# 780 NaN                  Bimonthly     NaN             0253-9624  0253-9624
# 781 NaN                  Bimonthly     NaN             0253-3766  0253-3766
# 782 NaN                  Monthly,      NaN             0289-0003  0289-0003
#
#     Language TitleContinuationYN  IndexingStartDate CurrentlyIndexedYN  \
# 0    eng      Y                   2018.0             Y
# 1    eng      Y                   2006.0             Y
# 2    eng      N                   1974.0             Y
# 3    eng      Y                   2004.0             Y
# 4    eng      N                   2007.0             Y
# ..   ...     ..                      ...            ..
# 778  chi      N                   1998.0             Y
# 779  chi      N                   1973.0             Y
# 780  chi      N                   1979.0             Y
# 781  chi      N                   1979.0             Y
# 782  eng      N                   2002.0             Y
#
#     IndexOnlineYN IndexingSubset  \
# 0    Y             IM
# 1    Y             N
# 2    Y             N
# 3    Y             IM
# 4    Y             IM
# ..  ..             ..
# 778  N             IM
# 779  N             IM
# 780  N             IM
# 781  N             IM
# 782  Y             IM
#
#                                                                                 IndexingSelectedURL  \
# 0    https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 1    https://aacnjournals.org/aacnacconline
# 2    https://www.aana.com/publications/aana-journal
# 3    https://academic.oup.com/abbs
# 4    http://www.actabio.pwr.wroc.pl/archive.php
# ..                                          ...
# 778  NaN
# 779  NaN
# 780  NaN
# 781  NaN
# 782  http://www.bioone.org/loi/jzoo
#
#     ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0    Y                 2575-3126  NaN               NaN
# 1    Y                 1559-7776  yes               NaN
# 2    Y                 2162-5239  NaN               NaN
# 3    Y                 1745-7270  NaN               NaN
# 4    Y                 1509-409X  NaN               NaN
# ..  ..                       ...  ...                ..
# 778  Y                 1003-9406  NaN               NaN
# 779  Y                 0376-2491  NaN               NaN
# 780  Y                 0253-9624  NaN               NaN
# 781  Y                 0253-3766  NaN               NaN
# 782  Y                 0289-0003  NaN               NaN
#
#      embargo_published_version  embargo_accepted_version  sherpa_oa_green  \
# 0   NaN                        NaN                       NaN
# 1   NaN                        NaN                       NaN
# 2   NaN                        NaN                       NaN
# 3   NaN                        NaN                       NaN
# 4   NaN                        NaN                       NaN
# ..   ..                         ..                        ..
# 778 NaN                        NaN                       NaN
# 779 NaN                        NaN                       NaN
# 780 NaN                        NaN                       NaN
# 781 NaN                        NaN                       NaN
# 782 NaN                        NaN                       NaN
#
#      additional_oa_fee                 title_sherpa issne_sherpa issnp_sherpa  \
# 0   NaN                 NaN                          NaN          NaN
# 1   NaN                 AACN Advanced Critical Care  1559-7776    1559-7768
# 2   NaN                 NaN                          NaN          NaN
# 3   NaN                 NaN                          NaN          NaN
# 4   NaN                 NaN                          NaN          NaN
# ..   ..                 ...                          ...          ...
# 778 NaN                 NaN                          NaN          NaN
# 779 NaN                 NaN                          NaN          NaN
# 780 NaN                 NaN                          NaN          NaN
# 781 NaN                 NaN                          NaN          NaN
# 782 NaN                 NaN                          NaN          NaN
#
#                               url  publisher_id publisher_country  \
# 0    NaN                          NaN            NaN
# 1    http://acc.aacnjournals.org/  663.0         us
# 2    NaN                          NaN            NaN
# 3    NaN                          NaN            NaN
# 4    NaN                          NaN            NaN
# ..   ...                           ..            ...
# 778  NaN                          NaN            NaN
# 779  NaN                          NaN            NaN
# 780  NaN                          NaN            NaN
# 781  NaN                          NaN            NaN
# 782  NaN                          NaN            NaN
#
#         publisher_type          publisher_url  \
# 0    NaN                NaN
# 1    society_publisher  https://www.aacn.org/
# 2    NaN                NaN
# 3    NaN                NaN
# 4    NaN                NaN
# ..   ...                ...
# 778  NaN                NaN
# 779  NaN                NaN
# 780  NaN                NaN
# 781  NaN                NaN
# 782  NaN                NaN
#
#                                    publisher_name  \
# 0    NaN
# 1    American Association of Critical Care Nurses
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 778  NaN
# 779  NaN
# 780  NaN
# 781  NaN
# 782  NaN
#
#                                           sherpa_uri       sherpa_created  \
# 0    NaN                                              NaN
# 1    https://v2.sherpa.ac.uk/id/publisher_policy/663  2010-08-24 15:05:09
# 2    NaN                                              NaN
# 3    NaN                                              NaN
# 4    NaN                                              NaN
# ..   ...                                              ...
# 778  NaN                                              NaN
# 779  NaN                                              NaN
# 780  NaN                                              NaN
# 781  NaN                                              NaN
# 782  NaN                                              NaN
#
#     sherpa_last_modified  sherpa_id  DOAJ_pissn  ISSN_old  DOAJ_title  \
# 0    NaN                 NaN        NaN         NaN       NaN
# 1    2022-07-08 08:42:33  10921.0   NaN         NaN       NaN
# 2    NaN                 NaN        NaN         NaN       NaN
# 3    NaN                 NaN        NaN         NaN       NaN
# 4    NaN                 NaN        NaN         NaN       NaN
# ..   ...                  ..         ..          ..        ..
# 778  NaN                 NaN        NaN         NaN       NaN
# 779  NaN                 NaN        NaN         NaN       NaN
# 780  NaN                 NaN        NaN         NaN       NaN
# 781  NaN                 NaN        NaN         NaN       NaN
# 782  NaN                 NaN        NaN         NaN       NaN
#
#      DOAJ_eissn  DOAJ_Seal  DOAJ_date  DOAJ_year  DOAJ_license  \
# 0   NaN         NaN        NaN        NaN        NaN
# 1   NaN         NaN        NaN        NaN        NaN
# 2   NaN         NaN        NaN        NaN        NaN
# 3   NaN         NaN        NaN        NaN        NaN
# 4   NaN         NaN        NaN        NaN        NaN
# ..   ..          ..         ..         ..         ..
# 778 NaN         NaN        NaN        NaN        NaN
# 779 NaN         NaN        NaN        NaN        NaN
# 780 NaN         NaN        NaN        NaN        NaN
# 781 NaN         NaN        NaN        NaN        NaN
# 782 NaN         NaN        NaN        NaN        NaN
#
#      DOAJ_author_holds_copyright_without_restrictions  DOAJ_last_updated  \
# 0   NaN                                               NaN
# 1   NaN                                               NaN
# 2   NaN                                               NaN
# 3   NaN                                               NaN
# 4   NaN                                               NaN
# ..   ..                                                ..
# 778 NaN                                               NaN
# 779 NaN                                               NaN
# 780 NaN                                               NaN
# 781 NaN                                               NaN
# 782 NaN                                               NaN
#
#      DOAJ_APC  DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0   NaN       NaN   NaN           NaN                    NaN
# 1   NaN       NaN   NaN           NaN                    NaN
# 2   NaN       NaN   NaN           NaN                    NaN
# 3   NaN       NaN   NaN           NaN                    NaN
# 4   NaN       NaN   NaN           NaN                    NaN
# ..   ..        ..    ..            ..                    ...
# 778 NaN       NaN   NaN           NaN                    NaN
# 779 NaN       NaN   NaN           NaN                    NaN
# 780 NaN       NaN   NaN           NaN                    NaN
# 781 NaN       NaN   NaN           NaN                    NaN
# 782 NaN       NaN    1984.0        2005.0                Japan
#
#              society_affiliation  other_sci_affiliation flipped_journal_name  \
# 0    NaN                         NaN                     NaN
# 1    NaN                         NaN                     NaN
# 2    NaN                         NaN                     NaN
# 3    NaN                         NaN                     NaN
# 4    NaN                         NaN                     NaN
# ..   ...                          ..                     ...
# 778  NaN                         NaN                     NaN
# 779  NaN                         NaN                     NaN
# 780  NaN                         NaN                     NaN
# 781  NaN                         NaN                     NaN
# 782  Zoological Society of Japan  0.0                    Zoological Science
#
#              post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0    NaN                          NaN                 NaN       NaN
# 1    NaN                          NaN                 NaN       NaN
# 2    NaN                          NaN                 NaN       NaN
# 3    NaN                          NaN                 NaN       NaN
# 4    NaN                          NaN                 NaN       NaN
# ..   ...                          ...                  ..       ...
# 778  NaN                          NaN                 NaN       NaN
# 779  NaN                          NaN                 NaN       NaN
# 780  NaN                          NaN                 NaN       NaN
# 781  NaN                          NaN                 NaN       NaN
# 782  Zoological Society of Japan  Subscription        NaN       -
#
#     apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0    NaN     NaN       NaN         NaN              NaN
# 1    NaN     NaN       NaN         NaN              NaN
# 2    NaN     NaN       NaN         NaN              NaN
# 3    NaN     NaN       NaN         NaN              NaN
# 4    NaN     NaN       NaN         NaN              NaN
# ..   ...     ...        ..          ..               ..
# 778  NaN     NaN       NaN         NaN              NaN
# 779  NaN     NaN       NaN         NaN              NaN
# 780  NaN     NaN       NaN         NaN              NaN
# 781  NaN     NaN       NaN         NaN              NaN
# 782  -       LS         1.0         0.0             NaN
#
#     Reverse_Flip not_sherpa_and_not_doaj_or_not_oa  unconquerables
# 0    NaN          yes                               1.0
# 1    NaN          yes                               1.0
# 2    NaN          yes                               1.0
# 3    NaN          yes                               1.0
# 4    NaN          yes                               1.0
# ..   ...          ...                               ...
# 778  NaN          yes                               1.0
# 779  NaN          yes                               1.0
# 780  NaN          yes                               1.0
# 781  NaN          yes                               1.0
# 782  yes          yes                               1.0
#
# [783 rows x 70 columns]

# %%
# merge
df_journals = df_journals.merge(df_unconquerables[['NlmUniqueID', 'unconquerables']], on='NlmUniqueID', how='left')
df_journals
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0     9015384     20 century British history   20 Century Br Hist
# 1     101714112   A&A practice                 A A Pract
# 2     101269322   AACN advanced critical care  AACN Adv Crit Care
# 3     0431420     AANA journal                 AANA J
# 4     101223209   The AAPS journal             AAPS J
# ...         ...                ...                ...
# 5274  8702287     Zoological science           Zoolog Sci
# 5275  9435608     Zoology (Jena, Germany)      Zoology (Jena)
# 5276  101300786   Zoonoses and public health   Zoonoses Public Health
# 5277  101179386   Zootaxa                      Zootaxa
# 5278  9309124     Zygote (Cambridge, England)  Zygote
#
#             Country                     Place  \
# 0     England        Eynsham, Oxford
# 1     United States  [Philadelphia, PA]
# 2     United States  Aliso Viejo, CA
# 3     United States  Park Ridge, Ill.
# 4     United States  Arlington, Va., USA
# ...             ...                  ...
# 5274  Japan          Tokyo, Japan
# 5275  Germany        Jena, Germany
# 5276  Germany        Berlin, Germany
# 5277  New Zealand    Auckland, N.Z.
# 5278  England        Cambridge ; New York, NY
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency  \
# 0     1990                NaN                  4 no. a year,
# 1     2018                NaN                  Biweekly
# 2     2006                NaN                  Quarterly
# 3     1974                NaN                  Bimonthly
# 4     2004                NaN                  Four no. a year
# ...    ...                 ..                              ...
# 5274  1984                NaN                  Monthly,
# 5275  1994                NaN                  Six no. a year,
# 5276  2007                NaN                  Ten no. a year
# 5277  2001                NaN                  Irregular
# 5278  1993                NaN                  Quarterly,
#
#      ISSN-Electronic ISSN-Print ISSN-Linking Language TitleContinuationYN  \
# 0     1477-4674       0955-2359  0955-2359    eng      N
# 1     2575-3126       NaN        2575-3126    eng      Y
# 2     1559-7776       1559-7768  1559-7768    eng      Y
# 3     2162-5239       0094-6354  0094-6354    eng      N
# 4     1550-7416       NaN        1550-7416    eng      Y
# ...         ...       ...              ...    ...     ..
# 5274  NaN             0289-0003  0289-0003    eng      N
# 5275  1873-2720       0944-2006  0944-2006    eng      N
# 5276  1863-2378       1863-1959  1863-1959    eng      Y
# 5277  1175-5334       1175-5326  1175-5326    eng      N
# 5278  1469-8730       0967-1994  0967-1994    eng      N
#
#       IndexingStartDate CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0     1990.0             Y                  N             QIS
# 1     2018.0             Y                  Y             IM
# 2     2006.0             Y                  Y             N
# 3     1974.0             Y                  Y             N
# 4     2004.0             Y                  Y             IM
# ...      ...            ..                 ..             ..
# 5274  2002.0             Y                  Y             IM
# 5275  2005.0             Y                  Y             IM
# 5276  2007.0             Y                  Y             IM
# 5277  2013.0             Y                  Y             IM
# 5278  1993.0             Y                  Y             IM
#
#                                                                                  IndexingSelectedURL  \
# 0     NaN
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=ovid&PAGE=toc&D=ovft&AN=02054229-000000000-00000
# 2     https://aacnjournals.org/aacnacconline
# 3     https://www.aana.com/publications/aana-journal
# 4     https://link.springer.com/journal/12248
# ...                                       ...
# 5274  http://www.bioone.org/loi/jzoo
# 5275  https://www.sciencedirect.com/journal/zoology
# 5276  http://onlinelibrary.wiley.com/journal/10.1111/(ISSN)1863-2378
# 5277  http://www.mapress.com/j/zt/
# 5278  https://www.cambridge.org/core/journals/zygote
#
#      ReportedMedlineYN       ISSN sherpa_has_oa_path  embargo  \
# 0     Y                 1477-4674  yes                24.0
# 1     Y                 2575-3126  NaN               NaN
# 2     Y                 1559-7776  yes               NaN
# 3     Y                 2162-5239  NaN               NaN
# 4     Y                 1550-7416  yes                12.0
# ...  ..                       ...  ...                 ...
# 5274  Y                 0289-0003  NaN               NaN
# 5275  Y                 1873-2720  yes                12.0
# 5276  Y                 1863-2378  yes                12.0
# 5277  Y                 1175-5334  yes               NaN
# 5278  Y                 1469-8730  yes                6.0
#
#       embargo_published_version  embargo_accepted_version sherpa_oa_green  \
# 0    NaN                         24.0                      yes
# 1    NaN                        NaN                        NaN
# 2    NaN                        NaN                        NaN
# 3    NaN                        NaN                        NaN
# 4    NaN                         12.0                      yes
# ...   ..                          ...                      ...
# 5274 NaN                        NaN                        NaN
# 5275 NaN                         12.0                      yes
# 5276 NaN                         12.0                      yes
# 5277 NaN                        NaN                        NaN
# 5278 NaN                         6.0                       yes
#
#      additional_oa_fee                       title_sherpa issne_sherpa  \
# 0     yes               Twentieth Century British History  1477-4674
# 1     NaN               NaN                                NaN
# 2     NaN               AACN Advanced Critical Care        1559-7776
# 3     NaN               NaN                                NaN
# 4     yes               AAPS Journal                       NaN
# ...   ...                        ...                       ...
# 5274  NaN               NaN                                NaN
# 5275  yes               NaN                                NaN
# 5276  yes               Zoonoses and Public Health         1863-2378
# 5277  yes               Zootaxa                            1175-5334
# 5278  yes               Zygote                             1469-8730
#
#      issnp_sherpa  \
# 0     0955-2359
# 1     NaN
# 2     1559-7768
# 3     NaN
# 4     1550-7416
# ...         ...
# 5274  NaN
# 5275  NaN
# 5276  1863-1959
# 5277  1175-5326
# 5278  0967-1994
#
#                                                               url  \
# 0     https://academic.oup.com/tcbh
# 1     NaN
# 2     http://acc.aacnjournals.org/
# 3     NaN
# 4     http://link.springer.com/journal/12248
# ...                                      ...
# 5274  NaN
# 5275  NaN
# 5276  https://onlinelibrary.wiley.com/journal/18632378
# 5277  https://www.mapress.com/zt/
# 5278  http://journals.cambridge.org/action/displayJournal?jid=ZYG
#
#       publisher_id publisher_country        publisher_type  \
# 0     55.0          gb                university_publisher
# 1    NaN            NaN               NaN
# 2     663.0         us                society_publisher
# 3    NaN            NaN               NaN
# 4     313.0         us                client_organisation
# ...     ...         ..                                ...
# 5274 NaN            NaN               NaN
# 5275 NaN            NaN               NaN
# 5276  580.0         us                commercial_publisher
# 5277  284.0         nz                commercial_publisher
# 5278  27.0          gb                university_publisher
#
#                            publisher_url  \
# 0     https://academic.oup.com/journals/
# 1     NaN
# 2     https://www.aacn.org/
# 3     NaN
# 4     https://www.aaps.org/home
# ...                         ...
# 5274  NaN
# 5275  NaN
# 5276  https://www.wiley.com/en-gb
# 5277  https://www.mapress.com/
# 5278  https://www.cambridge.org/
#
#                                          publisher_name  \
# 0     Oxford University Press
# 1     NaN
# 2     American Association of Critical Care Nurses
# 3     NaN
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  NaN
# 5275  NaN
# 5276  Wiley
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#                                             sherpa_uri       sherpa_created  \
# 0     https://v2.sherpa.ac.uk/id/publisher_policy/1112  2010-07-15 16:04:39
# 1     NaN                                               NaN
# 2     https://v2.sherpa.ac.uk/id/publisher_policy/663   2010-08-24 15:05:09
# 3     NaN                                               NaN
# 4     https://v2.sherpa.ac.uk/id/publisher_policy/3291  2010-09-15 13:16:19
# ...                                                ...                  ...
# 5274  NaN                                               NaN
# 5275  NaN                                               NaN
# 5276  https://v2.sherpa.ac.uk/id/publisher_policy/2050  2010-07-20 14:58:33
# 5277  https://v2.sherpa.ac.uk/id/publisher_policy/284   2010-06-30 17:47:50
# 5278  https://v2.sherpa.ac.uk/id/publisher_policy/5000  2010-07-19 16:07:37
#
#      sherpa_last_modified  sherpa_id DOAJ_pissn ISSN_old DOAJ_title  \
# 0     2022-07-26 10:25:23  1406.0     NaN        NaN      NaN
# 1     NaN                 NaN         NaN        NaN      NaN
# 2     2022-07-08 08:42:33  10921.0    NaN        NaN      NaN
# 3     NaN                 NaN         NaN        NaN      NaN
# 4     2023-01-05 14:55:40  16180.0    NaN        NaN      NaN
# ...                   ...      ...    ...        ...      ...
# 5274  NaN                 NaN         NaN        NaN      NaN
# 5275  NaN                  15919.0    NaN        NaN      NaN
# 5276  2022-07-27 12:37:58  2555.0     NaN        NaN      NaN
# 5277  2022-07-15 08:53:17  6.0        NaN        NaN      NaN
# 5278  2022-06-16 13:58:04  2242.0     NaN        NaN      NaN
#
#      DOAJ_eissn DOAJ_Seal DOAJ_date  DOAJ_year DOAJ_license  \
# 0     NaN        NaN       NaN      NaN         NaN
# 1     NaN        NaN       NaN      NaN         NaN
# 2     NaN        NaN       NaN      NaN         NaN
# 3     NaN        NaN       NaN      NaN         NaN
# 4     NaN        NaN       NaN      NaN         NaN
# ...   ...        ...       ...       ..         ...
# 5274  NaN        NaN       NaN      NaN         NaN
# 5275  NaN        NaN       NaN      NaN         NaN
# 5276  NaN        NaN       NaN      NaN         NaN
# 5277  NaN        NaN       NaN      NaN         NaN
# 5278  NaN        NaN       NaN      NaN         NaN
#
#      DOAJ_author_holds_copyright_without_restrictions DOAJ_last_updated  \
# 0     NaN                                              NaN
# 1     NaN                                              NaN
# 2     NaN                                              NaN
# 3     NaN                                              NaN
# 4     NaN                                              NaN
# ...   ...                                              ...
# 5274  NaN                                              NaN
# 5275  NaN                                              NaN
# 5276  NaN                                              NaN
# 5277  NaN                                              NaN
# 5278  NaN                                              NaN
#
#      DOAJ_APC DOAJ  year_founded  year_reverse_flipped journal_location  \
# 0     NaN      NaN NaN           NaN                    NaN
# 1     NaN      NaN NaN           NaN                    NaN
# 2     NaN      NaN NaN           NaN                    NaN
# 3     NaN      NaN NaN           NaN                    NaN
# 4     NaN      NaN NaN           NaN                    NaN
# ...   ...      ...  ..            ..                    ...
# 5274  NaN      NaN  1984.0        2005.0                Japan
# 5275  NaN      NaN NaN           NaN                    NaN
# 5276  NaN      NaN NaN           NaN                    NaN
# 5277  NaN      NaN NaN           NaN                    NaN
# 5278  NaN      NaN NaN           NaN                    NaN
#
#               society_affiliation other_sci_affiliation flipped_journal_name  \
# 0     NaN                          NaN                   NaN
# 1     NaN                          NaN                   NaN
# 2     NaN                          NaN                   NaN
# 3     NaN                          NaN                   NaN
# 4     NaN                          NaN                   NaN
# ...   ...                          ...                   ...
# 5274  Zoological Society of Japan  0                     Zoological Science
# 5275  NaN                          NaN                   NaN
# 5276  NaN                          NaN                   NaN
# 5277  NaN                          NaN                   NaN
# 5278  NaN                          NaN                   NaN
#
#               post_flip_publisher flipped_access_model  apc_pre apc_post  \
# 0     NaN                          NaN                 NaN       NaN
# 1     NaN                          NaN                 NaN       NaN
# 2     NaN                          NaN                 NaN       NaN
# 3     NaN                          NaN                 NaN       NaN
# 4     NaN                          NaN                 NaN       NaN
# ...   ...                          ...                  ..       ...
# 5274  Zoological Society of Japan  Subscription        NaN       -
# 5275  NaN                          NaN                 NaN       NaN
# 5276  NaN                          NaN                 NaN       NaN
# 5277  NaN                          NaN                 NaN       NaN
# 5278  NaN                          NaN                 NaN       NaN
#
#      apc_now discipline  flipped_oa  flipped_born_oa  flipped_embargo  \
# 0     NaN     NaN       NaN         NaN              NaN
# 1     NaN     NaN       NaN         NaN              NaN
# 2     NaN     NaN       NaN         NaN              NaN
# 3     NaN     NaN       NaN         NaN              NaN
# 4     NaN     NaN       NaN         NaN              NaN
# ...   ...     ...        ..          ..               ..
# 5274  -       LS         1.0         0.0             NaN
# 5275  NaN     NaN       NaN         NaN              NaN
# 5276  NaN     NaN       NaN         NaN              NaN
# 5277  NaN     NaN       NaN         NaN              NaN
# 5278  NaN     NaN       NaN         NaN              NaN
#
#      Reverse_Flip  CurrentlyIndexed  first_year  last_year    PMIDs     DOIs  \
# 0     NaN          1.0               1990.0      2019.0     145.0    144.0
# 1     NaN          1.0               2018.0      2022.0     999.0    999.0
# 2     NaN          1.0               2006.0      2022.0     851.0    837.0
# 3     NaN          1.0               1974.0      2022.0     2547.0   0.0
# 4     NaN          1.0               2004.0      2022.0     1976.0   1976.0
# ...   ...          ...                  ...         ...        ...      ...
# 5274  yes          1.0               1987.0      2022.0     2680.0   2635.0
# 5275  NaN          1.0               2001.0      2022.0     1019.0   1017.0
# 5276  NaN          1.0               2007.0      2022.0     1445.0   1444.0
# 5277  NaN          1.0               2008.0      2022.0     20965.0  20886.0
# 5278  NaN          1.0               1993.0      2022.0     1709.0   1641.0
#
#       PMIDs_2021  PMIDs_2022  unconquerables
# 0    NaN         NaN         NaN
# 1     187.0       73.0        1.0
# 2     59.0        37.0        1.0
# 3     75.0        60.0        1.0
# 4     123.0       109.0      NaN
# ...     ...         ...       ..
# 5274  62.0        53.0        1.0
# 5275  74.0        41.0       NaN
# 5276  102.0       117.0      NaN
# 5277  2316.0      1315.0     NaN
# 5278  75.0        126.0      NaN
#
# [5279 rows x 76 columns]

# %%
df_journals.loc[df_journals['unconquerables'] == 1].shape[0]
# Out:
# 783

# %% [markdown]
# ## Export journals data
#
# Choice of fileds to keep:
#  * NlmUniqueID
#  * Country
#  * Publisher
#  * PublicationFirstYear
#  * PublicationEndYear
#  * Frequency
#  * Language
#  * first_year
#  * last_year
#  * PMIDs
#  * PMIDs 2021
#  * PMIDs 2022
#  * DOIs
#  * unconquerables

# %%
# csv export
df_journals[['NlmUniqueID',
             'Title',
             'Country',
             'Publisher',
             'PublicationFirstYear',
             'PublicationEndYear',
             'Frequency',
             'Language',
             'first_year',
             'last_year',
             'PMIDs',
             'PMIDs_2021',
             'PMIDs_2022',
             'DOIs',
             'unconquerables'            
            ]].to_csv('results/2023/journals_final_data.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# ## Add unconquerable tag to MeSH

# %%
# Open MeSH data
df_mesh = pd.read_csv('results/2023/MeshHeadings.tsv', delimiter='\t', header=0)
df_mesh
# Out:
#       NlmUniqueID            MeshHeading  sherpa_id_x sherpa_has_oa_path  \
# 0      9015384     History                1406.0       yes
# 1      9015384     United Kingdom         1406.0       yes
# 2      101637720   Anesthesiology        NaN           NaN
# 3      101714112   Anesthesiology        NaN           NaN
# 4      101269322   Critical Care          10921.0      yes
# ...          ...             ...              ...      ...
# 26785  21830020R   History of Medicine   NaN           NaN
# 26786  0233767     Dentistry             NaN           NaN
# 26787  9309124     Embryonic Development  2242.0       yes
# 26788  9309124     Fetal Development      2242.0       yes
# 26789  9309124     Zygote                 2242.0       yes
#
#        embargo  sherpa_id_y  embargo_published_version  \
# 0      24.0     1406.0      NaN
# 1      24.0     1406.0      NaN
# 2     NaN      NaN          NaN
# 3     NaN      NaN          NaN
# 4     NaN      NaN          NaN
# ...    ..       ..           ..
# 26785 NaN      NaN          NaN
# 26786 NaN      NaN          NaN
# 26787  6.0      2242.0      NaN
# 26788  6.0      2242.0      NaN
# 26789  6.0      2242.0      NaN
#
#        embargo_accepted_version sherpa_oa_green  sherpa_id additional_oa_fee  \
# 0      24.0                      yes             1406.0     yes
# 1      24.0                      yes             1406.0     yes
# 2     NaN                        NaN            NaN         NaN
# 3     NaN                        NaN            NaN         NaN
# 4     NaN                        NaN            NaN         NaN
# ...    ..                        ...             ..         ...
# 26785 NaN                        NaN            NaN         NaN
# 26786 NaN                        NaN            NaN         NaN
# 26787  6.0                       yes             2242.0     yes
# 26788  6.0                       yes             2242.0     yes
# 26789  6.0                       yes             2242.0     yes
#
#       sherpa_oa_hybrid DOAJ_Seal DOAJ Reverse_Flip  flipped_embargo  \
# 0      hybrid or gold   NaN       NaN  NaN         NaN
# 1      hybrid or gold   NaN       NaN  NaN         NaN
# 2      NaN              NaN       NaN  NaN         NaN
# 3      NaN              NaN       NaN  NaN         NaN
# 4      NaN              NaN       NaN  NaN         NaN
# ...    ...              ...       ...  ...          ..
# 26785  NaN              NaN       NaN  NaN         NaN
# 26786  NaN              NaN       NaN  NaN         NaN
# 26787  hybrid or gold   NaN       NaN  NaN         NaN
# 26788  hybrid or gold   NaN       NaN  NaN         NaN
# 26789  hybrid or gold   NaN       NaN  NaN         NaN
#
#       flipped_access_model  flipped_born_oa
# 0      NaN                 NaN
# 1      NaN                 NaN
# 2      NaN                 NaN
# 3      NaN                 NaN
# 4      NaN                 NaN
# ...    ...                  ..
# 26785  NaN                 NaN
# 26786  NaN                 NaN
# 26787  NaN                 NaN
# 26788  NaN                 NaN
# 26789  NaN                 NaN
#
# [26790 rows x 18 columns]

# %%
# convert to str
df_mesh.loc[df_mesh['NlmUniqueID'].notna(), 'NlmUniqueID'] = df_mesh['NlmUniqueID'].astype(str)

# %%
# merge
df_mesh = df_mesh.merge(df_journals[['NlmUniqueID',
             'Country',
             'Publisher',
             'PublicationFirstYear',
             'PublicationEndYear',
             'Frequency',
             'Language',
             'first_year',
             'last_year',
             'PMIDs',
             'DOIs',
             'unconquerables'            
            ]], on='NlmUniqueID', how='left')
df_mesh
# Out:
#       NlmUniqueID            MeshHeading  sherpa_id_x sherpa_has_oa_path  \
# 0      9015384     History                1406.0       yes
# 1      9015384     United Kingdom         1406.0       yes
# 2      101637720   Anesthesiology        NaN           NaN
# 3      101714112   Anesthesiology        NaN           NaN
# 4      101269322   Critical Care          10921.0      yes
# ...          ...             ...              ...      ...
# 26785  21830020R   History of Medicine   NaN           NaN
# 26786  0233767     Dentistry             NaN           NaN
# 26787  9309124     Embryonic Development  2242.0       yes
# 26788  9309124     Fetal Development      2242.0       yes
# 26789  9309124     Zygote                 2242.0       yes
#
#        embargo  sherpa_id_y  embargo_published_version  \
# 0      24.0     1406.0      NaN
# 1      24.0     1406.0      NaN
# 2     NaN      NaN          NaN
# 3     NaN      NaN          NaN
# 4     NaN      NaN          NaN
# ...    ..       ..           ..
# 26785 NaN      NaN          NaN
# 26786 NaN      NaN          NaN
# 26787  6.0      2242.0      NaN
# 26788  6.0      2242.0      NaN
# 26789  6.0      2242.0      NaN
#
#        embargo_accepted_version sherpa_oa_green  sherpa_id additional_oa_fee  \
# 0      24.0                      yes             1406.0     yes
# 1      24.0                      yes             1406.0     yes
# 2     NaN                        NaN            NaN         NaN
# 3     NaN                        NaN            NaN         NaN
# 4     NaN                        NaN            NaN         NaN
# ...    ..                        ...             ..         ...
# 26785 NaN                        NaN            NaN         NaN
# 26786 NaN                        NaN            NaN         NaN
# 26787  6.0                       yes             2242.0     yes
# 26788  6.0                       yes             2242.0     yes
# 26789  6.0                       yes             2242.0     yes
#
#       sherpa_oa_hybrid DOAJ_Seal DOAJ Reverse_Flip  flipped_embargo  \
# 0      hybrid or gold   NaN       NaN  NaN         NaN
# 1      hybrid or gold   NaN       NaN  NaN         NaN
# 2      NaN              NaN       NaN  NaN         NaN
# 3      NaN              NaN       NaN  NaN         NaN
# 4      NaN              NaN       NaN  NaN         NaN
# ...    ...              ...       ...  ...          ..
# 26785  NaN              NaN       NaN  NaN         NaN
# 26786  NaN              NaN       NaN  NaN         NaN
# 26787  hybrid or gold   NaN       NaN  NaN         NaN
# 26788  hybrid or gold   NaN       NaN  NaN         NaN
# 26789  hybrid or gold   NaN       NaN  NaN         NaN
#
#       flipped_access_model  flipped_born_oa        Country  \
# 0      NaN                 NaN               England
# 1      NaN                 NaN               England
# 2      NaN                 NaN               NaN
# 3      NaN                 NaN               United States
# 4      NaN                 NaN               United States
# ...    ...                  ..                         ...
# 26785  NaN                 NaN               NaN
# 26786  NaN                 NaN               NaN
# 26787  NaN                 NaN               England
# 26788  NaN                 NaN               England
# 26789  NaN                 NaN               England
#
#                                                  Publisher  \
# 0      Oxford University Press
# 1      Oxford University Press
# 2      NaN
# 3      Wolters Kluwer Health, Inc.
# 4      American Association of Critical-Care Nurses (AACN)
# ...                                                    ...
# 26785  NaN
# 26786  NaN
# 26787  Cambridge University Press
# 26788  Cambridge University Press
# 26789  Cambridge University Press
#
#       PublicationFirstYear  PublicationEndYear      Frequency Language  \
# 0      1990                NaN                  4 no. a year,  eng
# 1      1990                NaN                  4 no. a year,  eng
# 2      NaN                 NaN                  NaN            NaN
# 3      2018                NaN                  Biweekly       eng
# 4      2006                NaN                  Quarterly      eng
# ...     ...                 ..                        ...      ...
# 26785  NaN                 NaN                  NaN            NaN
# 26786  NaN                 NaN                  NaN            NaN
# 26787  1993                NaN                  Quarterly,     eng
# 26788  1993                NaN                  Quarterly,     eng
# 26789  1993                NaN                  Quarterly,     eng
#
#        first_year  last_year   PMIDs    DOIs  unconquerables
# 0      1990.0      2019.0     145.0   144.0  NaN
# 1      1990.0      2019.0     145.0   144.0  NaN
# 2     NaN         NaN        NaN     NaN     NaN
# 3      2018.0      2022.0     999.0   999.0   1.0
# 4      2006.0      2022.0     851.0   837.0   1.0
# ...       ...         ...       ...     ...   ...
# 26785 NaN         NaN        NaN     NaN     NaN
# 26786 NaN         NaN        NaN     NaN     NaN
# 26787  1993.0      2022.0     1709.0  1641.0 NaN
# 26788  1993.0      2022.0     1709.0  1641.0 NaN
# 26789  1993.0      2022.0     1709.0  1641.0 NaN
#
# [26790 rows x 29 columns]

# %%
# take the number of journals for each MeSH
df_mesh_counts = df_mesh[['MeshHeading', 'NlmUniqueID']].groupby(by='MeshHeading').count()
# reset index and rename columns
df_mesh_counts = df_mesh_counts.reset_index(drop=False)
df_mesh_counts = df_mesh_counts.rename(columns={'NlmUniqueID' : 'count'})
df_mesh_counts
# Out:
#                                 MeshHeading  count
# 0     AIDS Dementia Complex                  1
# 1     AIDS Vaccines                          2
# 2     AIDS-Related Opportunistic Infections  1
# 3     Abdomen                                3
# 4     Abnormalities, Drug-Induced            5
# ...                           ...           ..
# 2658  Zimbabwe                               3
# 2659  Zoology                                33
# 2660  Zoonoses                               5
# 2661  Zygote                                 1
# 2662  alpha-Fetoproteins                     2
#
# [2663 rows x 2 columns]

# %%
# take the number of journals for each MeSH for unconquerables
df_mesh_unconquerables_counts = df_mesh.loc[df_mesh['unconquerables'] == 1][['MeshHeading', 'NlmUniqueID']].groupby(by='MeshHeading').count()
# reset index and rename columns
df_mesh_unconquerables_counts = df_mesh_unconquerables_counts.reset_index(drop=False)
df_mesh_unconquerables_counts = df_mesh_unconquerables_counts.rename(columns={'NlmUniqueID' : 'unconquerables_count'})
df_mesh_unconquerables_counts
# Out:
#                             MeshHeading  unconquerables_count
# 0    Accidents                           1
# 1    Accidents, Occupational             1
# 2    Accidents, Traffic                  1
# 3    Acquired Immunodeficiency Syndrome  2
# 4    Actuarial Analysis                  1
# ..                  ...                 ..
# 608  Weights and Measures                1
# 609  Wound Healing                       1
# 610  Wounds and Injuries                 9
# 611  Yoga                                1
# 612  Zoology                             2
#
# [613 rows x 2 columns]

# %%
# merge
df_mesh_counts = df_mesh_counts.merge(df_mesh_unconquerables_counts, on='MeshHeading', how='left')
df_mesh_counts
# Out:
#                                 MeshHeading  count  unconquerables_count
# 0     AIDS Dementia Complex                  1     NaN
# 1     AIDS Vaccines                          2     NaN
# 2     AIDS-Related Opportunistic Infections  1     NaN
# 3     Abdomen                                3     NaN
# 4     Abnormalities, Drug-Induced            5     NaN
# ...                           ...           ..      ..
# 2658  Zimbabwe                               3     NaN
# 2659  Zoology                                33     2.0
# 2660  Zoonoses                               5     NaN
# 2661  Zygote                                 1     NaN
# 2662  alpha-Fetoproteins                     2     NaN
#
# [2663 rows x 3 columns]

# %%
# replace NaN by 0
df_mesh_counts.loc[df_mesh_counts['unconquerables_count'].isna(), 'unconquerables_count'] = 0
df_mesh_counts.loc[df_mesh_counts['unconquerables_count'].notna(), 'unconquerables_count'] = df_mesh_counts['unconquerables_count'].astype(int)
df_mesh_counts
# Out:
#                                 MeshHeading  count  unconquerables_count
# 0     AIDS Dementia Complex                  1      0
# 1     AIDS Vaccines                          2      0
# 2     AIDS-Related Opportunistic Infections  1      0
# 3     Abdomen                                3      0
# 4     Abnormalities, Drug-Induced            5      0
# ...                           ...           ..     ..
# 2658  Zimbabwe                               3      0
# 2659  Zoology                                33     2
# 2660  Zoonoses                               5      0
# 2661  Zygote                                 1      0
# 2662  alpha-Fetoproteins                     2      0
#
# [2663 rows x 3 columns]

# %%
# add ratios
df_mesh_counts['ratio'] = df_mesh_counts['unconquerables_count'] / df_mesh_counts['count']
df_mesh_counts
# Out:
#                                 MeshHeading  count  unconquerables_count  \
# 0     AIDS Dementia Complex                  1      0
# 1     AIDS Vaccines                          2      0
# 2     AIDS-Related Opportunistic Infections  1      0
# 3     Abdomen                                3      0
# 4     Abnormalities, Drug-Induced            5      0
# ...                           ...           ..     ..
# 2658  Zimbabwe                               3      0
# 2659  Zoology                                33     2
# 2660  Zoonoses                               5      0
# 2661  Zygote                                 1      0
# 2662  alpha-Fetoproteins                     2      0
#
#          ratio
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
# ...        ...
# 2658  0.000000
# 2659  0.060606
# 2660  0.000000
# 2661  0.000000
# 2662  0.000000
#
# [2663 rows x 4 columns]

# %%
# test high ratios (> 0.15)
df_mesh_counts.loc[df_mesh_counts['ratio'] > 0.15].sort_values(by='ratio', ascending=False)
# Out:
#                          MeshHeading  count  unconquerables_count     ratio
# 22    Actuarial Analysis              1      1                     1.000000
# 887   Excipients                      1      1                     1.000000
# 1515  Maternal-Child Health Services  1      1                     1.000000
# 1511  Maternal Health                 1      1                     1.000000
# 1487  Mali                            1      1                     1.000000
# ...    ...                           ..     ..                          ...
# 1185  History of Nursing              6      1                     0.166667
# 914   Family Practice                 38     6                     0.157895
# 1494  Managed Care Programs           26     4                     0.153846
# 633   Dental Hygienists               13     2                     0.153846
# 885   Evidence-Based Medicine         26     4                     0.153846
#
# [271 rows x 4 columns]

# %%
# test highest ratios (= 1)
df_mesh_counts.loc[df_mesh_counts['ratio'] == 1].sort_values(by='count', ascending=False)
# Out:
#                                      MeshHeading  count  unconquerables_count  \
# 708   Diving                                      2      2
# 2123  Psychoanalytic Therapy                      2      2
# 1241  Hyperbaric Oxygenation                      2      2
# 1651  Moxibustion                                 1      1
# 1951  Peritoneal Dialysis, Continuous Ambulatory  1      1
# ...                                          ... ..     ..
# 993   Gastrointestinal Motility                   1      1
# 1099  Health Equity                               1      1
# 1106  Health Inequities                           1      1
# 1175  Hispanic Americans                          1      1
# 2654  Yoga                                        1      1
#
#       ratio
# 708   1.0
# 2123  1.0
# 1241  1.0
# 1651  1.0
# 1951  1.0
# ...   ...
# 993   1.0
# 1099  1.0
# 1106  1.0
# 1175  1.0
# 2654  1.0
#
# [64 rows x 4 columns]

# %%
# export CSV
df_mesh_counts.sort_values(by='MeshHeading', ascending=True).to_csv('results/2023/mesh_counts.tsv', sep='\t', index=False)

# %% [markdown]
# ## Add unconquerable tag to Broad Journal Headings

# %%
import pandas as pd
# Open journals data
df_journals = pd.read_csv('results/2023/journals_final_data.tsv', delimiter='\t', header=0)
df_journals
# Out:
#      NlmUniqueID                        Title        Country  \
# 0     9015384     20 century British history   England
# 1     101714112   A&A practice                 United States
# 2     101269322   AACN advanced critical care  United States
# 3     0431420     AANA journal                 United States
# 4     101223209   The AAPS journal             United States
# ...         ...                ...                       ...
# 5274  8702287     Zoological science           Japan
# 5275  9435608     Zoology (Jena, Germany)      Germany
# 5276  101300786   Zoonoses and public health   Germany
# 5277  101179386   Zootaxa                      New Zealand
# 5278  9309124     Zygote (Cambridge, England)  England
#
#                                                 Publisher  \
# 0     Oxford University Press
# 1     Wolters Kluwer Health, Inc.
# 2     American Association of Critical-Care Nurses (AACN)
# 3     American Association of Nurse Anesthetists
# 4     American Association of Pharmaceutical Scientists
# ...                                                 ...
# 5274  Zoological Society of Japan
# 5275  Urban & Fischer
# 5276  Blackwell Verlag
# 5277  Magnolia Press
# 5278  Cambridge University Press
#
#      PublicationFirstYear  PublicationEndYear        Frequency Language  \
# 0     1990                NaN                  4 no. a year,    eng
# 1     2018                NaN                  Biweekly         eng
# 2     2006                NaN                  Quarterly        eng
# 3     1974                NaN                  Bimonthly        eng
# 4     2004                NaN                  Four no. a year  eng
# ...    ...                 ..                              ...  ...
# 5274  1984                NaN                  Monthly,         eng
# 5275  1994                NaN                  Six no. a year,  eng
# 5276  2007                NaN                  Ten no. a year   eng
# 5277  2001                NaN                  Irregular        eng
# 5278  1993                NaN                  Quarterly,       eng
#
#       first_year  last_year    PMIDs  PMIDs_2021  PMIDs_2022     DOIs  \
# 0     1990.0      2019.0     145.0   NaN         NaN          144.0
# 1     2018.0      2022.0     999.0    187.0       73.0        999.0
# 2     2006.0      2022.0     851.0    59.0        37.0        837.0
# 3     1974.0      2022.0     2547.0   75.0        60.0        0.0
# 4     2004.0      2022.0     1976.0   123.0       109.0       1976.0
# ...      ...         ...        ...     ...         ...          ...
# 5274  1987.0      2022.0     2680.0   62.0        53.0        2635.0
# 5275  2001.0      2022.0     1019.0   74.0        41.0        1017.0
# 5276  2007.0      2022.0     1445.0   102.0       117.0       1444.0
# 5277  2008.0      2022.0     20965.0  2316.0      1315.0      20886.0
# 5278  1993.0      2022.0     1709.0   75.0        126.0       1641.0
#
#       unconquerables
# 0    NaN
# 1     1.0
# 2     1.0
# 3     1.0
# 4    NaN
# ...   ..
# 5274  1.0
# 5275 NaN
# 5276 NaN
# 5277 NaN
# 5278 NaN
#
# [5279 rows x 15 columns]

# %%
# Open Broad Journal Headings
df_bjh = pd.read_csv('results/2023/BroadJournalHeadings.tsv', delimiter='\t', header=0)
df_bjh
# Out:
#       NlmUniqueID    BroadJournalHeading  sherpa_id_x sherpa_has_oa_path  \
# 0      9015384     History of Medicine    1406.0       yes
# 1      101637720   Anesthesiology        NaN           NaN
# 2      101714112   Anesthesiology        NaN           NaN
# 3      101269322   Critical Care          10921.0      yes
# 4      101269322   Nursing                10921.0      yes
# ...          ...       ...                    ...      ...
# 16386  0056272     Reproductive Medicine NaN           NaN
# 16387  0056272     Veterinary Medicine   NaN           NaN
# 16388  21830020R   History of Medicine   NaN           NaN
# 16389  0233767     Dentistry             NaN           NaN
# 16390  9309124     Embryology             2242.0       yes
#
#        embargo  sherpa_id_y  embargo_published_version  \
# 0      24.0     1406.0      NaN
# 1     NaN      NaN          NaN
# 2     NaN      NaN          NaN
# 3     NaN      NaN          NaN
# 4     NaN      NaN          NaN
# ...    ..       ..           ..
# 16386 NaN      NaN          NaN
# 16387 NaN      NaN          NaN
# 16388 NaN      NaN          NaN
# 16389 NaN      NaN          NaN
# 16390  6.0      2242.0      NaN
#
#        embargo_accepted_version sherpa_oa_green  sherpa_id additional_oa_fee  \
# 0      24.0                      yes             1406.0     yes
# 1     NaN                        NaN            NaN         NaN
# 2     NaN                        NaN            NaN         NaN
# 3     NaN                        NaN            NaN         NaN
# 4     NaN                        NaN            NaN         NaN
# ...    ..                        ...             ..         ...
# 16386 NaN                        NaN            NaN         NaN
# 16387 NaN                        NaN            NaN         NaN
# 16388 NaN                        NaN            NaN         NaN
# 16389 NaN                        NaN            NaN         NaN
# 16390  6.0                       yes             2242.0     yes
#
#       sherpa_oa_hybrid DOAJ_Seal DOAJ Reverse_Flip  flipped_embargo  \
# 0      hybrid or gold   NaN       NaN  NaN         NaN
# 1      NaN              NaN       NaN  NaN         NaN
# 2      NaN              NaN       NaN  NaN         NaN
# 3      NaN              NaN       NaN  NaN         NaN
# 4      NaN              NaN       NaN  NaN         NaN
# ...    ...              ...       ...  ...          ..
# 16386  NaN              NaN       NaN  NaN         NaN
# 16387  NaN              NaN       NaN  NaN         NaN
# 16388  NaN              NaN       NaN  NaN         NaN
# 16389  NaN              NaN       NaN  NaN         NaN
# 16390  hybrid or gold   NaN       NaN  NaN         NaN
#
#       flipped_access_model  flipped_born_oa
# 0      NaN                 NaN
# 1      NaN                 NaN
# 2      NaN                 NaN
# 3      NaN                 NaN
# 4      NaN                 NaN
# ...    ...                  ..
# 16386  NaN                 NaN
# 16387  NaN                 NaN
# 16388  NaN                 NaN
# 16389  NaN                 NaN
# 16390  NaN                 NaN
#
# [16391 rows x 18 columns]

# %%
# convert to str
df_bjh.loc[df_bjh['NlmUniqueID'].notna(), 'NlmUniqueID'] = df_bjh['NlmUniqueID'].astype(str)

# %%
# merge
df_bjh = df_bjh.merge(df_journals[['NlmUniqueID',
             'Country',
             'Publisher',
             'PublicationFirstYear',
             'PublicationEndYear',
             'Frequency',
             'Language',
             'first_year',
             'last_year',
             'PMIDs',
             'DOIs',
             'unconquerables'            
            ]], on='NlmUniqueID', how='left')
df_bjh
# Out:
#       NlmUniqueID    BroadJournalHeading  sherpa_id_x sherpa_has_oa_path  \
# 0      9015384     History of Medicine    1406.0       yes
# 1      101637720   Anesthesiology        NaN           NaN
# 2      101714112   Anesthesiology        NaN           NaN
# 3      101269322   Critical Care          10921.0      yes
# 4      101269322   Nursing                10921.0      yes
# ...          ...       ...                    ...      ...
# 16386  0056272     Reproductive Medicine NaN           NaN
# 16387  0056272     Veterinary Medicine   NaN           NaN
# 16388  21830020R   History of Medicine   NaN           NaN
# 16389  0233767     Dentistry             NaN           NaN
# 16390  9309124     Embryology             2242.0       yes
#
#        embargo  sherpa_id_y  embargo_published_version  \
# 0      24.0     1406.0      NaN
# 1     NaN      NaN          NaN
# 2     NaN      NaN          NaN
# 3     NaN      NaN          NaN
# 4     NaN      NaN          NaN
# ...    ..       ..           ..
# 16386 NaN      NaN          NaN
# 16387 NaN      NaN          NaN
# 16388 NaN      NaN          NaN
# 16389 NaN      NaN          NaN
# 16390  6.0      2242.0      NaN
#
#        embargo_accepted_version sherpa_oa_green  sherpa_id additional_oa_fee  \
# 0      24.0                      yes             1406.0     yes
# 1     NaN                        NaN            NaN         NaN
# 2     NaN                        NaN            NaN         NaN
# 3     NaN                        NaN            NaN         NaN
# 4     NaN                        NaN            NaN         NaN
# ...    ..                        ...             ..         ...
# 16386 NaN                        NaN            NaN         NaN
# 16387 NaN                        NaN            NaN         NaN
# 16388 NaN                        NaN            NaN         NaN
# 16389 NaN                        NaN            NaN         NaN
# 16390  6.0                       yes             2242.0     yes
#
#       sherpa_oa_hybrid DOAJ_Seal DOAJ Reverse_Flip  flipped_embargo  \
# 0      hybrid or gold   NaN       NaN  NaN         NaN
# 1      NaN              NaN       NaN  NaN         NaN
# 2      NaN              NaN       NaN  NaN         NaN
# 3      NaN              NaN       NaN  NaN         NaN
# 4      NaN              NaN       NaN  NaN         NaN
# ...    ...              ...       ...  ...          ..
# 16386  NaN              NaN       NaN  NaN         NaN
# 16387  NaN              NaN       NaN  NaN         NaN
# 16388  NaN              NaN       NaN  NaN         NaN
# 16389  NaN              NaN       NaN  NaN         NaN
# 16390  hybrid or gold   NaN       NaN  NaN         NaN
#
#       flipped_access_model  flipped_born_oa        Country  \
# 0      NaN                 NaN               England
# 1      NaN                 NaN               NaN
# 2      NaN                 NaN               United States
# 3      NaN                 NaN               United States
# 4      NaN                 NaN               United States
# ...    ...                  ..                         ...
# 16386  NaN                 NaN               NaN
# 16387  NaN                 NaN               NaN
# 16388  NaN                 NaN               NaN
# 16389  NaN                 NaN               NaN
# 16390  NaN                 NaN               England
#
#                                                  Publisher  \
# 0      Oxford University Press
# 1      NaN
# 2      Wolters Kluwer Health, Inc.
# 3      American Association of Critical-Care Nurses (AACN)
# 4      American Association of Critical-Care Nurses (AACN)
# ...                                                    ...
# 16386  NaN
# 16387  NaN
# 16388  NaN
# 16389  NaN
# 16390  Cambridge University Press
#
#       PublicationFirstYear  PublicationEndYear      Frequency Language  \
# 0      1990                NaN                  4 no. a year,  eng
# 1      NaN                 NaN                  NaN            NaN
# 2      2018                NaN                  Biweekly       eng
# 3      2006                NaN                  Quarterly      eng
# 4      2006                NaN                  Quarterly      eng
# ...     ...                 ..                        ...      ...
# 16386  NaN                 NaN                  NaN            NaN
# 16387  NaN                 NaN                  NaN            NaN
# 16388  NaN                 NaN                  NaN            NaN
# 16389  NaN                 NaN                  NaN            NaN
# 16390  1993                NaN                  Quarterly,     eng
#
#        first_year  last_year   PMIDs    DOIs  unconquerables
# 0      1990.0      2019.0     145.0   144.0  NaN
# 1     NaN         NaN        NaN     NaN     NaN
# 2      2018.0      2022.0     999.0   999.0   1.0
# 3      2006.0      2022.0     851.0   837.0   1.0
# 4      2006.0      2022.0     851.0   837.0   1.0
# ...       ...         ...       ...     ...   ...
# 16386 NaN         NaN        NaN     NaN     NaN
# 16387 NaN         NaN        NaN     NaN     NaN
# 16388 NaN         NaN        NaN     NaN     NaN
# 16389 NaN         NaN        NaN     NaN     NaN
# 16390  1993.0      2022.0     1709.0  1641.0 NaN
#
# [16391 rows x 29 columns]

# %%
# take the number of journals for each Broad Journal Headings
df_bjh_counts = df_bjh[['BroadJournalHeading', 'NlmUniqueID']].groupby(by='BroadJournalHeading').count()
# reset index and rename columns
df_bjh_counts = df_bjh_counts.reset_index(drop=False)
df_bjh_counts = df_bjh_counts.rename(columns={'NlmUniqueID' : 'count'})
df_bjh_counts
# Out:
#                     BroadJournalHeading  count
# 0    Acquired Immunodeficiency Syndrome  91
# 1    Aerospace Medicine                  21
# 2    Allergy and Immunology              302
# 3    Anatomy                             84
# 4    Anesthesiology                      88
# ..              ...                      ..
# 120  Veterinary Medicine                 184
# 121  Virology                            62
# 122  Vital Statistics                    28
# 123  Women's Health                      25
# 124  Zoology                             51
#
# [125 rows x 2 columns]

# %%
# take the number of journals for each Broad Journal Headings for unconquerables
df_bjh_unconquerables_counts = df_bjh.loc[df_bjh['unconquerables'] == 1][['BroadJournalHeading', 'NlmUniqueID']].groupby(by='BroadJournalHeading').count()
# reset index and rename columns
df_bjh_unconquerables_counts = df_bjh_unconquerables_counts.reset_index(drop=False)
df_bjh_unconquerables_counts = df_bjh_unconquerables_counts.rename(columns={'NlmUniqueID' : 'unconquerables_count'})
df_bjh_unconquerables_counts
# Out:
#                     BroadJournalHeading  unconquerables_count
# 0    Acquired Immunodeficiency Syndrome  3
# 1    Aerospace Medicine                  2
# 2    Allergy and Immunology              17
# 3    Anatomy                             5
# 4    Anesthesiology                      6
# ..              ...                     ..
# 108  Vascular Diseases                   8
# 109  Veterinary Medicine                 11
# 110  Virology                            4
# 111  Vital Statistics                    8
# 112  Zoology                             3
#
# [113 rows x 2 columns]

# %%
# merge
df_bjh_counts = df_bjh_counts.merge(df_bjh_unconquerables_counts, on='BroadJournalHeading', how='left')
df_bjh_counts
# Out:
#                     BroadJournalHeading  count  unconquerables_count
# 0    Acquired Immunodeficiency Syndrome  91     3.0
# 1    Aerospace Medicine                  21     2.0
# 2    Allergy and Immunology              302    17.0
# 3    Anatomy                             84     5.0
# 4    Anesthesiology                      88     6.0
# ..              ...                      ..     ...
# 120  Veterinary Medicine                 184    11.0
# 121  Virology                            62     4.0
# 122  Vital Statistics                    28     8.0
# 123  Women's Health                      25    NaN
# 124  Zoology                             51     3.0
#
# [125 rows x 3 columns]

# %%
# replace NaN by 0
df_bjh_counts.loc[df_bjh_counts['unconquerables_count'].isna(), 'unconquerables_count'] = 0
df_bjh_counts.loc[df_bjh_counts['unconquerables_count'].notna(), 'unconquerables_count'] = df_bjh_counts['unconquerables_count'].astype(int)
df_bjh_counts
# Out:
#                     BroadJournalHeading  count  unconquerables_count
# 0    Acquired Immunodeficiency Syndrome  91     3
# 1    Aerospace Medicine                  21     2
# 2    Allergy and Immunology              302    17
# 3    Anatomy                             84     5
# 4    Anesthesiology                      88     6
# ..              ...                      ..    ..
# 120  Veterinary Medicine                 184    11
# 121  Virology                            62     4
# 122  Vital Statistics                    28     8
# 123  Women's Health                      25     0
# 124  Zoology                             51     3
#
# [125 rows x 3 columns]

# %%
# add ratios
df_bjh_counts['ratio'] = df_bjh_counts['unconquerables_count'] / df_bjh_counts['count']
df_bjh_counts
# Out:
#                     BroadJournalHeading  count  unconquerables_count     ratio
# 0    Acquired Immunodeficiency Syndrome  91     3                     0.032967
# 1    Aerospace Medicine                  21     2                     0.095238
# 2    Allergy and Immunology              302    17                    0.056291
# 3    Anatomy                             84     5                     0.059524
# 4    Anesthesiology                      88     6                     0.068182
# ..              ...                      ..    ..                          ...
# 120  Veterinary Medicine                 184    11                    0.059783
# 121  Virology                            62     4                     0.064516
# 122  Vital Statistics                    28     8                     0.285714
# 123  Women's Health                      25     0                     0.000000
# 124  Zoology                             51     3                     0.058824
#
# [125 rows x 4 columns]

# %%
# test high ratios (> 0.15)
df_bjh_counts.loc[df_bjh_counts['ratio'] > 0.15].sort_values(by='ratio', ascending=False)
# Out:
#            BroadJournalHeading  count  unconquerables_count     ratio
# 32   Disaster Medicine          9      3                     0.333333
# 122  Vital Statistics           28     8                     0.285714
# 58   Laboratory Animal Science  11     3                     0.272727
# 56   Internal Medicine          40     9                     0.225000
# 70   Neurosurgery               55     12                    0.218182
# 93   Primary Health Care        51     10                    0.196078
# 64   Military Medicine          28     5                     0.178571
# 92   Podiatry                   6      1                     0.166667

# %%
# test highest ratios (= 1)
df_bjh_counts.loc[df_bjh_counts['ratio'] == 1].sort_values(by='count', ascending=False)
# Out:
# Empty DataFrame
# Columns: [BroadJournalHeading, count, unconquerables_count, ratio]
# Index: []

# %%
# export CSV
df_bjh_counts.sort_values(by='BroadJournalHeading', ascending=True).to_csv('results/2023/broad_journal_headings_counts.tsv', sep='\t', index=False)
