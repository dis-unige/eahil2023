# %% [markdown]
# # The Unconquerables of Open Access
#
# ## Parsing Sherpa/Romeo data
#
# Project for the EAHIL conference 2023 : https://eahil2023.org/
# Authors : **Floriane Muller & Pablo Iriarte**, University of Geneva
# Last update : 13.04.2023
#
# This notebook is used to extract the Sherpa/Romeo data obtained by API and process it to make it usable in the research project.
#
# ### Sources
#
# **Sherpa/Romeo API**
#
#   * Example or API call:
#   https://v2.sherpa.ac.uk/cgi/retrieve_by_id?item-type=publication&api-key=EEE6F146-678E-11EB-9C3A-202F3DE2659A&format=Json&identifier=17601

# %%
import pandas as pd
import csv
import json
import numpy as np
import os
# afficher toutes les colonnes
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Import MEDLINE journals

# %%
df = pd.read_csv('data/sources/nlm/lsi2023_medline_issns.tsv', encoding='utf-8', header=0, sep='\t')
df
# Out:
#      NlmUniqueID                        Title               MedlineTA  \
# 0        9015384   20 century British history      20 Century Br Hist
# 1      101714112                 A&A practice               A A Pract
# 2      101269322  AACN advanced critical care      AACN Adv Crit Care
# 3        0431420                 AANA journal                  AANA J
# 4      101223209             The AAPS journal                  AAPS J
# ...          ...                          ...                     ...
# 5274     8702287           Zoological science              Zoolog Sci
# 5275     9435608      Zoology (Jena, Germany)          Zoology (Jena)
# 5276   101300786   Zoonoses and public health  Zoonoses Public Health
# 5277   101179386                      Zootaxa                 Zootaxa
# 5278     9309124  Zygote (Cambridge, England)                  Zygote
#
#             Country                     Place  \
# 0           England           Eynsham, Oxford
# 1     United States        [Philadelphia, PA]
# 2     United States           Aliso Viejo, CA
# 3     United States          Park Ridge, Ill.
# 4     United States       Arlington, Va., USA
# ...             ...                       ...
# 5274          Japan              Tokyo, Japan
# 5275        Germany             Jena, Germany
# 5276        Germany           Berlin, Germany
# 5277    New Zealand            Auckland, N.Z.
# 5278        England  Cambridge ; New York, NY
#
#                                               Publisher PublicationFirstYear  \
# 0                               Oxford University Press                 1990
# 1                           Wolters Kluwer Health, Inc.                 2018
# 2     American Association of Critical-Care Nurses (...                 2006
# 3            American Association of Nurse Anesthetists                 1974
# 4     American Association of Pharmaceutical Scientists                 2004
# ...                                                 ...                  ...
# 5274                        Zoological Society of Japan                 1984
# 5275                                    Urban & Fischer                 1994
# 5276                                   Blackwell Verlag                 2007
# 5277                                     Magnolia Press                 2001
# 5278                         Cambridge University Press                 1993
#
#       PublicationEndYear        Frequency ISSN-Electronic ISSN-Print  \
# 0                    NaN    4 no. a year,       1477-4674  0955-2359
# 1                    NaN         Biweekly       2575-3126        NaN
# 2                    NaN        Quarterly       1559-7776  1559-7768
# 3                    NaN        Bimonthly       2162-5239  0094-6354
# 4                    NaN  Four no. a year       1550-7416        NaN
# ...                  ...              ...             ...        ...
# 5274                 NaN         Monthly,             NaN  0289-0003
# 5275                 NaN  Six no. a year,       1873-2720  0944-2006
# 5276                 NaN   Ten no. a year       1863-2378  1863-1959
# 5277                 NaN        Irregular       1175-5334  1175-5326
# 5278                 NaN       Quarterly,       1469-8730  0967-1994
#
#      ISSN-Linking Language TitleContinuationYN  IndexingStartDate  \
# 0       0955-2359      eng                   N             1990.0
# 1       2575-3126      eng                   Y             2018.0
# 2       1559-7768      eng                   Y             2006.0
# 3       0094-6354      eng                   N             1974.0
# 4       1550-7416      eng                   Y             2004.0
# ...           ...      ...                 ...                ...
# 5274    0289-0003      eng                   N             2002.0
# 5275    0944-2006      eng                   N             2005.0
# 5276    1863-1959      eng                   Y             2007.0
# 5277    1175-5326      eng                   N             2013.0
# 5278    0967-1994      eng                   N             1993.0
#
#      CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 0                     Y             N            QIS
# 1                     Y             Y             IM
# 2                     Y             Y              N
# 3                     Y             Y              N
# 4                     Y             Y             IM
# ...                 ...           ...            ...
# 5274                  Y             Y             IM
# 5275                  Y             Y             IM
# 5276                  Y             Y             IM
# 5277                  Y             Y             IM
# 5278                  Y             Y             IM
#
#                                     IndexingSelectedURL ReportedMedlineYN  \
# 0                                                   NaN                 Y
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=...                 Y
# 2                https://aacnjournals.org/aacnacconline                 Y
# 3        https://www.aana.com/publications/aana-journal                 Y
# 4               https://link.springer.com/journal/12248                 Y
# ...                                                 ...               ...
# 5274                     http://www.bioone.org/loi/jzoo                 Y
# 5275      https://www.sciencedirect.com/journal/zoology                 Y
# 5276  http://onlinelibrary.wiley.com/journal/10.1111...                 Y
# 5277                       http://www.mapress.com/j/zt/                 Y
# 5278     https://www.cambridge.org/core/journals/zygote                 Y
#
#            ISSN
# 0     1477-4674
# 1     2575-3126
# 2     1559-7776
# 3     2162-5239
# 4     1550-7416
# ...         ...
# 5274  0289-0003
# 5275  1873-2720
# 5276  1863-2378
# 5277  1175-5334
# 5278  1469-8730
#
# [5279 rows x 21 columns]

# %% [markdown]
# ## Parsing Sherpa/Romeo data

# %%
# creation du DF
col_names = ['NlmUniqueID',
             'title_sherpa',
             'issne_sherpa',
             'issnp_sherpa',
             'url',
             'publisher_id',
             'publisher_country',
             'publisher_type',
             'publisher_url',
             'publisher_name',
             'sherpa_id',
             'sherpa_uri',
             'open_access_prohibited',
             'additional_oa_fee',
             'article_version',
             'license',
             'embargo',
             'prerequisites',
             'prerequisite_funders',
             'prerequisite_funders_name',
             'prerequisite_funders_fundref',
             'prerequisite_funders_ror',
             'prerequisite_funders_country',
             'prerequisite_funders_url',
             'prerequisite_funders_sherpa_id',
             'prerequisite_subjects',
             'location',
             'locations_ir',
             'locations_not_ir',
             'named_repository',
             'named_academic_social_network',
             'copyright_owner',
             'publisher_deposit',
             'archiving',
             'conditions',
             'public_notes',
             'sherpa_created',
             'sherpa_last_modified'             
            ] 
sherpa_policies = pd.DataFrame(columns = col_names) 
sherpa_policies
# Out:
# Empty DataFrame
# Columns: [NlmUniqueID, title_sherpa, issne_sherpa, issnp_sherpa, url, publisher_id, publisher_country, publisher_type, publisher_url, publisher_name, sherpa_id, sherpa_uri, open_access_prohibited, additional_oa_fee, article_version, license, embargo, prerequisites, prerequisite_funders, prerequisite_funders_name, prerequisite_funders_fundref, prerequisite_funders_ror, prerequisite_funders_country, prerequisite_funders_url, prerequisite_funders_sherpa_id, prerequisite_subjects, location, locations_ir, locations_not_ir, named_repository, named_academic_social_network, copyright_owner, publisher_deposit, archiving, conditions, public_notes, sherpa_created, sherpa_last_modified]
# Index: []

# %%
# creation du DF pour le log
col_names = ['NlmUniqueID',
             'issn',
             'sherpa_id',
             'result'
            ] 
sherpalog = pd.DataFrame(columns = col_names) 
sherpalog
# Out:
# Empty DataFrame
# Columns: [NlmUniqueID, issn, sherpa_id, result]
# Index: []

# %%
# keep ISSNs
df_issns = df[['NlmUniqueID', 'ISSN']]
df_issns
# Out:
#      NlmUniqueID       ISSN
# 0        9015384  1477-4674
# 1      101714112  2575-3126
# 2      101269322  1559-7776
# 3        0431420  2162-5239
# 4      101223209  1550-7416
# ...          ...        ...
# 5274     8702287  0289-0003
# 5275     9435608  1873-2720
# 5276   101300786  1863-2378
# 5277   101179386  1175-5334
# 5278     9309124  1469-8730
#
# [5279 rows x 2 columns]

# %%
df_issns.loc[df_issns['ISSN'] != ''].shape[0]
# Out:
# 5279

# %%
df.loc[df['ISSN-Print'].isna()]
# Out:
#            NlmUniqueID                                      Title  \
# 1            101714112                               A&A practice
# 4            101223209                           The AAPS journal
# 5            100960111                          AAPS PharmSciTech
# 15           101729147                  ACS applied bio materials
# 17           101654670     ACS biomaterials science & engineering
# ...                ...                                        ...
# 5150         101231645                           Virology journal
# 5157         101509722                                    Viruses
# 5188  9918227353306676                WIREs mechanisms of disease
# 5197         101266603  World journal of emergency surgery : WJES
# 5203         101170544         World journal of surgical oncology
#
#                  MedlineTA        Country                Place  \
# 1                A A Pract  United States   [Philadelphia, PA]
# 4                   AAPS J  United States  Arlington, Va., USA
# 5        AAPS PharmSciTech  United States             New York
# 15      ACS Appl Bio Mater  United States       Washington, DC
# 17    ACS Biomater Sci Eng  United States       Washington, DC
# ...                    ...            ...                  ...
# 5150               Virol J        England             [London]
# 5157               Viruses    Switzerland   Basel, Switzerland
# 5188        WIREs Mech Dis  United States        [Hoboken, NJ]
# 5197    World J Emerg Surg        England               London
# 5203    World J Surg Oncol        England               London
#
#                                               Publisher PublicationFirstYear  \
# 1                           Wolters Kluwer Health, Inc.                 2018
# 4     American Association of Pharmaceutical Scientists                 2004
# 5                                              Springer                 2000
# 15                                     ACS Publications                 2018
# 17                            American Chemical Society                 2015
# ...                                                 ...                  ...
# 5150                                     BioMed Central                 2004
# 5157                                               MDPI                 2009
# 5188                            John Wiley & Sons, Inc.                 2021
# 5197                                     BioMed Central                 2006
# 5203                                     BioMed Central                 2003
#
#       PublicationEndYear        Frequency ISSN-Electronic ISSN-Print  \
# 1                    NaN         Biweekly       2575-3126        NaN
# 4                    NaN  Four no. a year       1550-7416        NaN
# 5                    NaN        Quarterly       1530-9932        NaN
# 15                   NaN          Monthly       2576-6422        NaN
# 17                   NaN          Monthly       2373-9878        NaN
# ...                  ...              ...             ...        ...
# 5150                 NaN              NaN       1743-422X        NaN
# 5157                 NaN        Quarterly       1999-4915        NaN
# 5188                 NaN        Bimonthly       2692-9368        NaN
# 5197                 NaN              NaN       1749-7922        NaN
# 5203                 NaN              NaN       1477-7819        NaN
#
#      ISSN-Linking Language TitleContinuationYN  IndexingStartDate  \
# 1       2575-3126      eng                   Y             2018.0
# 4       1550-7416      eng                   Y             2004.0
# 5       1530-9932      eng                   N             2000.0
# 15      2576-6422      eng                   N             2021.0
# 17      2373-9878      eng                   N             2020.0
# ...           ...      ...                 ...                ...
# 5150    1743-422X      eng                   N             2004.0
# 5157    1999-4915      eng                   N             2011.0
# 5188    2692-9368      eng                   Y             2021.0
# 5197    1749-7922      eng                   N             2017.0
# 5203    1477-7819      eng                   N             2007.0
#
#      CurrentlyIndexedYN IndexOnlineYN IndexingSubset  \
# 1                     Y             Y             IM
# 4                     Y             Y             IM
# 5                     Y             Y             IM
# 15                    Y             Y             IM
# 17                    Y             Y             IM
# ...                 ...           ...            ...
# 5150                  Y             Y             IM
# 5157                  Y             Y             IM
# 5188                  Y             Y             IM
# 5197                  Y             Y             IM
# 5203                  Y             Y             IM
#
#                                     IndexingSelectedURL ReportedMedlineYN  \
# 1     https://ovidsp.ovid.com/ovidweb.cgi?T=JS&MODE=...                 Y
# 4               https://link.springer.com/journal/12248                 Y
# 5               https://link.springer.com/journal/12249                 Y
# 15                  https://pubs.acs.org/journal/aabmcb                 Y
# 17                  https://pubs.acs.org/journal/abseba                 Y
# ...                                                 ...               ...
# 5150                          http://www.virologyj.com/                 Y
# 5157                http://www.mdpi.com/journal/viruses                 Y
# 5188  https://wires.onlinelibrary.wiley.com/journal/...                 Y
# 5197                               http://www.wjes.org/                 Y
# 5203                               http://www.wjso.com/                 Y
#
#            ISSN
# 1     2575-3126
# 4     1550-7416
# 5     1530-9932
# 15    2576-6422
# 17    2373-9878
# ...         ...
# 5150  1743-422X
# 5157  1999-4915
# 5188  2692-9368
# 5197  1749-7922
# 5203  1477-7819
#
# [447 rows x 21 columns]

# %%
df_pissns = df[['NlmUniqueID', 'ISSN-Print']].loc[df['ISSN-Print'].notna()]
df_pissns = df_pissns.rename(columns={'ISSN-Print' : 'ISSN'})
df_pissns
# Out:
#      NlmUniqueID       ISSN
# 0        9015384  0955-2359
# 2      101269322  1559-7768
# 3        0431420  0094-6354
# 6      101674571  2366-004X
# 7        9418450  1069-6563
# ...          ...        ...
# 5274     8702287  0289-0003
# 5275     9435608  0944-2006
# 5276   101300786  1863-1959
# 5277   101179386  1175-5326
# 5278     9309124  0967-1994
#
# [4832 rows x 2 columns]

# %%
# concat ISSN and 'ISSN-Print'
df_issns = df_issns.append(df_pissns, ignore_index=True)
df_issns
# Out:
#       NlmUniqueID       ISSN
# 0         9015384  1477-4674
# 1       101714112  2575-3126
# 2       101269322  1559-7776
# 3         0431420  2162-5239
# 4       101223209  1550-7416
# ...           ...        ...
# 10106     8702287  0289-0003
# 10107     9435608  0944-2006
# 10108   101300786  1863-1959
# 10109   101179386  1175-5326
# 10110     9309124  0967-1994
#
# [10111 rows x 2 columns]

# %%
# type de repositories qui provoquent archiving = 1 :
# tous les types : 'academic_social_network', 'any_repository', 'any_website', 'authors_homepage',
# 'funder_designated_location', 'institutional_repository', 'institutional_website', 'named_academic_social_network',
# 'named_repository', 'non_commercial_institutional_repository', 'non_commercial_repository',
# 'non_commercial_social_network', 'non_commercial_subject_repository', 'non_commercial_website',
# 'preprint_repository', 'subject_repository', 'this_journal'
repositories_archiving = ['any_repository',
                          'institutional_repository',
                          'institutional_website',
                          'non_commercial_institutional_repository',
                          'non_commercial_repository',
                          'any_website',
                          'non_commercial_website']

# extraction des termes
iteri = int(0)
print (str(iteri))
for index, row in df_issns.iterrows():
    iteri = iteri + 1
    journal_id = row['NlmUniqueID']
    journal_issn = row['ISSN']
    sherpa_log = ''
    # boucle des fichiers json
    # print(row['format'])
    if (((iteri/100) - int(iteri/100)) == 0) :
        print(str(iteri))
    # test d'existance du fichier
    if os.path.exists('data/sources/sherpa/data_2023/' + journal_issn + '.json'):
        # fichier existant
        sherpa_log = 'JSON file OK - '
        with open('data/sources/sherpa/data_2023/' + journal_issn + '.json', 'r', encoding='utf-8') as f:
            data = json.load(f)
            # initialisation des variables à extraire
            sherpa_id = np.nan
            title_sherpa = np.nan
            issne_sherpa = np.nan
            issnp_sherpa = np.nan
            issns = np.nan
            myissn = np.nan
            mytype = np.nan
            url = np.nan
            publisher_id = np.nan
            publisher_country = np.nan
            publisher_type = np.nan
            publisher_url = np.nan
            publisher_name = np.nan
            sherpa_uri = np.nan
            open_access_prohibited = np.nan
            location = np.nan
            locations_ir = ''
            locations_not_ir = ''
            additional_oa_fee = np.nan
            article_versions = np.nan
            article_version = np.nan
            licenses = []
            embargo = 0
            prerequisites = np.nan
            prerequisites_phrases = ''
            prerequisite_funders = np.nan
            prerequisite_funders_name = np.nan
            prerequisite_funders_fundref = np.nan
            prerequisite_funders_ror = np.nan
            prerequisite_funders_country = np.nan
            prerequisite_funders_url = np.nan
            prerequisite_funders_sherpa_id = np.nan
            prerequisite_subjects = np.nan
            named_repository = np.nan
            named_academic_social_network = np.nan
            copyright_owner = np.nan
            publisher_deposit = np.nan
            archiving = np.nan
            conditions = np.nan
            public_notes = np.nan
            sherpa_created = np.nan
            sherpa_last_modified = np.nan
            if (len(data['items']) > 0):
                if ('url' in data['items'][0]):
                    url = data['items'][0]['url']
                if ('title' in data['items'][0]['title'][0]):
                    title_sherpa = data['items'][0]['title'][0]['title']
                if ('issns' in data['items'][0]):
                    issns = data['items'][0]['issns']
                for i in issns:
                    if ('issn' in i):
                        myissn = i['issn']
                    if ('type' in i):
                        mytype = i['type']
                        if mytype == 'print':
                            issnp_sherpa = myissn
                        if mytype == 'electronic':
                            issne_sherpa = myissn
                publisher_id = data['items'][0]['publishers'][0]['publisher']['id']
                sherpa_created = data['items'][0]['system_metadata']['date_created']
                sherpa_last_modified = data['items'][0]['system_metadata']['date_modified']
                if ('country' in data['items'][0]['publishers'][0]['publisher']):
                    publisher_country = data['items'][0]['publishers'][0]['publisher']['country']
                if ('relationship_type' in data['items'][0]['publishers'][0]):
                    publisher_type = data['items'][0]['publishers'][0]['relationship_type']
                if ('url' in data['items'][0]['publishers'][0]['publisher']):
                    publisher_url = data['items'][0]['publishers'][0]['publisher']['url']
                if ('name' in data['items'][0]['publishers'][0]['publisher']['name'][0]):
                    publisher_name = data['items'][0]['publishers'][0]['publisher']['name'][0]['name']
                if ('id' in data['items'][0]):
                    sherpa_id = data['items'][0]['id']
                    # test si l'id est déjà présent 
                    if sherpa_id in sherpa_policies['sherpa_id'].values :
                        # print(journal_issn + ' - sherpa ID ' + str(sherpa_id) + ' déjà traité -> SKIP')
                        sherpa_log = sherpa_log + 'sherpa_id already done - '
                    else :
                        poilicies = data['items'][0]['publisher_policy']
                        for poilicy in poilicies:
                            # initialisation des variables à extraire
                            sherpa_uri = np.nan
                            open_access_prohibited = np.nan
                            if ('uri' in poilicy):
                                sherpa_uri = poilicy['uri']
                            if ('open_access_prohibited' in poilicy):
                                open_access_prohibited = poilicy['open_access_prohibited']
                            if ('permitted_oa' in poilicy):
                                poas = poilicy['permitted_oa']
                                for poa in poas:
                                    additional_oa_fee = np.nan
                                    article_versions = np.nan
                                    article_version = np.nan
                                    licenses = []
                                    embargo = 0
                                    prerequisites = np.nan
                                    prerequisites_phrases = ''
                                    prerequisite_funders = np.nan
                                    prerequisite_funders_name = np.nan
                                    prerequisite_funders_fundref = np.nan
                                    prerequisite_funders_ror = np.nan
                                    prerequisite_funders_country = np.nan
                                    prerequisite_funders_url = np.nan
                                    prerequisite_funders_sherpa_id = np.nan
                                    prerequisite_subjects = np.nan
                                    named_repository = np.nan
                                    named_academic_social_network = np.nan
                                    locations_ir = ''
                                    locations_not_ir = ''
                                    copyright_owner = np.nan
                                    conditions = np.nan
                                    public_notes = np.nan
                                    if ('additional_oa_fee' in poa):
                                        additional_oa_fee = poa['additional_oa_fee']
                                    if ('location' in poa):
                                        archiving = 0
                                        location = ''
                                        mylocations = poa['location']['location']
                                        mylocations_text = poa['location']['location_phrases']
                                        if (type(mylocations) is not list):
                                            mylocations = [mylocations]
                                        location = ' ; '.join(mylocations)
                                        for locationi in mylocations:
                                            if locationi in repositories_archiving :
                                                archiving = archiving + 1
                                                for locationi_text in mylocations_text:
                                                    if locationi_text['value'] == locationi :
                                                        if locations_ir == '':
                                                            locations_ir = locations_ir + locationi_text['phrase']
                                                        else :
                                                            if locationi_text['phrase'] not in locations_ir :
                                                                locations_ir = locations_ir + ' ; ' + locationi_text['phrase']
                                            else :
                                                for locationi_text in mylocations_text:
                                                    if locationi_text['value'] == locationi :
                                                        if locations_not_ir == '':
                                                            locations_not_ir = locations_not_ir + locationi_text['phrase']
                                                        else :
                                                            if locationi_text['phrase'] not in locations_not_ir :
                                                                locations_not_ir = locations_not_ir + ' ; ' + locationi_text['phrase']
                                        # print (archiving)
                                        if archiving > 0:
                                            archiving = True
                                        else : 
                                            archiving = False
                                        if ('named_repository' in poa['location']):
                                            if (type(poa['location']['named_repository']) is list):
                                                named_repository = ' ; '.join(poa['location']['named_repository'])
                                            else : 
                                                named_repository = poa['location']['named_repository']
                                            locations_not_ir = locations_not_ir.replace('Named Repository', named_repository)
                                            locations_ir = locations_ir.replace('Named Repository', named_repository)
                                        if ('named_academic_social_network' in poa['location']):
                                            if (type(poa['location']['named_academic_social_network']) is list):
                                                named_academic_social_network = ' ; '.join(poa['location']['named_academic_social_network'])
                                            else : 
                                                named_academic_social_network = poa['location']['named_academic_social_network']
                                            locations_not_ir = locations_not_ir.replace('Named Academic Social Network', named_academic_social_network)
                                            locations_ir = locations_ir.replace('Named Academic Social Network', named_academic_social_network)
                                    if ('embargo' in poa):
                                        # print(poa['embargo'])
                                        embargo_amount = 0
                                        if ('amount' in poa['embargo']):
                                            embargo_amount = poa['embargo']['amount']
                                        if ('units' in poa['embargo']):
                                            if (poa['embargo']['units'] == 'months') :
                                                embargo = embargo_amount
                                            elif (poa['embargo']['units'] == 'years') :
                                                embargo = embargo_amount*12
                                            elif (poa['embargo']['units'] == 'weeks') :
                                                if (embargo_amount == 0):
                                                    embargo = 0
                                                if (embargo_amount > 0):
                                                    embargo = int(embargo_amount/4)
                                                    if (embargo == 0):
                                                        embargo = 1
                                            elif (poa['embargo']['units'] == 'days') :
                                                if (embargo_amount == 0):
                                                    embargo = 0
                                                if (embargo_amount > 0):
                                                    embargo = int(embargo_amount/30)
                                                    if (embargo == 0):
                                                        embargo = 1
                                        else :
                                            embargo = embargo_amount
                                    if ('prerequisites' in poa):
                                        if 'prerequisites' in poa['prerequisites'] :
                                            if (type(poa['prerequisites']['prerequisites']) is list):
                                                prerequisites = ' ; '.join(poa['prerequisites']['prerequisites'])
                                            else:
                                                prerequisites = poa['prerequisites']['prerequisites']
                                        if 'prerequisites_phrases' in poa['prerequisites'] :
                                            if (type(poa['prerequisites']['prerequisites_phrases']) is list):
                                                for prerequisites_phrasesi in poa['prerequisites']['prerequisites_phrases']:
                                                    if 'phrase' in prerequisites_phrasesi:
                                                        prerequisites_phrases = prerequisites_phrases + prerequisites_phrasesi['phrase'] + ' ; '
                                            else:
                                                prerequisites_phrases = poa['prerequisites']['prerequisites_phrases']['phrase']
                                        if ('prerequisite_funders' in poa['prerequisites']):
                                            prerequisite_funders = True
                                            # prerequisite_funders = poa['prerequisites']['prerequisite_funders']
                                            # if (type(poa['prerequisites']['prerequisite_funders']) is list):
                                            #     prerequisite_funders = ' ; '.join(poa['prerequisites']['prerequisite_funders'])
                                            # else:
                                            #     prerequisite_funders = poa['prerequisites']['prerequisite_funders']
                                        if ('prerequisite_subjects' in poa['prerequisites']):
                                            prerequisite_subjects = True
                                            # prerequisite_subjects = poa['prerequisites']['prerequisite_subjects']
                                            # if (type(poa['prerequisite_subjects']) is list):
                                            #     prerequisite_subjects = ' ; '.join(poa['prerequisite_subjects'])
                                            # else:
                                            #     prerequisite_subjects = poa['prerequisite_subjects']
                                    if ('copyright_owner' in poa):
                                        copyright_owner = poa['copyright_owner']
                                    if ('publisher_deposit' in poa):
                                        publisher_deposit = ''
                                        if (type(poa['publisher_deposit']) is list):
                                            for deposit in poa['publisher_deposit']:
                                                if 'type' in deposit['repository_metadata']:
                                                    publisher_deposit = publisher_deposit + deposit['repository_metadata']['type']
                                                    if 'name' in deposit['repository_metadata']:
                                                        publisher_deposit = publisher_deposit + ' (' + deposit['repository_metadata']['name'][0]['name'] + ')'
                                                else :
                                                    if 'name' in deposit['repository_metadata']:
                                                        publisher_deposit = publisher_deposit + deposit['repository_metadata']['name'][0]['name']
                                                publisher_deposit = publisher_deposit + ' ; '
                                        else :
                                            deposit = poa['publisher_deposit']
                                            if 'type' in deposit['repository_metadata']:
                                                publisher_deposit = publisher_deposit + deposit['repository_metadata']['type']
                                                if 'name' in deposit['repository_metadata']:
                                                    publisher_deposit = publisher_deposit + ' (' + deposit['repository_metadata']['name'][0]['name'] + ')'
                                            else :
                                                if 'name' in deposit['repository_metadata']:
                                                    publisher_deposit = publisher_deposit + deposit['repository_metadata']['name'][0]['name']
                                            publisher_deposit = publisher_deposit + ' ; '
                                        # print (publisher_deposit)
                                    if ('conditions' in poa):
                                        if (type(poa['conditions']) is list):
                                            conditions = ' ; '.join(poa['conditions'])
                                        else:
                                            conditions = poa['conditions']
                                    if ('public_notes' in poa):
                                        if (type(poa['public_notes']) is list):
                                            public_notes = ' ; '.join(poa['public_notes'])
                                        else:
                                            public_notes = poa['public_notes']
                                    if ('license' in poa):
                                        licenses = poa['license']
                                        if (type(licenses) is not list):
                                            licenses = [licenses]
                                    else :
                                        licenses = ['']
                                    # avec article version
                                    if ('article_version' in poa):
                                        article_versions = poa['article_version']
                                        for article_version in article_versions:
                                            for license in licenses:
                                                if ('license' in license):
                                                    mylicense = license['license']
                                                else :
                                                    mylicense = ''
                                                # avec prerequisites
                                                if ('prerequisites' in poa) :
                                                    # avec prerequisites_funders
                                                    if ('prerequisite_funders' in poa['prerequisites']):
                                                        for prerequisite_fundersi in poa['prerequisites']['prerequisite_funders'] :
                                                            prerequisite_funders_name = prerequisite_fundersi['funder_metadata']['name'][0]['name']
                                                            if 'acronym' in prerequisite_fundersi['funder_metadata']['name'][0]:
                                                                prerequisite_funders_name = prerequisite_funders_name + ' (' + prerequisite_fundersi['funder_metadata']['name'][0]['acronym'] + ')'
                                                            if 'identifiers' in prerequisite_fundersi['funder_metadata'] :
                                                                for fund_identifier in prerequisite_fundersi['funder_metadata']['identifiers'] :
                                                                    if fund_identifier['type'] == 'fundref':
                                                                        prerequisite_funders_fundref = fund_identifier['identifier']
                                                                    if fund_identifier['type'] == 'ror':
                                                                        prerequisite_funders_ror = fund_identifier['identifier']
                                                            if 'country' in prerequisite_fundersi['funder_metadata']:
                                                                prerequisite_funders_country = prerequisite_fundersi['funder_metadata']['country']
                                                            if 'url' in prerequisite_fundersi['funder_metadata']:
                                                                prerequisite_funders_url = prerequisite_fundersi['funder_metadata']['url'][0]['url']
                                                            prerequisite_funders_sherpa_id = prerequisite_fundersi['funder_metadata']['id']
                                                            sherpa_policies = sherpa_policies.append({'NlmUniqueID' : journal_id,
                                                                                              'title_sherpa' : title_sherpa,
                                                                                              'issnp_sherpa' : issnp_sherpa,
                                                                                              'issne_sherpa' : issne_sherpa,
                                                                                              'url' : url,
                                                                                              'publisher_id' : publisher_id,
                                                                                              'publisher_country' : publisher_country,
                                                                                              'publisher_type' : publisher_type,
                                                                                              'publisher_url' : publisher_url,
                                                                                              'publisher_name' : publisher_name,
                                                                                              'sherpa_id' : sherpa_id,
                                                                                              'sherpa_uri' : sherpa_uri,
                                                                                              'open_access_prohibited' : open_access_prohibited,
                                                                                              'additional_oa_fee' : additional_oa_fee,
                                                                                              'article_version' : article_version,
                                                                                              'license' : mylicense,
                                                                                              'embargo' : embargo,
                                                                                              'prerequisites' : prerequisites,
                                                                                              'prerequisites_phrases' : prerequisites_phrases,
                                                                                              'prerequisite_funders' : prerequisite_funders,
                                                                                              'prerequisite_funders_name' : prerequisite_funders_name,
                                                                                              'prerequisite_funders_fundref' : prerequisite_funders_fundref,
                                                                                              'prerequisite_funders_ror' : prerequisite_funders_ror,
                                                                                              'prerequisite_funders_country' : prerequisite_funders_country,
                                                                                              'prerequisite_funders_url' : prerequisite_funders_url,
                                                                                              'prerequisite_funders_sherpa_id' : prerequisite_funders_sherpa_id,
                                                                                              'prerequisite_subjects' : prerequisite_subjects,
                                                                                              'location' : location,
                                                                                              'locations_ir' : locations_ir,
                                                                                              'locations_not_ir' : locations_not_ir,
                                                                                              'named_repository' : named_repository,
                                                                                              'named_academic_social_network' : named_academic_social_network,
                                                                                              'copyright_owner' : copyright_owner,
                                                                                              'publisher_deposit' : publisher_deposit,
                                                                                              'archiving' : archiving,
                                                                                              'conditions' : conditions,
                                                                                              'public_notes' : public_notes,
                                                                                              'sherpa_created' : sherpa_created,
                                                                                              'sherpa_last_modified' : sherpa_last_modified
                                                                                              }, ignore_index=True)
                                                    # sans prerequisites_funders
                                                    else :
                                                        sherpa_policies = sherpa_policies.append({'NlmUniqueID' : journal_id,
                                                                                          'title_sherpa' : title_sherpa,
                                                                                          'issnp_sherpa' : issnp_sherpa,
                                                                                          'issne_sherpa' : issne_sherpa,
                                                                                          'url' : url,
                                                                                          'publisher_id' : publisher_id,
                                                                                          'publisher_country' : publisher_country,
                                                                                          'publisher_type' : publisher_type,
                                                                                          'publisher_url' : publisher_url,
                                                                                          'publisher_name' : publisher_name,
                                                                                          'sherpa_id' : sherpa_id,
                                                                                          'sherpa_uri' : sherpa_uri,
                                                                                          'open_access_prohibited' : open_access_prohibited,
                                                                                          'additional_oa_fee' : additional_oa_fee,
                                                                                          'article_version' : article_version,
                                                                                          'license' : mylicense,
                                                                                          'embargo' : embargo,
                                                                                          'prerequisites' : prerequisites,
                                                                                          'prerequisites_phrases' : prerequisites_phrases,
                                                                                          'prerequisite_funders' : prerequisite_funders,
                                                                                          'prerequisite_funders_name' : prerequisite_funders_name,
                                                                                          'prerequisite_funders_fundref' : prerequisite_funders_fundref,
                                                                                          'prerequisite_funders_ror' : prerequisite_funders_ror,
                                                                                          'prerequisite_funders_country' : prerequisite_funders_country,
                                                                                          'prerequisite_funders_url' : prerequisite_funders_url,
                                                                                          'prerequisite_funders_sherpa_id' : prerequisite_funders_sherpa_id,
                                                                                          'prerequisite_subjects' : prerequisite_subjects,
                                                                                          'location' : location,
                                                                                          'locations_ir' : locations_ir,
                                                                                          'locations_not_ir' : locations_not_ir,
                                                                                          'named_repository' : named_repository,
                                                                                          'named_academic_social_network' : named_academic_social_network,
                                                                                          'copyright_owner' : copyright_owner,
                                                                                          'publisher_deposit' : publisher_deposit,
                                                                                          'archiving' : archiving,
                                                                                          'conditions' : conditions,
                                                                                          'public_notes' : public_notes,
                                                                                          'sherpa_created' : sherpa_created,
                                                                                          'sherpa_last_modified' : sherpa_last_modified
                                                                                          }, ignore_index=True)
                                                # sans prerequisites
                                                else :
                                                    sherpa_policies = sherpa_policies.append({'NlmUniqueID' : journal_id,
                                                                                          'title_sherpa' : title_sherpa,
                                                                                          'issnp_sherpa' : issnp_sherpa,
                                                                                          'issne_sherpa' : issne_sherpa,
                                                                                          'url' : url,
                                                                                          'publisher_id' : publisher_id,
                                                                                          'publisher_country' : publisher_country,
                                                                                          'publisher_type' : publisher_type,
                                                                                          'publisher_url' : publisher_url,
                                                                                          'publisher_name' : publisher_name,
                                                                                          'sherpa_id' : sherpa_id,
                                                                                          'sherpa_uri' : sherpa_uri,
                                                                                          'open_access_prohibited' : open_access_prohibited,
                                                                                          'additional_oa_fee' : additional_oa_fee,
                                                                                          'article_version' : article_version,
                                                                                          'license' : mylicense,
                                                                                          'embargo' : embargo,
                                                                                          'prerequisites' : prerequisites,
                                                                                          'prerequisites_phrases' : prerequisites_phrases,
                                                                                          'prerequisite_funders' : prerequisite_funders,
                                                                                          'prerequisite_funders_name' : prerequisite_funders_name,
                                                                                          'prerequisite_funders_fundref' : prerequisite_funders_fundref,
                                                                                          'prerequisite_funders_ror' : prerequisite_funders_ror,
                                                                                          'prerequisite_funders_country' : prerequisite_funders_country,
                                                                                          'prerequisite_funders_url' : prerequisite_funders_url,
                                                                                          'prerequisite_funders_sherpa_id' : prerequisite_funders_sherpa_id,
                                                                                          'prerequisite_subjects' : prerequisite_subjects,
                                                                                          'location' : location,
                                                                                          'locations_ir' : locations_ir,
                                                                                          'locations_not_ir' : locations_not_ir,
                                                                                          'named_repository' : named_repository,
                                                                                          'named_academic_social_network' : named_academic_social_network,
                                                                                          'copyright_owner' : copyright_owner,
                                                                                          'publisher_deposit' : publisher_deposit,
                                                                                          'archiving' : archiving,
                                                                                          'conditions' : conditions,
                                                                                          'public_notes' : public_notes,
                                                                                          'sherpa_created' : sherpa_created,
                                                                                          'sherpa_last_modified' : sherpa_last_modified
                                                                                          }, ignore_index=True)

                                    # sans article version
                                    else :
                                        if (type(licenses) is not list):
                                            licenses = [licenses]
                                        for license in licenses:
                                            if ('license' in license):
                                                mylicense = license['license']
                                            else :
                                                mylicense = ''
                                            # avec prerequisites
                                            if ('prerequisites' in poa) :
                                                # avec prerequisites_funders
                                                if ('prerequisite_funders' in poa['prerequisites']):
                                                    for prerequisite_fundersi in poa['prerequisites']['prerequisite_funders'] :
                                                        prerequisite_funders_name = prerequisite_fundersi['funder_metadata']['name'][0]['name']
                                                        if 'acronym' in prerequisite_fundersi['funder_metadata']['name'][0]:
                                                            prerequisite_funders_name = prerequisite_funders_name + ' (' + prerequisite_fundersi['funder_metadata']['name'][0]['acronym'] + ')'
                                                        if 'identifiers' in prerequisite_fundersi['funder_metadata'] :
                                                            for fund_identifier in prerequisite_fundersi['funder_metadata']['identifiers'] :
                                                                if fund_identifier['type'] == 'fundref':
                                                                    prerequisite_funders_fundref = fund_identifier['identifier']
                                                                if fund_identifier['type'] == 'ror':
                                                                    prerequisite_funders_ror = fund_identifier['identifier']
                                                        if 'country' in prerequisite_fundersi['funder_metadata']:
                                                            prerequisite_funders_country = prerequisite_fundersi['funder_metadata']['country']
                                                        if 'url' in prerequisite_fundersi['funder_metadata']:
                                                            prerequisite_funders_url = prerequisite_fundersi['funder_metadata']['url'][0]['url']
                                                        prerequisite_funders_sherpa_id = prerequisite_fundersi['funder_metadata']['id']
                                                        sherpa_policies = sherpa_policies.append({'NlmUniqueID' : journal_id,
                                                                                          'title_sherpa' : title_sherpa,
                                                                                          'issnp_sherpa' : issnp_sherpa,
                                                                                          'issne_sherpa' : issne_sherpa,
                                                                                          'url' : url,
                                                                                          'publisher_id' : publisher_id,
                                                                                          'publisher_country' : publisher_country,
                                                                                          'publisher_type' : publisher_type,
                                                                                          'publisher_url' : publisher_url,
                                                                                          'publisher_name' : publisher_name,
                                                                                          'sherpa_id' : sherpa_id,
                                                                                          'sherpa_uri' : sherpa_uri,
                                                                                          'open_access_prohibited' : open_access_prohibited,
                                                                                          'additional_oa_fee' : additional_oa_fee,
                                                                                          'article_version' : article_version,
                                                                                          'license' : mylicense,
                                                                                          'embargo' : embargo,
                                                                                          'prerequisites' : prerequisites,
                                                                                          'prerequisites_phrases' : prerequisites_phrases,
                                                                                          'prerequisite_funders' : prerequisite_funders,
                                                                                          'prerequisite_funders_name' : prerequisite_funders_name,
                                                                                          'prerequisite_funders_fundref' : prerequisite_funders_fundref,
                                                                                          'prerequisite_funders_ror' : prerequisite_funders_ror,
                                                                                          'prerequisite_funders_country' : prerequisite_funders_country,
                                                                                          'prerequisite_funders_url' : prerequisite_funders_url,
                                                                                          'prerequisite_funders_sherpa_id' : prerequisite_funders_sherpa_id,
                                                                                          'prerequisite_subjects' : prerequisite_subjects,
                                                                                          'location' : location,
                                                                                          'locations_ir' : locations_ir,
                                                                                          'locations_not_ir' : locations_not_ir,
                                                                                          'named_repository' : named_repository,
                                                                                          'named_academic_social_network' : named_academic_social_network,
                                                                                          'copyright_owner' : copyright_owner,
                                                                                          'publisher_deposit' : publisher_deposit,
                                                                                          'archiving' : archiving,
                                                                                          'conditions' : conditions,
                                                                                          'public_notes' : public_notes,
                                                                                          'sherpa_created' : sherpa_created,
                                                                                          'sherpa_last_modified' : sherpa_last_modified
                                                                                          }, ignore_index=True)
                                                # sans prerequisites_funders
                                                else :
                                                    sherpa_policies = sherpa_policies.append({'NlmUniqueID' : journal_id,
                                                                                          'title_sherpa' : title_sherpa,
                                                                                          'issnp_sherpa' : issnp_sherpa,
                                                                                          'issne_sherpa' : issne_sherpa,
                                                                                          'url' : url,
                                                                                          'publisher_id' : publisher_id,
                                                                                          'publisher_country' : publisher_country,
                                                                                          'publisher_type' : publisher_type,
                                                                                          'publisher_url' : publisher_url,
                                                                                          'publisher_name' : publisher_name,
                                                                                          'sherpa_id' : sherpa_id,
                                                                                          'sherpa_uri' : sherpa_uri,
                                                                                          'open_access_prohibited' : open_access_prohibited,
                                                                                          'additional_oa_fee' : additional_oa_fee,
                                                                                          'article_version' : article_version,
                                                                                          'license' : mylicense,
                                                                                          'embargo' : embargo,
                                                                                          'prerequisites' : prerequisites,
                                                                                          'prerequisites_phrases' : prerequisites_phrases,
                                                                                          'prerequisite_funders' : prerequisite_funders,
                                                                                          'prerequisite_funders_name' : prerequisite_funders_name,
                                                                                          'prerequisite_funders_fundref' : prerequisite_funders_fundref,
                                                                                          'prerequisite_funders_ror' : prerequisite_funders_ror,
                                                                                          'prerequisite_funders_country' : prerequisite_funders_country,
                                                                                          'prerequisite_funders_url' : prerequisite_funders_url,
                                                                                          'prerequisite_funders_sherpa_id' : prerequisite_funders_sherpa_id,
                                                                                          'prerequisite_subjects' : prerequisite_subjects,
                                                                                          'location' : location,
                                                                                          'locations_ir' : locations_ir,
                                                                                          'locations_not_ir' : locations_not_ir,
                                                                                          'named_repository' : named_repository,
                                                                                          'named_academic_social_network' : named_academic_social_network,
                                                                                          'copyright_owner' : copyright_owner,
                                                                                          'publisher_deposit' : publisher_deposit,
                                                                                          'archiving' : archiving,
                                                                                          'conditions' : conditions,
                                                                                          'public_notes' : public_notes,
                                                                                          'sherpa_created' : sherpa_created,
                                                                                          'sherpa_last_modified' : sherpa_last_modified
                                                                                          }, ignore_index=True)
                                            # sans prerequisites
                                            else :
                                                sherpa_policies = sherpa_policies.append({'NlmUniqueID' : journal_id,
                                                                                          'title_sherpa' : title_sherpa,
                                                                                          'issnp_sherpa' : issnp_sherpa,
                                                                                          'issne_sherpa' : issne_sherpa,
                                                                                          'url' : url,
                                                                                          'publisher_id' : publisher_id,
                                                                                          'publisher_country' : publisher_country,
                                                                                          'publisher_type' : publisher_type,
                                                                                          'publisher_url' : publisher_url,
                                                                                          'publisher_name' : publisher_name,
                                                                                      'sherpa_id' : sherpa_id,
                                                                                      'sherpa_uri' : sherpa_uri,
                                                                                      'open_access_prohibited' : open_access_prohibited,
                                                                                      'additional_oa_fee' : additional_oa_fee,
                                                                                      'article_version' : article_version,
                                                                                      'license' : mylicense,
                                                                                      'embargo' : embargo,
                                                                                      'prerequisites' : prerequisites,
                                                                                      'prerequisites_phrases' : prerequisites_phrases,
                                                                                      'prerequisite_funders' : prerequisite_funders,
                                                                                      'prerequisite_funders_name' : prerequisite_funders_name,
                                                                                      'prerequisite_funders_fundref' : prerequisite_funders_fundref,
                                                                                      'prerequisite_funders_ror' : prerequisite_funders_ror,
                                                                                      'prerequisite_funders_country' : prerequisite_funders_country,
                                                                                      'prerequisite_funders_url' : prerequisite_funders_url,
                                                                                      'prerequisite_funders_sherpa_id' : prerequisite_funders_sherpa_id,
                                                                                      'prerequisite_subjects' : prerequisite_subjects,
                                                                                      'location' : location,
                                                                                      'locations_ir' : locations_ir,
                                                                                      'locations_not_ir' : locations_not_ir,
                                                                                      'named_repository' : named_repository,
                                                                                      'named_academic_social_network' : named_academic_social_network,
                                                                                      'copyright_owner' : copyright_owner,
                                                                                      'publisher_deposit' : publisher_deposit,
                                                                                      'archiving' : archiving,
                                                                                      'conditions' : conditions,
                                                                                      'public_notes' : public_notes,
                                                                                      'sherpa_created' : sherpa_created,
                                                                                      'sherpa_last_modified' : sherpa_last_modified
                                                                                      }, ignore_index=True)
                            # sans permitted_oa
                            else :
                                # print(journal_issn + ' - sherpa ID ' + str(sherpa_id) + ' permitted_oa MISSING -> SKIP')
                                sherpa_log = sherpa_log + 'permitted_oa MISSING - '
                else :
                    # print(journal_issn + ' - sherpa ID MISSING')
                    sherpa_log = sherpa_log + 'sherpa ID MISSING - '
            else :
                # print(journal_issn + ' - sherpa sans items')
                sherpa_log = sherpa_log + 'sherpa without items - '
    else :
        sherpa_log = sherpa_log + 'JSON file MISSING - '
    sherpalog = sherpalog.append({'journal' : journal_id, 'issn' : journal_issn, 'sherpa_id' : sherpa_id, 'result' : sherpa_log}, ignore_index=True)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100

# %%
sherpa_policies
# Out:
#       NlmUniqueID                       title_sherpa issne_sherpa  \
# 0         9015384  Twentieth Century British History    1477-4674
# 1         9015384  Twentieth Century British History    1477-4674
# 2         9015384  Twentieth Century British History    1477-4674
# 3         9015384  Twentieth Century British History    1477-4674
# 4         9015384  Twentieth Century British History    1477-4674
# ...           ...                                ...          ...
# 49562     9435608                            Zoology          NaN
# 49563     9435608                            Zoology          NaN
# 49564     9435608                            Zoology          NaN
# 49565     9435608                            Zoology          NaN
# 49566     9435608                            Zoology          NaN
#
#       issnp_sherpa                                                url  \
# 0        0955-2359                      https://academic.oup.com/tcbh
# 1        0955-2359                      https://academic.oup.com/tcbh
# 2        0955-2359                      https://academic.oup.com/tcbh
# 3        0955-2359                      https://academic.oup.com/tcbh
# 4        0955-2359                      https://academic.oup.com/tcbh
# ...            ...                                                ...
# 49562    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49563    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49564    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49565    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49566    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
#
#       publisher_id publisher_country        publisher_type  \
# 0               55                gb  university_publisher
# 1               55                gb  university_publisher
# 2               55                gb  university_publisher
# 3               55                gb  university_publisher
# 4               55                gb  university_publisher
# ...            ...               ...                   ...
# 49562           30                us  commercial_publisher
# 49563           30                us  commercial_publisher
# 49564           30                us  commercial_publisher
# 49565           30                us  commercial_publisher
# 49566           30                us  commercial_publisher
#
#                             publisher_url           publisher_name sherpa_id  \
# 0      https://academic.oup.com/journals/  Oxford University Press      1406
# 1      https://academic.oup.com/journals/  Oxford University Press      1406
# 2      https://academic.oup.com/journals/  Oxford University Press      1406
# 3      https://academic.oup.com/journals/  Oxford University Press      1406
# 4      https://academic.oup.com/journals/  Oxford University Press      1406
# ...                                   ...                      ...       ...
# 49562            http://www.elsevier.com/                 Elsevier     15919
# 49563            http://www.elsevier.com/                 Elsevier     15919
# 49564            http://www.elsevier.com/                 Elsevier     15919
# 49565            http://www.elsevier.com/                 Elsevier     15919
# 49566            http://www.elsevier.com/                 Elsevier     15919
#
#                                              sherpa_uri  \
# 0      https://v2.sherpa.ac.uk/id/publisher_policy/1112
# 1      https://v2.sherpa.ac.uk/id/publisher_policy/1112
# 2      https://v2.sherpa.ac.uk/id/publisher_policy/1112
# 3      https://v2.sherpa.ac.uk/id/publisher_policy/3302
# 4      https://v2.sherpa.ac.uk/id/publisher_policy/3302
# ...                                                 ...
# 49562  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49563  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49564  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49565  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49566  https://v2.sherpa.ac.uk/id/publisher_policy/3323
#
#       open_access_prohibited additional_oa_fee article_version      license  \
# 0                         no                no       submitted
# 1                         no                no        accepted
# 2                         no                no        accepted
# 3                         no               yes       published     cc_by_nc
# 4                         no               yes       published  cc_by_nc_nd
# ...                      ...               ...             ...          ...
# 49562                     no               yes       published        cc_by
# 49563                     no               yes       published        cc_by
# 49564                     no               yes       published        cc_by
# 49565                     no               yes       published        cc_by
# 49566                     no               yes       published        cc_by
#
#       embargo prerequisites prerequisite_funders  \
# 0           0           NaN                  NaN
# 1          24           NaN                  NaN
# 2           0           NaN                  NaN
# 3           0           NaN                  NaN
# 4           0           NaN                  NaN
# ...       ...           ...                  ...
# 49562       0           NaN                 True
# 49563       0           NaN                 True
# 49564       0           NaN                 True
# 49565       0           NaN                 True
# 49566       0           NaN                 True
#
#                                prerequisite_funders_name  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49562                     Medical Research Council (MRC)
# 49563  Motor Neuron Disease Association (MND Associat...
# 49564                                     Parkinson's UK
# 49565                                Telethon Foundation
# 49566  National Institute for Health and Care Researc...
#
#                   prerequisite_funders_fundref   prerequisite_funders_ror  \
# 0                                          NaN                        NaN
# 1                                          NaN                        NaN
# 2                                          NaN                        NaN
# 3                                          NaN                        NaN
# 4                                          NaN                        NaN
# ...                                        ...                        ...
# 49562  http://dx.doi.org/10.13039/501100000265  https://ror.org/03x94j517
# 49563  http://dx.doi.org/10.13039/501100000406  https://ror.org/02gq0fg61
# 49564  http://dx.doi.org/10.13039/501100000304  https://ror.org/02417p338
# 49565  http://dx.doi.org/10.13039/501100002426  https://ror.org/04xraxn18
# 49566                    10.13039/501100000272  https://ror.org/0187kwz08
#
#       prerequisite_funders_country        prerequisite_funders_url  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ...                            ...                             ...
# 49562                           gb  http://www.mrc.ac.uk/index.htm
# 49563                           gb  http://www.mndassociation.org/
# 49564                           gb   http://www.parkinsons.org.uk/
# 49565                           it     https://www.telethon.it/en/
# 49566                           gb         https://www.nihr.ac.uk/
#
#       prerequisite_funders_sherpa_id prerequisite_subjects  \
# 0                                NaN                   NaN
# 1                                NaN                   NaN
# 2                                NaN                   NaN
# 3                                NaN                   NaN
# 4                                NaN                   NaN
# ...                              ...                   ...
# 49562                            705                   NaN
# 49563                            562                   NaN
# 49564                            411                   NaN
# 49565                            325                   NaN
# 49566                           1333                   NaN
#
#                                                 location  \
# 0      any_repository ; any_website ; authors_homepag...
# 1      institutional_repository ; non_commercial_subj...
# 2                                       authors_homepage
# 3      any_website ; named_repository ; non_commercia...
# 4      any_website ; named_repository ; non_commercia...
# ...                                                  ...
# 49562  any_repository ; institutional_repository ; na...
# 49563  any_repository ; institutional_repository ; na...
# 49564  any_repository ; institutional_repository ; na...
# 49565  any_repository ; institutional_repository ; na...
# 49566  any_repository ; institutional_repository ; na...
#
#                                             locations_ir  \
# 0      Any Repository ; Any Website ; Institutional R...
# 1                               Institutional Repository
# 2
# 3      Any Website ; Non-Commercial Institutional Rep...
# 4      Any Website ; Non-Commercial Institutional Rep...
# ...                                                  ...
# 49562          Any Repository ; Institutional Repository
# 49563          Any Repository ; Institutional Repository
# 49564          Any Repository ; Institutional Repository
# 49565          Any Repository ; Institutional Repository
# 49566          Any Repository ; Institutional Repository
#
#                                         locations_not_ir  \
# 0      Author's Homepage ; Non-Commercial Subject Rep...
# 1                      Non-Commercial Subject Repository
# 2                                      Author's Homepage
# 3      PubMed Central ; Non-Commercial Subject Reposi...
# 4      PubMed Central ; Non-Commercial Subject Reposi...
# ...                                                  ...
# 49562  PubMed Central ; Research for Development Repo...
# 49563  PubMed Central ; Research for Development Repo...
# 49564  PubMed Central ; Research for Development Repo...
# 49565  PubMed Central ; Research for Development Repo...
# 49566  PubMed Central ; Research for Development Repo...
#
#                                         named_repository  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                         PubMed Central
# 4                                         PubMed Central
# ...                                                  ...
# 49562  PubMed Central ; Research for Development Repo...
# 49563  PubMed Central ; Research for Development Repo...
# 49564  PubMed Central ; Research for Development Repo...
# 49565  PubMed Central ; Research for Development Repo...
# 49566  PubMed Central ; Research for Development Repo...
#
#       named_academic_social_network copyright_owner  \
# 0                               NaN             NaN
# 1                               NaN             NaN
# 2                               NaN             NaN
# 3                               NaN             NaN
# 4                               NaN             NaN
# ...                             ...             ...
# 49562                           NaN             NaN
# 49563                           NaN             NaN
# 49564                           NaN             NaN
# 49565                           NaN             NaN
# 49566                           NaN             NaN
#
#                       publisher_deposit archiving  \
# 0                                   NaN      True
# 1                                   NaN      True
# 2                                   NaN     False
# 3      disciplinary (PubMed Central) ;       True
# 4      disciplinary (PubMed Central) ;       True
# ...                                 ...       ...
# 49562  disciplinary (PubMed Central) ;       True
# 49563  disciplinary (PubMed Central) ;       True
# 49564  disciplinary (PubMed Central) ;       True
# 49565  disciplinary (PubMed Central) ;       True
# 49566  disciplinary (PubMed Central) ;       True
#
#                                               conditions public_notes  \
# 0      Prior to acceptance ; Must be accompanied by a...          NaN
# 1      Published source must be acknowledged ; Must l...          NaN
# 2      Published source must be acknowledged ; Must l...          NaN
# 3      Published source must be acknowledged with cit...          NaN
# 4      Published source must be acknowledged with cit...          NaN
# ...                                                  ...          ...
# 49562  Published source must be acknowledged with cit...          NaN
# 49563  Published source must be acknowledged with cit...          NaN
# 49564  Published source must be acknowledged with cit...          NaN
# 49565  Published source must be acknowledged with cit...          NaN
# 49566  Published source must be acknowledged with cit...          NaN
#
#             sherpa_created sherpa_last_modified prerequisites_phrases
# 0      2010-07-15 16:04:39  2022-07-26 10:25:23
# 1      2010-07-15 16:04:39  2022-07-26 10:25:23
# 2      2010-07-15 16:04:39  2022-07-26 10:25:23
# 3      2010-07-15 16:04:39  2022-07-26 10:25:23
# 4      2010-07-15 16:04:39  2022-07-26 10:25:23
# ...                    ...                  ...                   ...
# 49562  2010-09-14 14:06:06  2022-07-26 14:26:43
# 49563  2010-09-14 14:06:06  2022-07-26 14:26:43
# 49564  2010-09-14 14:06:06  2022-07-26 14:26:43
# 49565  2010-09-14 14:06:06  2022-07-26 14:26:43
# 49566  2010-09-14 14:06:06  2022-07-26 14:26:43
#
# [49567 rows x 39 columns]

# %%
# convertir l'index en id
sherpa_policies.reset_index(drop=True, inplace=True)
# ajout de l'id avec l'index + 1
sherpa_policies['id'] = sherpa_policies.index + 1
sherpa_policies
# Out:
#       NlmUniqueID                       title_sherpa issne_sherpa  \
# 0         9015384  Twentieth Century British History    1477-4674
# 1         9015384  Twentieth Century British History    1477-4674
# 2         9015384  Twentieth Century British History    1477-4674
# 3         9015384  Twentieth Century British History    1477-4674
# 4         9015384  Twentieth Century British History    1477-4674
# ...           ...                                ...          ...
# 49562     9435608                            Zoology          NaN
# 49563     9435608                            Zoology          NaN
# 49564     9435608                            Zoology          NaN
# 49565     9435608                            Zoology          NaN
# 49566     9435608                            Zoology          NaN
#
#       issnp_sherpa                                                url  \
# 0        0955-2359                      https://academic.oup.com/tcbh
# 1        0955-2359                      https://academic.oup.com/tcbh
# 2        0955-2359                      https://academic.oup.com/tcbh
# 3        0955-2359                      https://academic.oup.com/tcbh
# 4        0955-2359                      https://academic.oup.com/tcbh
# ...            ...                                                ...
# 49562    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49563    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49564    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49565    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
# 49566    0944-2006  http://www.elsevier.com/wps/product/cws_home/7...
#
#       publisher_id publisher_country        publisher_type  \
# 0               55                gb  university_publisher
# 1               55                gb  university_publisher
# 2               55                gb  university_publisher
# 3               55                gb  university_publisher
# 4               55                gb  university_publisher
# ...            ...               ...                   ...
# 49562           30                us  commercial_publisher
# 49563           30                us  commercial_publisher
# 49564           30                us  commercial_publisher
# 49565           30                us  commercial_publisher
# 49566           30                us  commercial_publisher
#
#                             publisher_url           publisher_name sherpa_id  \
# 0      https://academic.oup.com/journals/  Oxford University Press      1406
# 1      https://academic.oup.com/journals/  Oxford University Press      1406
# 2      https://academic.oup.com/journals/  Oxford University Press      1406
# 3      https://academic.oup.com/journals/  Oxford University Press      1406
# 4      https://academic.oup.com/journals/  Oxford University Press      1406
# ...                                   ...                      ...       ...
# 49562            http://www.elsevier.com/                 Elsevier     15919
# 49563            http://www.elsevier.com/                 Elsevier     15919
# 49564            http://www.elsevier.com/                 Elsevier     15919
# 49565            http://www.elsevier.com/                 Elsevier     15919
# 49566            http://www.elsevier.com/                 Elsevier     15919
#
#                                              sherpa_uri  \
# 0      https://v2.sherpa.ac.uk/id/publisher_policy/1112
# 1      https://v2.sherpa.ac.uk/id/publisher_policy/1112
# 2      https://v2.sherpa.ac.uk/id/publisher_policy/1112
# 3      https://v2.sherpa.ac.uk/id/publisher_policy/3302
# 4      https://v2.sherpa.ac.uk/id/publisher_policy/3302
# ...                                                 ...
# 49562  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49563  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49564  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49565  https://v2.sherpa.ac.uk/id/publisher_policy/3323
# 49566  https://v2.sherpa.ac.uk/id/publisher_policy/3323
#
#       open_access_prohibited additional_oa_fee article_version      license  \
# 0                         no                no       submitted
# 1                         no                no        accepted
# 2                         no                no        accepted
# 3                         no               yes       published     cc_by_nc
# 4                         no               yes       published  cc_by_nc_nd
# ...                      ...               ...             ...          ...
# 49562                     no               yes       published        cc_by
# 49563                     no               yes       published        cc_by
# 49564                     no               yes       published        cc_by
# 49565                     no               yes       published        cc_by
# 49566                     no               yes       published        cc_by
#
#       embargo prerequisites prerequisite_funders  \
# 0           0           NaN                  NaN
# 1          24           NaN                  NaN
# 2           0           NaN                  NaN
# 3           0           NaN                  NaN
# 4           0           NaN                  NaN
# ...       ...           ...                  ...
# 49562       0           NaN                 True
# 49563       0           NaN                 True
# 49564       0           NaN                 True
# 49565       0           NaN                 True
# 49566       0           NaN                 True
#
#                                prerequisite_funders_name  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 49562                     Medical Research Council (MRC)
# 49563  Motor Neuron Disease Association (MND Associat...
# 49564                                     Parkinson's UK
# 49565                                Telethon Foundation
# 49566  National Institute for Health and Care Researc...
#
#                   prerequisite_funders_fundref   prerequisite_funders_ror  \
# 0                                          NaN                        NaN
# 1                                          NaN                        NaN
# 2                                          NaN                        NaN
# 3                                          NaN                        NaN
# 4                                          NaN                        NaN
# ...                                        ...                        ...
# 49562  http://dx.doi.org/10.13039/501100000265  https://ror.org/03x94j517
# 49563  http://dx.doi.org/10.13039/501100000406  https://ror.org/02gq0fg61
# 49564  http://dx.doi.org/10.13039/501100000304  https://ror.org/02417p338
# 49565  http://dx.doi.org/10.13039/501100002426  https://ror.org/04xraxn18
# 49566                    10.13039/501100000272  https://ror.org/0187kwz08
#
#       prerequisite_funders_country        prerequisite_funders_url  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ...                            ...                             ...
# 49562                           gb  http://www.mrc.ac.uk/index.htm
# 49563                           gb  http://www.mndassociation.org/
# 49564                           gb   http://www.parkinsons.org.uk/
# 49565                           it     https://www.telethon.it/en/
# 49566                           gb         https://www.nihr.ac.uk/
#
#       prerequisite_funders_sherpa_id prerequisite_subjects  \
# 0                                NaN                   NaN
# 1                                NaN                   NaN
# 2                                NaN                   NaN
# 3                                NaN                   NaN
# 4                                NaN                   NaN
# ...                              ...                   ...
# 49562                            705                   NaN
# 49563                            562                   NaN
# 49564                            411                   NaN
# 49565                            325                   NaN
# 49566                           1333                   NaN
#
#                                                 location  \
# 0      any_repository ; any_website ; authors_homepag...
# 1      institutional_repository ; non_commercial_subj...
# 2                                       authors_homepage
# 3      any_website ; named_repository ; non_commercia...
# 4      any_website ; named_repository ; non_commercia...
# ...                                                  ...
# 49562  any_repository ; institutional_repository ; na...
# 49563  any_repository ; institutional_repository ; na...
# 49564  any_repository ; institutional_repository ; na...
# 49565  any_repository ; institutional_repository ; na...
# 49566  any_repository ; institutional_repository ; na...
#
#                                             locations_ir  \
# 0      Any Repository ; Any Website ; Institutional R...
# 1                               Institutional Repository
# 2
# 3      Any Website ; Non-Commercial Institutional Rep...
# 4      Any Website ; Non-Commercial Institutional Rep...
# ...                                                  ...
# 49562          Any Repository ; Institutional Repository
# 49563          Any Repository ; Institutional Repository
# 49564          Any Repository ; Institutional Repository
# 49565          Any Repository ; Institutional Repository
# 49566          Any Repository ; Institutional Repository
#
#                                         locations_not_ir  \
# 0      Author's Homepage ; Non-Commercial Subject Rep...
# 1                      Non-Commercial Subject Repository
# 2                                      Author's Homepage
# 3      PubMed Central ; Non-Commercial Subject Reposi...
# 4      PubMed Central ; Non-Commercial Subject Reposi...
# ...                                                  ...
# 49562  PubMed Central ; Research for Development Repo...
# 49563  PubMed Central ; Research for Development Repo...
# 49564  PubMed Central ; Research for Development Repo...
# 49565  PubMed Central ; Research for Development Repo...
# 49566  PubMed Central ; Research for Development Repo...
#
#                                         named_repository  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                         PubMed Central
# 4                                         PubMed Central
# ...                                                  ...
# 49562  PubMed Central ; Research for Development Repo...
# 49563  PubMed Central ; Research for Development Repo...
# 49564  PubMed Central ; Research for Development Repo...
# 49565  PubMed Central ; Research for Development Repo...
# 49566  PubMed Central ; Research for Development Repo...
#
#       named_academic_social_network copyright_owner  \
# 0                               NaN             NaN
# 1                               NaN             NaN
# 2                               NaN             NaN
# 3                               NaN             NaN
# 4                               NaN             NaN
# ...                             ...             ...
# 49562                           NaN             NaN
# 49563                           NaN             NaN
# 49564                           NaN             NaN
# 49565                           NaN             NaN
# 49566                           NaN             NaN
#
#                       publisher_deposit archiving  \
# 0                                   NaN      True
# 1                                   NaN      True
# 2                                   NaN     False
# 3      disciplinary (PubMed Central) ;       True
# 4      disciplinary (PubMed Central) ;       True
# ...                                 ...       ...
# 49562  disciplinary (PubMed Central) ;       True
# 49563  disciplinary (PubMed Central) ;       True
# 49564  disciplinary (PubMed Central) ;       True
# 49565  disciplinary (PubMed Central) ;       True
# 49566  disciplinary (PubMed Central) ;       True
#
#                                               conditions public_notes  \
# 0      Prior to acceptance ; Must be accompanied by a...          NaN
# 1      Published source must be acknowledged ; Must l...          NaN
# 2      Published source must be acknowledged ; Must l...          NaN
# 3      Published source must be acknowledged with cit...          NaN
# 4      Published source must be acknowledged with cit...          NaN
# ...                                                  ...          ...
# 49562  Published source must be acknowledged with cit...          NaN
# 49563  Published source must be acknowledged with cit...          NaN
# 49564  Published source must be acknowledged with cit...          NaN
# 49565  Published source must be acknowledged with cit...          NaN
# 49566  Published source must be acknowledged with cit...          NaN
#
#             sherpa_created sherpa_last_modified prerequisites_phrases     id
# 0      2010-07-15 16:04:39  2022-07-26 10:25:23                            1
# 1      2010-07-15 16:04:39  2022-07-26 10:25:23                            2
# 2      2010-07-15 16:04:39  2022-07-26 10:25:23                            3
# 3      2010-07-15 16:04:39  2022-07-26 10:25:23                            4
# 4      2010-07-15 16:04:39  2022-07-26 10:25:23                            5
# ...                    ...                  ...                   ...    ...
# 49562  2010-09-14 14:06:06  2022-07-26 14:26:43                        49563
# 49563  2010-09-14 14:06:06  2022-07-26 14:26:43                        49564
# 49564  2010-09-14 14:06:06  2022-07-26 14:26:43                        49565
# 49565  2010-09-14 14:06:06  2022-07-26 14:26:43                        49566
# 49566  2010-09-14 14:06:06  2022-07-26 14:26:43                        49567
#
# [49567 rows x 40 columns]

# %% [markdown]
# ## Export

# %%
# exports csv
sherpa_policies.to_csv('data/temp/2023/sherpa_policies.tsv', sep='\t', encoding='utf-8', index=False)
sherpalog.to_csv('data/temp/2023/sherpa_log.tsv', sep='\t', encoding='utf-8', index=False)

# %%
# exports excel
sherpa_policies.to_excel('data/temp/2023/sherpa_policies.xlsx', index=False)
sherpalog.to_excel('data/temp/2023/sherpa_log.xlsx', index=False)
# Out:
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://authorservices.wiley.com/open-research/open-access/index.html' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.springernature.com/gp/products/journals' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://uk.sagepub.com/en-gb/eur/home' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.liebertpub.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.karger.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://academic.oup.com/journals/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.elsevier.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.wiley.com/en-gb' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.biomedcentral.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://taylorandfrancis.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.nature.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.heart.org/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.ieee.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.acm.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aai.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.futuremedicine.com/about' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.iospress.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.sivb.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://iiar-anticancer.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.medknow.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://scientificscholar.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.cambridge.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.hindawi.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://benthamscience.com/index.php' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://asm.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://group.bmj.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://lww.com/pages/default.aspx' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://pubs.acs.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.minervamedica.it/it/index.php' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jstage.jst.go.jp/browse/ihj' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.degruyter.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://ivyspring.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.dustri.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.ijdb.ehu.es/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.mdpi.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.emerald.com/insight/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.kmu.ac.ir/Default8.aspx?Id=1' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.springeropen.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.begellhouse.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.spandidos-publications.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.worldscientific.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.imp.lodz.pl/index.php' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.markallengroup.com/ma-healthcare/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.swansea.ac.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.frontiersin.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://us.humankinetics.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.thieme.com/en-us' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://microbiologysociety.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://theunion.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.hogrefe.com/uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://revistes.iec.cat/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aaidd.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.arvo.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://journals.tums.ac.ir//' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.iucr.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.quintessence-publishing.com/deu/en' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.asabe.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.asahp.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.asn-online.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.avma.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www5.usp.br/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.physiology.org/?SSO=Y' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.apa.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.nata.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.wiley-vch.de/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://akjournals.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.asme.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://spie.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://iopscience.iop.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://rupress.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.biologists.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aip.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.press.uchicago.edu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.the-asci.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.asco.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.psychiatrist.com/about-psychiatrist-com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://aasm.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://mitpress.mit.edu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.springerpub.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://becaris.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://journals.healio.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aapd.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.kuksiwon.or.kr/index.do' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.bioscientifica.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://jeaweb.jp/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.oldcitypublishing.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.foodprotection.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://isogh.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.press.jhu.edu/journals' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.dukeupress.edu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.pennpress.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.imrpress.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.kams.or.kr/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.thomsonreuters.com.au/en.html' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.rsc.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://jmirpublications.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.mlanet.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.icmpe.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://psychiatryonline.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.sfn.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.snmmi.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.optica.org/en-us/home/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aaid-implant.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jospt.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aspet.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://medicaljournalssweden.se/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.publish.csiro.au/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.cma.ca/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.palgrave.com/gb/journals' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://royalsociety.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jrheum.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.asha.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.utpjournals.press/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jove.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://iwaponline.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.wildlifedisease.org/PersonifyEbusiness/Home' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.ama-assn.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://acousticalsociety.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.wolterskluwer.com/en' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.thieme.de/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.cshlpress.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://bristoluniversitypress.co.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jsmrm.jp/modules/en/index.php?content_id=1' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jle.com/fr/index.phtml' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.aimspress.com/index.html' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.cell.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://publications.edpsciences.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.ubiquitypress.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.pleiades.online/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.ascb.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aacr.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.ksmcb.or.kr/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.apsnet.org/Pages/default.aspx' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://brill.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.massmed.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://journal.nzma.org.nz/old-home' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.societyforchaostheory.org/home/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.longwoods.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://journals.rcni.com/home' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://ediciones.grupoaran.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://onf.ons.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.impactjournals.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://aosis.co.za/about-journals/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.upr.edu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.ansinet.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.edp-open.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.pagepress.org/site' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aap.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://peerj.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aps.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://plos.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.termedia.pl/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://wydawnictwo.umw.edu.pl/pl/home/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://karolinum.cz/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.nasonline.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.cop-asturias.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.psychiatriapolska.pl' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.rsna.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://sciendo.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jsmp.org/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.unc.edu.ar/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.revistas.unal.edu.co/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.jcu.edu.au/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.samedical.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.unla.edu.ar/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.norosh.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aaas.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://smw.ch/about-us' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.libraweb.net/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.legeforeningen.no/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://asia-spinalinjury.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.turkjpath.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.ums.ac.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.keaipublishing.com/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.emergencymed.uci.edu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.who.int/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.wjgnet.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.lungca.org/index.php?journal=01' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.mapress.com/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
# ...
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.economy-ni.gov.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.cso.scot.nhs.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.gov.uk/government/organisations/department-of-health-and-social-care' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://dunhillmedical.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://erc.europa.eu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.mndassociation.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.telethon.it/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aka.fi/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.agence-nationale-recherche.fr/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://parkinsonsroadmap.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://ec.europa.eu/research/horizon2020/index_en.cfm' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.forte.se/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.fnr.lu/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.formas.se/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.fct.pt/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.hcst.gov.jo/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.gov.uk/government/organisations/innovate-uk' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://ncn.gov.pl/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.nwo.nl/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.forskningsradet.no/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.rj.se/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.sagw.ch/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.arrs.si/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.templetonworldcharity.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.vinnova.se/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.who.int/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.sfi.ie/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.arrs.si' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.aasciences.ac.ke/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.samrc.ac.za/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.ahrq.gov/index.html' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://science.nasa.gov/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.actiononhearingloss.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://alzheimers.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://acmedsci.ac.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.diabetes.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://prostatecanceruk.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.snf.ch/de/Seiten/default.aspx' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.mariecurie.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.mssociety.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.myrovlytistrust.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.nc3rs.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.worldwidecancerresearch.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.vr.se/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.worldbank.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.yorkshirecancerresearch.org.uk/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.helmholtz.de/en/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://www.idrc.ca/en' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://ec.europa.eu/research/fp7/index_en.cfm' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://frq.gouv.qc.ca/nature-et-technologies/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://frq.gouv.qc.ca/sante/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://frq.gouv.qc.ca/en/society-and-culture/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.cihr-irsc.gc.ca/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'https://kaw.wallenberg.org/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://energy.gov/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://ies.ed.gov/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.nsf.gov/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.nserc-crsng.gc.ca/index_eng.asp' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\iriarte\AppData\Local\Continuum\anaconda3\lib\site-packages\xlsxwriter\worksheet.py:939: UserWarning: Ignoring URL 'http://www.sshrc-crsh.gc.ca/home-accueil-eng.aspx' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
